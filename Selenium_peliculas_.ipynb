# %%
#Importar librerías necesarias:

#Librería para manipulación y análisis de datos.
import pandas as pd

#Selenium para automatizar la interacción con navegadores web.
from selenium import webdriver

#Maneja la instalación automática del ChromeDriver.
from webdriver_manager.chrome import ChromeDriverManager

#Permite localizar elementos HTML usando diferentes métodos.
from selenium.webdriver.common.by import By

#Espera explícita para asegurar que los elementos se carguen.
from selenium.webdriver.support.ui import WebDriverWait 

#Condiciones de espera explícitas.
from selenium.webdriver.support import expected_conditions as EC

#Pausa la ejecución del código por un número de segundos.
from time import sleep

#Configuraciones iniciales para pandas:

#Configuración para mostrar todas las columnas del DataFrame.
pd.set_option('display.max_columns', None)

# %%
#Función para generar el driver de Selenium:

def generar_driver():
    #Configuración del navegador:
    driver = webdriver.Chrome() #Inicializa ChromeDriver.

    sleep(2)

    driver.maximize_window() #Maximiza la ventana del navegador.
    print("Maximizando la web.")

    sleep(2)

    driver.get("https://www.imdb.com/") #Navega a IMDb.
    print("Accediendo a la web.")

    sleep(2)
    
    #Aceptar cookies si aparece el botón.
    driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
    print("Cookies aceptadas.")
    
    return driver

# %%
#Función para extraer información utilizando una lista de selectores CSS:

def extraer_con_selectores(driver, selectores):
    #Itera sobre los selectores proporcionados hasta encontrar uno que funcione.

    for selector in selectores:
        try:
            elemento = driver.find_element(By.CSS_SELECTOR, selector) #Busca el elemento usando CSS selector.
            if elemento: #Si el elemento se encuentra, devuelve su texto.
                return elemento.text
        except:
            continue #Si falla, pasa al siguiente selector.
    return "No disponible" #Devuelve "No disponible" si ninguno de los selectores funciona.

# %% [markdown]
# En la siguiente función usamos XPath.
#  XPath es un lenguaje para seleccionar nodos en un documento XML/HTML.
#  Es especialmente útil para encontrar elementos en estructuras complejas de HTML que no pueden ser fácilmente seleccionadas con CSS selectors.

# %%
# Función para extraer los nombres de directores y guionistas filtrando correctamente

def extraer_nombres(driver, xpath_selector):
    try:
        #Encuentra los elementos usando el XPath especificado.
        elementos = driver.find_elements(By.XPATH, xpath_selector)
        #Limpia los textos, eliminando espacios adicionales y evitando elementos vacíos.
        nombres = [elemento.text.strip() for elemento in elementos if elemento.text.strip()]
        #Une los nombres en una cadena, separados por comas.
        return ", ".join(nombres).rstrip(",") if nombres else "No disponible"
    except:
        return "No disponible"

# %%
#Función principal para extraer los datos de una película dada su ID de IMDb.

def extraer_datos_pelicula(driver, id_pelicula):
#Construye la URL de la película usando su ID.
    url_pelicula = f"https://www.imdb.com/title/{id_pelicula}"
    driver.get(url_pelicula) #Navega a la página de la película.
    print(f"Accediendo a la película con ID {id_pelicula}")
    sleep(2)

    #Extrae nombre de la película.
    try:
        titulo_pelicula = driver.find_element(By.CSS_SELECTOR, 'h1').text #Busca el título usando un selector CSS simple.
        print("Nombre de la película:", titulo_pelicula)
    except:
        titulo_pelicula = "No disponible"
        print("Nombre de la película:", titulo_pelicula)

    #Lista de posibles selectores para la puntuación de IMDb.
    selectores_puntuacion = [
        'span[class*="AggregateRatingButton__RatingScore"]',
        'span[data-testid="hero-rating-bar__aggregate-rating__score"]',
        'div[data-testid="hero-rating-bar__aggregate-rating__score"] span'
    ]

    #Intenta extraer la puntuación utilizando varios selectores.
    puntuacion_pelicula = extraer_con_selectores(driver, selectores_puntuacion)
    print("Puntuación de IMDb:", puntuacion_pelicula)

    #Extrae los directores utilizando un selector XPath específico.
    directores_texto = extraer_nombres(driver, '//a[contains(@href, "/name/") and contains(@href, "/?ref_=tt_ov_dr")]')
    print("Directores:", directores_texto)

    #Extrae los guionistas utilizando un selector XPath específico.
    guionistas_texto = extraer_nombres(driver, '//a[contains(@href, "/name/") and contains(@href, "/?ref_=tt_ov_wr")]')
    print("Guionistas:", guionistas_texto)

    #Extrae el ID de la película desde la URL actual.
    try:
        argumento_pelicula = driver.find_element(By.CSS_SELECTOR, 'span[data-testid="plot-xl"]').text
        print("Argumento:", argumento_pelicula)
    except:
        argumento_pelicula = "No disponible"
        print("Argumento:", argumento_pelicula)

    #Extrae el ID de la película desde la URL actual.
    id_pelicula = driver.current_url.split('/')[4]
    print("ID de la película:", id_pelicula)

    sleep(2)

    #Crea una tupla con todos los datos extraídos para almacenarlos posteriormente.
    tupla_datos_pelicula = (titulo_pelicula, puntuacion_pelicula, directores_texto, guionistas_texto, argumento_pelicula, id_pelicula)

    #Imprime la tupla de resultados.
    print("Datos extraídos:", tupla_datos_pelicula)

    return tupla_datos_pelicula

# %%
#Función para extraer los IDs de las películas desde un archivo CSV:

def extractor_idowners(archivo_csv):
    df_pelis_API = pd.read_csv(archivo_csv) #Lee el archivo CSV con los IDs de las películas.
    lista_idowners = df_pelis_API['IdOwner'].tolist() #Convierte la columna de IDs a una lista.
    return lista_idowners

# %%
#Lista de IDs de las películas a extraer.
ids_peliculas = extractor_idowners('peliculas_api_desde_1995_a_2009.csv')

# %%
#Crear el driver de Selenium.
mi_driver = generar_driver()
# Out:
# Maximizando la web.
# Accediendo a la web.
# Cookies aceptadas.

# %%
#Lista para almacenar los datos extraídos de todas las películas.
datos_peliculas = []

# %%
#Itera sobre cada ID de película y extrae los datos correspondientes.
for id_owner in ids_peliculas:
    mis_datos = extraer_datos_pelicula(mi_driver, id_owner)
    datos_peliculas.append(mis_datos)
# Out:
# Accediendo a la película con ID tt0100267
# Nombre de la película: Nobat e Asheghi
# Puntuación de IMDb: 6,4
# Directores: Mohsen Makhmalbaf
# Guionistas: Mohsen Makhmalbaf
# Argumento: Part one: A brown-haired man finds out that his wife cheats on him with a blonde-haired man. He kills his rival and is condemned to the capital punishment. Gazale takes her own life. Part two: Same story. Same denouement, the only variant being that it is the blond-haired man who is the husband and the brown-haired one who is the lover. Part three: The story starts ov... Leer todo
# ID de la película: tt0100267
# Datos extraídos: ('Nobat e Asheghi', '6,4', 'Mohsen Makhmalbaf', 'Mohsen Makhmalbaf', 'Part one: A brown-haired man finds out that his wife cheats on him with a blonde-haired man. He kills his rival and is condemned to the capital punishment. Gazale takes her own life. Part two: Same story. Same denouement, the only variant being that it is the blond-haired man who is the husband and the brown-haired one who is the lover. Part three: The story starts ov... Leer todo', 'tt0100267')
# Accediendo a la película con ID tt0102739
# Nombre de la película: ¡Que vivan los crotos!
# Puntuación de IMDb: 6,7
# Directores: Ana Poliak
# Guionistas: Willi Behnisch, Ana Poliak
# Argumento: The film tells the story of an imigrant to Argentina who works for the railway company of this land. Being a witness to the history of the land of silver in this century the film is also a shortcut of the changes in Argentina during the last 100 years.
# ID de la película: tt0102739
# Datos extraídos: ('¡Que vivan los crotos!', '6,7', 'Ana Poliak', 'Willi Behnisch, Ana Poliak', 'The film tells the story of an imigrant to Argentina who works for the railway company of this land. Being a witness to the history of the land of silver in this century the film is also a shortcut of the changes in Argentina during the last 100 years.', 'tt0102739')
# Accediendo a la película con ID tt0105096
# Nombre de la película: Paraíso Perdido
# Puntuación de IMDb: 6,4
# Directores: Alberto Seixas Santos
# Guionistas: António Cabrita, Alberto Seixas Santos
# Argumento:
# ID de la película: tt0105096
# Datos extraídos: ('Paraíso Perdido', '6,4', 'Alberto Seixas Santos', 'António Cabrita, Alberto Seixas Santos', '', 'tt0105096')
# Accediendo a la película con ID tt0105298
# Nombre de la película: Nacidos para la libertad
# Puntuación de IMDb: 5,5
# Directores: Dee McLachlan
# Guionistas: John Varty, Andrea Buck, Dee McLachlan
# Argumento: A filmmaker determines to document the story of a conservationist who is struggling to save wild leopards in Africa from extinction.
# ID de la película: tt0105298
# Datos extraídos: ('Nacidos para la libertad', '5,5', 'Dee McLachlan', 'John Varty, Andrea Buck, Dee McLachlan', 'A filmmaker determines to document the story of a conservationist who is struggling to save wild leopards in Africa from extinction.', 'tt0105298')
# Accediendo a la película con ID tt0106616
# Nombre de la película: Las cosas del querer 2ª parte
# Puntuación de IMDb: 5,1
# Directores: Jaime Chávarri
# Guionistas: Antonio Larreta, Luis Sanz
# Argumento:
# ID de la película: tt0106616
# Datos extraídos: ('Las cosas del querer 2ª parte', '5,1', 'Jaime Chávarri', 'Antonio Larreta, Luis Sanz', '', 'tt0106616')
# Accediendo a la película con ID tt0107070
# Nombre de la película: Halbe Welt
# Puntuación de IMDb: 6,6
# Directores: Florian Flicker
# Guionistas: Florian Flicker, Michael Sturminger
# Argumento: The sun blazes down from the sky with destructive power; exposing oneself to its light means death. People have transposed everyday existence to the night. In the metropolis of HALF WORLD a culture based on various languages and lifeforms has grown rampant. Everyone is looking for a way to survive.
# ID de la película: tt0107070
# Datos extraídos: ('Halbe Welt', '6,6', 'Florian Flicker', 'Florian Flicker, Michael Sturminger', 'The sun blazes down from the sky with destructive power; exposing oneself to its light means death. People have transposed everyday existence to the night. In the metropolis of HALF WORLD a culture based on various languages and lifeforms has grown rampant. Everyone is looking for a way to survive.', 'tt0107070')
# Accediendo a la película con ID tt0102952
# Nombre de la película: ¡Que rollo de madre!
# Puntuación de IMDb: 4,9
# Directores: Lawrence David Foldes
# Guionistas: Elisa Charouhas, Lawrence David Foldes
# Argumento: Babe Kim Sterling was destined to become the ball queen, but Beverly Hills' high society gets a taste of their own medicine when she alters the plans for their prestigious Las Madonnas Debutante Ball and turns it into a madcap fiesta.
# ID de la película: tt0102952
# Datos extraídos: ('¡Que rollo de madre!', '4,9', 'Lawrence David Foldes', 'Elisa Charouhas, Lawrence David Foldes', "Babe Kim Sterling was destined to become the ball queen, but Beverly Hills' high society gets a taste of their own medicine when she alters the plans for their prestigious Las Madonnas Debutante Ball and turns it into a madcap fiesta.", 'tt0102952')
# Accediendo a la película con ID tt0101616
# Nombre de la película: Coolie No. 1
# Puntuación de IMDb: 6,6
# Directores: David Dhawan
# Guionistas: Rumi Jaffery, Kader Khan
# Argumento: In order to avenge his insult against wealthy Hoshiarchand Choudhary; Pandit Shaadiram Gharjodhe asks Raju; a coolie by profession to masquerade as a wealthy business tycoon so that he can get marry to Choudhary's daughter Malti.
# ID de la película: tt0101616
# Datos extraídos: ('Coolie No. 1', '6,6', 'David Dhawan', 'Rumi Jaffery, Kader Khan', "In order to avenge his insult against wealthy Hoshiarchand Choudhary; Pandit Shaadiram Gharjodhe asks Raju; a coolie by profession to masquerade as a wealthy business tycoon so that he can get marry to Choudhary's daughter Malti.", 'tt0101616')
# Accediendo a la película con ID tt0102532
# Nombre de la película: Night Visions
# Puntuación de IMDb: 5,3
# Directores: Nicholas Mariolis
# Guionistas: Nicholas Mariolis
# Argumento: Author of erotic literature is suffering from writer's block. Beautiful women from various eras of history start appearing to the desperate man to introduce him to erotica popular in their times to help him find inspiration.
# ID de la película: tt0102532
# Datos extraídos: ('Night Visions', '5,3', 'Nicholas Mariolis', 'Nicholas Mariolis', "Author of erotic literature is suffering from writer's block. Beautiful women from various eras of history start appearing to the desperate man to introduce him to erotica popular in their times to help him find inspiration.", 'tt0102532')
# Accediendo a la película con ID tt0108576
# Nombre de la película: Witch Academy
# Puntuación de IMDb: 3,8
# Directores: Fred Olen Ray
# Guionistas: Mark Thomas McGee
# Argumento: Members of an exclusive college sorority (where sadomasochism seems to rule the day) seek twisted new ways to humiliate a new pledge.
# ID de la película: tt0108576
# Datos extraídos: ('Witch Academy', '3,8', 'Fred Olen Ray', 'Mark Thomas McGee', 'Members of an exclusive college sorority (where sadomasochism seems to rule the day) seek twisted new ways to humiliate a new pledge.', 'tt0108576')
# Accediendo a la película con ID tt0107537
# Nombre de la película: Mecánicas celestes
# Puntuación de IMDb: 6,7
# Directores: Fina Torres
# Guionistas: Yves Belaubre, Telsche Boorman, Daniel Odier
# Argumento: Ana bolts from her wedding altar and flies from Venezuela to Paris (in her wedding gown) to realize her dream of becoming a great opera star. The great Parisian director Italo Medici is filming an operatic Cinderella, but will Ana "fit into the glass slipper" before she is deported back to Caracas? The evil, plotting, self-absorbed Celeste tries to thwart Ana, but Ana... Leer todo
# ID de la película: tt0107537
# Datos extraídos: ('Mecánicas celestes', '6,7', 'Fina Torres', 'Yves Belaubre, Telsche Boorman, Daniel Odier', 'Ana bolts from her wedding altar and flies from Venezuela to Paris (in her wedding gown) to realize her dream of becoming a great opera star. The great Parisian director Italo Medici is filming an operatic Cinderella, but will Ana "fit into the glass slipper" before she is deported back to Caracas? The evil, plotting, self-absorbed Celeste tries to thwart Ana, but Ana... Leer todo', 'tt0107537')
# Accediendo a la película con ID tt0105881
# Nombre de la película: Magkasangga 2000
# Puntuación de IMDb: 4,1
# Directores: Joe Mari Avellana, Phillip Ko, Johnny Wood
# Guionistas: Joe Mari Avellana
# Argumento:
# ID de la película: tt0105881
# Datos extraídos: ('Magkasangga 2000', '4,1', 'Joe Mari Avellana, Phillip Ko, Johnny Wood', 'Joe Mari Avellana', '', 'tt0105881')
# Accediendo a la película con ID tt0109178
# Nombre de la película: Automatic
# Puntuación de IMDb: 5,2
# Directores: John Murlowski
# Guionistas: Avi Nesher, Susan Lambert
# Argumento: Robgen industries newest security system is "The J Series Automatic", an android model designed and programmed to protect humans from violent attacks. But one night, an Automatic named J269 discovers a Robgen executive trying to rape a female employee named Nora Rochester. While trying to stop the crime, he inadvertently kills the executive. At this point, J269 then c... Leer todo
# ID de la película: tt0109178
# Datos extraídos: ('Automatic', '5,2', 'John Murlowski', 'Avi Nesher, Susan Lambert', 'Robgen industries newest security system is "The J Series Automatic", an android model designed and programmed to protect humans from violent attacks. But one night, an Automatic named J269 discovers a Robgen executive trying to rape a female employee named Nora Rochester. While trying to stop the crime, he inadvertently kills the executive. At this point, J269 then c... Leer todo', 'tt0109178')
# Accediendo a la película con ID tt0109033
# Nombre de la película: Secuestradas
# Puntuación de IMDb: 3,6
# Directores: Boon Collins
# Guionistas: Boon Collins, Lindsay Bourne
# Argumento: While a hunting guide takes a big-game hunter into the wilderness, his dead son comes back to life to terrorize three female campers.
# ID de la película: tt0109033
# Datos extraídos: ('Secuestradas', '3,6', 'Boon Collins', 'Boon Collins, Lindsay Bourne', 'While a hunting guide takes a big-game hunter into the wilderness, his dead son comes back to life to terrorize three female campers.', 'tt0109033')
# Accediendo a la película con ID tt0109536
# Nombre de la película: Peligroso
# Puntuación de IMDb: 4,0
# Directores: Rod Hewitt, David Winters
# Guionistas: Rod Hewitt
# Argumento: Brother and sister Ninja warriors get revenge for their sister's death by killing the drug dealers in New Orleans. The police enlist the help of a biker warrior to solve the crime. The head drug dealer stirs the pot even further by hiring Cajun warriors to kill those he believes are responsible for the deaths of his dealers.
# ID de la película: tt0109536
# Datos extraídos: ('Peligroso', '4,0', 'Rod Hewitt, David Winters', 'Rod Hewitt', "Brother and sister Ninja warriors get revenge for their sister's death by killing the drug dealers in New Orleans. The police enlist the help of a biker warrior to solve the crime. The head drug dealer stirs the pot even further by hiring Cajun warriors to kill those he believes are responsible for the deaths of his dealers.", 'tt0109536')
# Accediendo a la película con ID tt0109400
# Nombre de la película: El misterioso fantasma de un niño muy normalito
# Puntuación de IMDb: 4,7
# Directores: Anthony Edwards
# Guionistas: Lance W. Dreesen, Clint Hutchison, Mark Twain
# Argumento: An archeologist finds remains of a famous explorer and moves them to a museum. This causes the spirit of the explorer to become restless. He wants his bones properly buried and returns as ghost to seek help from the archeologist's son.
# ID de la película: tt0109400
# Datos extraídos: ('El misterioso fantasma de un niño muy normalito', '4,7', 'Anthony Edwards', 'Lance W. Dreesen, Clint Hutchison, Mark Twain', "An archeologist finds remains of a famous explorer and moves them to a museum. This causes the spirit of the explorer to become restless. He wants his bones properly buried and returns as ghost to seek help from the archeologist's son.", 'tt0109400')
# Accediendo a la película con ID tt0109746
# Nombre de la película: Esti Kornél csodálatos utazása
# Puntuación de IMDb: 7,0
# Directores: József Pacskovszky
# Guionistas: Dezsö Kosztolányi, János Matúz, József Pacskovszky
# Argumento: A middle-aged writer (Kornél Esti) travels to Germany to deliver a lecture. During the long journey he recalls the memories of another journey he made 30 years before.
# ID de la película: tt0109746
# Datos extraídos: ('Esti Kornél csodálatos utazása', '7,0', 'József Pacskovszky', 'Dezsö Kosztolányi, János Matúz, József Pacskovszky', 'A middle-aged writer (Kornél Esti) travels to Germany to deliver a lecture. During the long journey he recalls the memories of another journey he made 30 years before.', 'tt0109746')
# Accediendo a la película con ID tt0109905
# Nombre de la película: El policía gladiador
# Puntuación de IMDb: 3,1
# Directores: Nick Rotundo
# Guionistas: Nick Rotundo, Paco Alvarez, Nicolas Stiliadis
# Argumento: Alexander the Great's sword is stolen from a museum as it holds special powers for the reincarnation of Alex. Illegal gladiator style duels are held around NYC. The cop investigating has visions of these fights.
# ID de la película: tt0109905
# Datos extraídos: ('El policía gladiador', '3,1', 'Nick Rotundo', 'Nick Rotundo, Paco Alvarez, Nicolas Stiliadis', "Alexander the Great's sword is stolen from a museum as it holds special powers for the reincarnation of Alex. Illegal gladiator style duels are held around NYC. The cop investigating has visions of these fights.", 'tt0109905')
# Accediendo a la película con ID tt0110252
# Nombre de la película: Keïta! L'héritage du griot
# Puntuación de IMDb: 6,4
# Directores: Dani Kouyaté
# Guionistas: Dani Kouyaté
# Argumento: A storyteller named Djeliba comes to the town of a young boy named Mabo with promises that he will reveal the origin of the boy's ancestry.
# ID de la película: tt0110252
# Datos extraídos: ("Keïta! L'héritage du griot", '6,4', 'Dani Kouyaté', 'Dani Kouyaté', "A storyteller named Djeliba comes to the town of a young boy named Mabo with promises that he will reveal the origin of the boy's ancestry.", 'tt0110252')
# Accediendo a la película con ID tt0110826
# Nombre de la película: The Phoenix and the Magic Carpet
# Puntuación de IMDb: 4,9
# Directores: Zoran Perisic
# Guionistas: Florence Fox, E. Nesbit
# Argumento: The story follows 3 American kids who find a golden egg in their grandfather's cottage in England. When the egg falls into a bonfire, a Phoenix emerges and takes the children on a magic carpet to a fantastical land.
# ID de la película: tt0110826
# Datos extraídos: ('The Phoenix and the Magic Carpet', '4,9', 'Zoran Perisic', 'Florence Fox, E. Nesbit', "The story follows 3 American kids who find a golden egg in their grandfather's cottage in England. When the egg falls into a bonfire, a Phoenix emerges and takes the children on a magic carpet to a fantastical land.", 'tt0110826')
# Accediendo a la película con ID tt0111359
# Nombre de la película: Un cuento: El mito de Pecos Bill
# Puntuación de IMDb: 5,9
# Directores: Jeremiah S. Chechik
# Guionistas: Steve Bloom, Robert Rodat
# Argumento: A young boy's imagination summons cowboy legend Pecos Bill, who helps him save the family farm from a greedy land-grabber. With the help of a lumberjack and a railroad worker, they all embark on a surprise-filled adventure.
# ID de la película: tt0111359
# Datos extraídos: ('Un cuento: El mito de Pecos Bill', '5,9', 'Jeremiah S. Chechik', 'Steve Bloom, Robert Rodat', "A young boy's imagination summons cowboy legend Pecos Bill, who helps him save the family farm from a greedy land-grabber. With the help of a lumberjack and a railroad worker, they all embark on a surprise-filled adventure.", 'tt0111359')
# Accediendo a la película con ID tt0109546
# Nombre de la película: Tentación
# Puntuación de IMDb: 4,2
# Directores: Lawrence Lanoff
# Guionistas: Melissa Mitchell
# Argumento: Karin Swann brings a statue home from her travels to Asia and it soon begins to have a strange effect on her. She has an insatiable sexual appetite and develops strange fetishes such as pain and death. She soon gets out of control and only her boyfriend Matt Christianson has the power in his love to exorcise the demon spirits from Karin's body.
# ID de la película: tt0109546
# Datos extraídos: ('Tentación', '4,2', 'Lawrence Lanoff', 'Melissa Mitchell', "Karin Swann brings a statue home from her travels to Asia and it soon begins to have a strange effect on her. She has an insatiable sexual appetite and develops strange fetishes such as pain and death. She soon gets out of control and only her boyfriend Matt Christianson has the power in his love to exorcise the demon spirits from Karin's body.", 'tt0109546')
# Accediendo a la película con ID tt0109415
# Nombre de la película: Los chicos del maíz 3: La cosecha urbana
# Puntuación de IMDb: 4,3
# Directores: James D.R. Hickox
# Guionistas: Dode B. Levenson, Stephen King, Matt Greenberg
# Argumento: Dos sobrevivientes de eventos anteriores son adoptados por una familia de Chicago. En la gran ciudad, intentan adaptarse, pero uno de ellos es en realidad un emisario del mal y pronto comienza una nueva cosecha.
# ID de la película: tt0109415
# Datos extraídos: ('Los chicos del maíz 3: La cosecha urbana', '4,3', 'James D.R. Hickox', 'Dode B. Levenson, Stephen King, Matt Greenberg', 'Dos sobrevivientes de eventos anteriores son adoptados por una familia de Chicago. En la gran ciudad, intentan adaptarse, pero uno de ellos es en realidad un emisario del mal y pronto comienza una nueva cosecha.', 'tt0109415')
# Accediendo a la película con ID tt0109723
# Nombre de la película: El abrazo del vampiro
# Puntuación de IMDb: 4,4
# Directores: Anne Goursaud
# Guionistas: Halle Eaton, Nicole Coady, Rick Bitzelberger
# Argumento: Una estudiante de primer año de la universidad, es seducida por un apuesto vampiro que la introduce en un oscuro mundo de deseos carnales.
# ID de la película: tt0109723
# Datos extraídos: ('El abrazo del vampiro', '4,4', 'Anne Goursaud', 'Halle Eaton, Nicole Coady, Rick Bitzelberger', 'Una estudiante de primer año de la universidad, es seducida por un apuesto vampiro que la introduce en un oscuro mundo de deseos carnales.', 'tt0109723')
# Accediendo a la película con ID tt0110604
# Nombre de la película: Testigo mudo
# Puntuación de IMDb: 6,7
# Directores: Anthony Waller
# Guionistas: Anthony Waller
# Argumento: Una maquilladora estadounidense se encuentra en Moscú en el rodaje de una cinta de serie B. Un día, al terminar el rodaje se queda encerrada en los estudios y contempla el asesinato de una mujer que es protagonista de una "snuff movie".
# ID de la película: tt0110604
# Datos extraídos: ('Testigo mudo', '6,7', 'Anthony Waller', 'Anthony Waller', 'Una maquilladora estadounidense se encuentra en Moscú en el rodaje de una cinta de serie B. Un día, al terminar el rodaje se queda encerrada en los estudios y contempla el asesinato de una mujer que es protagonista de una "snuff movie".', 'tt0110604')
# Accediendo a la película con ID tt0111574
# Nombre de la película: The Upstairs Neighbour
# Puntuación de IMDb: 6,6
# Directores: James Merendino
# Guionistas: James Merendino
# Argumento: Pulp novelist Eric lives in a bad neighborhood, and the guy upstairs annoys him with his noise. Gradually this escalates to pranksters phone calls and wire tapping which ticks off Eric's already unstable, nervous and paranoid personality.
# ID de la película: tt0111574
# Datos extraídos: ('The Upstairs Neighbour', '6,6', 'James Merendino', 'James Merendino', "Pulp novelist Eric lives in a bad neighborhood, and the guy upstairs annoys him with his noise. Gradually this escalates to pranksters phone calls and wire tapping which ticks off Eric's already unstable, nervous and paranoid personality.", 'tt0111574')
# Accediendo a la película con ID tt0111464
# Nombre de la película: Jugando a morir
# Puntuación de IMDb: 3,5
# Directores: James Merendino
# Guionistas: Megan Heath, James Merendino
# Argumento: Traumatized after witnessing her jealous husband kill her adulterous lover and then himself, an unbalanced, nymphomaniac young woman finds herself stalked by an unknown assailant, but she cannot make anyone believe her desperate situation.
# ID de la película: tt0111464
# Datos extraídos: ('Jugando a morir', '3,5', 'James Merendino', 'Megan Heath, James Merendino', 'Traumatized after witnessing her jealous husband kill her adulterous lover and then himself, an unbalanced, nymphomaniac young woman finds herself stalked by an unknown assailant, but she cannot make anyone believe her desperate situation.', 'tt0111464')
# Accediendo a la película con ID tt0111244
# Nombre de la película: Satánica, todo el mal en ella
# Puntuación de IMDb: 4,1
# Directores: Jim Wynorski
# Guionistas: Mark Thomas McGee
# Argumento: Jealous witch Erica uses her powers to influence her unwitting husband Larry and his colleagues, who all work for a big law firm.
# ID de la película: tt0111244
# Datos extraídos: ('Satánica, todo el mal en ella', '4,1', 'Jim Wynorski', 'Mark Thomas McGee', 'Jealous witch Erica uses her powers to influence her unwitting husband Larry and his colleagues, who all work for a big law firm.', 'tt0111244')
# Accediendo a la película con ID tt0109028
# Nombre de la película: Fiebre helada
# Puntuación de IMDb: 7,0
# Directores: Friðrik Þór Friðriksson
# Guionistas: Friðrik Þór Friðriksson, Jim Stark
# Argumento: A Japanese businessman travels to Iceland and has a series of misadventures while venturing to a remote area to perform a traditional burial ritual where his parents died several years back.
# ID de la película: tt0109028
# Datos extraídos: ('Fiebre helada', '7,0', 'Friðrik Þór Friðriksson', 'Friðrik Þór Friðriksson, Jim Stark', 'A Japanese businessman travels to Iceland and has a series of misadventures while venturing to a remote area to perform a traditional burial ritual where his parents died several years back.', 'tt0109028')
# Accediendo a la película con ID tt0109642
# Nombre de la película: Eclipse total (Dolores Claiborne)
# Puntuación de IMDb: 7,4
# Directores: Taylor Hackford
# Guionistas: Stephen King, Tony Gilroy
# Argumento: Una periodista de una gran ciudad viaja a un pequeño pueblo en el que su madre ha sido detenida por el asesinato de una anciana para la que trabaja como sirvienta.
# ID de la película: tt0109642
# Datos extraídos: ('Eclipse total (Dolores Claiborne)', '7,4', 'Taylor Hackford', 'Stephen King, Tony Gilroy', 'Una periodista de una gran ciudad viaja a un pequeño pueblo en el que su madre ha sido detenida por el asesinato de una anciana para la que trabaja como sirvienta.', 'tt0109642')
# Accediendo a la película con ID tt0110217
# Nombre de la película: Jupiter's Wife
# Puntuación de IMDb: 7,1
# Directores: Michel Negroponte
# Guionistas: Gabriel Morgan, Michel Negroponte
# Argumento: Michel Negroponte, a documentary filmmaker, meets Maggie one day in Central Park. Maggie claims to be married to the god Jupiter and the daughter of actor Robert Ryan. Michel gets to know Maggie over the next couple of years, and attempts to use her often outlandish stories as clues to reconstruct her past.
# ID de la película: tt0110217
# Datos extraídos: ("Jupiter's Wife", '7,1', 'Michel Negroponte', 'Gabriel Morgan, Michel Negroponte', 'Michel Negroponte, a documentary filmmaker, meets Maggie one day in Central Park. Maggie claims to be married to the god Jupiter and the daughter of actor Robert Ryan. Michel gets to know Maggie over the next couple of years, and attempts to use her often outlandish stories as clues to reconstruct her past.', 'tt0110217')
# Accediendo a la película con ID tt0111151
# Nombre de la película: Mad Dogs and Englishmen
# Puntuación de IMDb: 3,9
# Directores: Henry Cole
# Guionistas: Tim Sewell, Henry Cole
# Argumento: Antonia is a cute drug addict in London, who meets a nice motorbike courier. They get caught between a corrupt drug cop and a drug dealer.
# ID de la película: tt0111151
# Datos extraídos: ('Mad Dogs and Englishmen', '3,9', 'Henry Cole', 'Tim Sewell, Henry Cole', 'Antonia is a cute drug addict in London, who meets a nice motorbike courier. They get caught between a corrupt drug cop and a drug dealer.', 'tt0111151')
# Accediendo a la película con ID tt0111269
# Nombre de la película: Die Knickerbocker-Bande: Das sprechende Grab
# Puntuación de IMDb: 4,7
# Directores: Marijan David Vajda
# Guionistas: Thomas Brezina, Milan Dor
# Argumento: Get set for the adventure of a lifetime when a "dare" leads four curious kids into a hair-raising investigation. While four friends meet at an old cemetery, they stumble over the grave of a famous magician. Things soon turn spooky as they're haunted by a cloaked stranger and mysterious voices begin erupting from the magician's grave. When they discover a magnificent s... Leer todo
# ID de la película: tt0111269
# Datos extraídos: ('Die Knickerbocker-Bande: Das sprechende Grab', '4,7', 'Marijan David Vajda', 'Thomas Brezina, Milan Dor', 'Get set for the adventure of a lifetime when a "dare" leads four curious kids into a hair-raising investigation. While four friends meet at an old cemetery, they stumble over the grave of a famous magician. Things soon turn spooky as they\'re haunted by a cloaked stranger and mysterious voices begin erupting from the magician\'s grave. When they discover a magnificent s... Leer todo', 'tt0111269')
# Accediendo a la película con ID tt0109363
# Nombre de la película: Seeking the Cafe Bob
# Puntuación de IMDb: 7,2
# Directores: Jeff Stolhand
# Guionistas: Jeff Stolhand
# Argumento:
# ID de la película: tt0109363
# Datos extraídos: ('Seeking the Cafe Bob', '7,2', 'Jeff Stolhand', 'Jeff Stolhand', '', 'tt0109363')
# Accediendo a la película con ID tt0109489
# Nombre de la película: Costa Brava
# Puntuación de IMDb: 6,3
# Directores: Marta Balletbò-Coll
# Guionistas: Marta Balletbò-Coll, Ana Simón Cerezo
# Argumento: In Barcelona, Anna is a tour guide working on her monologue, in which she's a Communist housewife whose lesbian neighbor is an object of curiosity. She's sent an audition tape to San Francisco's Another Stage. While giving a tour, she meets Montserrat, American, Jewish, teaching in Barcelona and unhappy with her job. Montserrat, claiming "I'm not a lesbian," approache... Leer todo
# ID de la película: tt0109489
# Datos extraídos: ('Costa Brava', '6,3', 'Marta Balletbò-Coll', 'Marta Balletbò-Coll, Ana Simón Cerezo', 'In Barcelona, Anna is a tour guide working on her monologue, in which she\'s a Communist housewife whose lesbian neighbor is an object of curiosity. She\'s sent an audition tape to San Francisco\'s Another Stage. While giving a tour, she meets Montserrat, American, Jewish, teaching in Barcelona and unhappy with her job. Montserrat, claiming "I\'m not a lesbian," approache... Leer todo', 'tt0109489')
# Accediendo a la película con ID tt0095102
# Nombre de la película: Les ennemis de la mafia
# Puntuación de IMDb: 7,6
# Directores: Sin Ming Ko
# Guionistas: Wai-Yee Fong, Kwong-Yam Yip
# Argumento:
# ID de la película: tt0095102
# Datos extraídos: ('Les ennemis de la mafia', '7,6', 'Sin Ming Ko', 'Wai-Yee Fong, Kwong-Yam Yip', '', 'tt0095102')
# Accediendo a la película con ID tt0109034
# Nombre de la película: Libre de sospecha
# Puntuación de IMDb: 6,7
# Directores: Steven Schachter
# Guionistas: Jerry Lazarus, William H. Macy, Steven Schachter
# Argumento: A paralyzed cop struggles with his life following a failed special operation and gets depressed. His wife and brother try to get him out of that state which causes a series of unpredictable events.
# ID de la película: tt0109034
# Datos extraídos: ('Libre de sospecha', '6,7', 'Steven Schachter', 'Jerry Lazarus, William H. Macy, Steven Schachter', 'A paralyzed cop struggles with his life following a failed special operation and gets depressed. His wife and brother try to get him out of that state which causes a series of unpredictable events.', 'tt0109034')
# Accediendo a la película con ID tt0109532
# Nombre de la película: Indiscrección peligrosa
# Puntuación de IMDb: 4,7
# Directores: Richard Kletter
# Guionistas: Jack Tarpon, Richard Kletter
# Argumento: Una noche, el ejecutivo publicitario Jim (C. Thomas Howell) tiene una aventura con una mujer. Por desgracia para él, ella es Caroline Everett (Joan Severance), la esposa del rico, poderoso y vengativo Roger Everett (Malcolm McDowell)
# ID de la película: tt0109532
# Datos extraídos: ('Indiscrección peligrosa', '4,7', 'Richard Kletter', 'Jack Tarpon, Richard Kletter', 'Una noche, el ejecutivo publicitario Jim (C. Thomas Howell) tiene una aventura con una mujer. Por desgracia para él, ella es Caroline Everett (Joan Severance), la esposa del rico, poderoso y vengativo Roger Everett (Malcolm McDowell)', 'tt0109532')
# Accediendo a la película con ID tt0099840
# Nombre de la película: In the Shadow of the Sandcastles
# Puntuación de IMDb: 5,5
# Directores: Philippe Blot
# Guionistas: Philippe Blot
# Argumento: The ex-cop Robin kills an actor and steals his money and cocaine. And now he is supposed to find the killer together with an interpol inspector. To hide his guilt Robin goes on murdering leaving hints that lead to the actress Angel...
# ID de la película: tt0099840
# Datos extraídos: ('In the Shadow of the Sandcastles', '5,5', 'Philippe Blot', 'Philippe Blot', 'The ex-cop Robin kills an actor and steals his money and cocaine. And now he is supposed to find the killer together with an interpol inspector. To hide his guilt Robin goes on murdering leaving hints that lead to the actress Angel...', 'tt0099840')
# Accediendo a la película con ID tt0103655
# Nombre de la película: Almost Blue
# Puntuación de IMDb: 4,8
# Directores: Keoni Waxman
# Guionistas: Keoni Waxman
# Argumento: The young jazz saxophonist Morris Poole is at the height of his career. When his wife dies he is almost overcome by grief and blames himself. When after a while he finds a new love, he ends up in a situation that reminds him of his wife's mysterious death.
# ID de la película: tt0103655
# Datos extraídos: ('Almost Blue', '4,8', 'Keoni Waxman', 'Keoni Waxman', "The young jazz saxophonist Morris Poole is at the height of his career. When his wife dies he is almost overcome by grief and blames himself. When after a while he finds a new love, he ends up in a situation that reminds him of his wife's mysterious death.", 'tt0103655')
# Accediendo a la película con ID tt0106322
# Nombre de la película: Augustitango
# Puntuación de IMDb: 4,4
# Directores: Lennart Svensson
# Guionistas: Lennart Svensson
# Argumento: About a relationship between a young man and a mature woman.
# ID de la película: tt0106322
# Datos extraídos: ('Augustitango', '4,4', 'Lennart Svensson', 'Lennart Svensson', 'About a relationship between a young man and a mature woman.', 'tt0106322')
# Accediendo a la película con ID tt0106621
# Nombre de la película: Marcada por el recuerdo
# Puntuación de IMDb: 6,8
# Directores: Avery Crounse
# Guionistas: Avery Crounse
# Argumento: After a hurricane reeks havoc on Sister Island, Mississippi, rescue parties find a young girl on the shore. The girl is alive and soon opens her eyes, but she is non responsive. Dorrie takes her to her mother's home and goes back to the island to look for family. Although there were only 30 people on the island, none of the survivors claim to know her. Weeks go by and... Leer todo
# ID de la película: tt0106621
# Datos extraídos: ('Marcada por el recuerdo', '6,8', 'Avery Crounse', 'Avery Crounse', "After a hurricane reeks havoc on Sister Island, Mississippi, rescue parties find a young girl on the shore. The girl is alive and soon opens her eyes, but she is non responsive. Dorrie takes her to her mother's home and goes back to the island to look for family. Although there were only 30 people on the island, none of the survivors claim to know her. Weeks go by and... Leer todo", 'tt0106621')
# Accediendo a la película con ID tt0106421
# Nombre de la película: Burakku jakku
# Puntuación de IMDb: 6,7
# Directores: Osamu Dezaki
# Guionistas: Osamu Dezaki, Udo Lindenberg, Eto Mori
# Argumento: The adventures of the unlicensed but genius doctor Black Jack, who encounters extraordinary people and phenomena as he attends to unusual medical cases.
# ID de la película: tt0106421
# Datos extraídos: ('Burakku jakku', '6,7', 'Osamu Dezaki', 'Osamu Dezaki, Udo Lindenberg, Eto Mori', 'The adventures of the unlicensed but genius doctor Black Jack, who encounters extraordinary people and phenomena as he attends to unusual medical cases.', 'tt0106421')
# Accediendo a la película con ID tt0107025
# Nombre de la película: God's Lonely Man
# Puntuación de IMDb: 6,4
# Directores: Francis von Zerneck
# Guionistas: Francis von Zerneck
# Argumento: As each relentless night turns towards day, Ernest Rackman turns towards violence to escape thoughts of loneliness and suicide. Then he poses as a police officer and rescues a young girl from her parent's apartment, where she was forced into a compromising life. Having discharged his violence, he plans to move forward with this new relationship, but the demons of lone... Leer todo
# ID de la película: tt0107025
# Datos extraídos: ("God's Lonely Man", '6,4', 'Francis von Zerneck', 'Francis von Zerneck', "As each relentless night turns towards day, Ernest Rackman turns towards violence to escape thoughts of loneliness and suicide. Then he poses as a police officer and rescues a young girl from her parent's apartment, where she was forced into a compromising life. Having discharged his violence, he plans to move forward with this new relationship, but the demons of lone... Leer todo", 'tt0107025')
# Accediendo a la película con ID tt0109239
# Nombre de la película: Belyy prazdnik
# Puntuación de IMDb: 7,3
# Directores: Vladimir Naumov
# Guionistas: Tonino Guerra, Vladimir Naumov
# Argumento: Knowing that he will soon pass on, elderly Valentin Grack hires private detective Stanislav to follow him around for an entire day and write down everything that he does. It is a cold day and during Grack's travels he encounters a younger woman who addresses him as professor. He then meets a prostitute who turns out to be his daughter, and finally he meets an old woma... Leer todo
# ID de la película: tt0109239
# Datos extraídos: ('Belyy prazdnik', '7,3', 'Vladimir Naumov', 'Tonino Guerra, Vladimir Naumov', "Knowing that he will soon pass on, elderly Valentin Grack hires private detective Stanislav to follow him around for an entire day and write down everything that he does. It is a cold day and during Grack's travels he encounters a younger woman who addresses him as professor. He then meets a prostitute who turns out to be his daughter, and finally he meets an old woma... Leer todo", 'tt0109239')
# Accediendo a la película con ID tt0110028
# Nombre de la película: Highway of Heartache
# Puntuación de IMDb: 8,0
# Directores: Gregory Wild
# Guionistas: Gregory Wild
# Argumento:
# ID de la película: tt0110028
# Datos extraídos: ('Highway of Heartache', '8,0', 'Gregory Wild', 'Gregory Wild', '', 'tt0110028')
# Accediendo a la película con ID tt0110294
# Nombre de la película: Ladri di cinema
# Puntuación de IMDb: 6,6
# Directores: Piero Natoli
# Guionistas: Piero Natoli
# Argumento: The story of an Italian director who cannot break through and blames Hollywood.
# ID de la película: tt0110294
# Datos extraídos: ('Ladri di cinema', '6,6', 'Piero Natoli', 'Piero Natoli', 'The story of an Italian director who cannot break through and blames Hollywood.', 'tt0110294')
# Accediendo a la película con ID tt0110910
# Nombre de la película: Pterodactyl Woman from Beverly Hills
# Puntuación de IMDb: 4,6
# Directores: Philippe Mora
# Guionistas: Philippe Mora
# Argumento: Pixie is cursed with turning into a Pterodactyl when her husband is caught messing with bones on an ancient burial ground. Her husband, children, friends, and neighbours must come to terms with Pixie's new "look". Her only chance to return to her normal state is to find the shaman who inflicted the curse on her.
# ID de la película: tt0110910
# Datos extraídos: ('Pterodactyl Woman from Beverly Hills', '4,6', 'Philippe Mora', 'Philippe Mora', 'Pixie is cursed with turning into a Pterodactyl when her husband is caught messing with bones on an ancient burial ground. Her husband, children, friends, and neighbours must come to terms with Pixie\'s new "look". Her only chance to return to her normal state is to find the shaman who inflicted the curse on her.', 'tt0110910')
# Accediendo a la película con ID tt0110463
# Nombre de la película: Mo him wong
# Puntuación de IMDb: 5,7
# Directores: Siu-Tung Ching
# Guionistas: Wai-Lun Lam, Sandy Shaw, Cheuk-Hon Szeto
# Argumento: A serial adventure writer with problems in his personal life lives out the adventures of his literary hero, King of Adventurers.
# ID de la película: tt0110463
# Datos extraídos: ('Mo him wong', '5,7', 'Siu-Tung Ching', 'Wai-Lun Lam, Sandy Shaw, Cheuk-Hon Szeto', 'A serial adventure writer with problems in his personal life lives out the adventures of his literary hero, King of Adventurers.', 'tt0110463')
# Accediendo a la película con ID tt0111678
# Nombre de la película: The Wedding Tape
# Puntuación de IMDb: No disponible
# Directores: John Behnke
# Guionistas: John Behnke, Rob Humphrey, Jim Peterson
# Argumento:
# ID de la película: tt0111678
# Datos extraídos: ('The Wedding Tape', 'No disponible', 'John Behnke', 'John Behnke, Rob Humphrey, Jim Peterson', '', 'tt0111678')
# Accediendo a la película con ID tt0111129
# Nombre de la película: La serva amorosa
# Puntuación de IMDb: 6,7
# Directores: Jean Douchet
# Guionistas: Carlo Goldoni
# Argumento: Coraline, a young servant in love with Florindo, will thwart the plans of Beatrice, the second wife of Ottavio, father of Florindo, who wants to capture the legacy of Florindo for his own advantage and that of his own son.
# ID de la película: tt0111129
# Datos extraídos: ('La serva amorosa', '6,7', 'Jean Douchet', 'Carlo Goldoni', 'Coraline, a young servant in love with Florindo, will thwart the plans of Beatrice, the second wife of Ottavio, father of Florindo, who wants to capture the legacy of Florindo for his own advantage and that of his own son.', 'tt0111129')
# Accediendo a la película con ID tt0112526
# Nombre de la película: Blondes Have More Guns
# Puntuación de IMDb: 4,5
# Directores: George Merriweather
# Guionistas: Dan Goodman, Mary Guthrie, George Merriweather
# Argumento: A bumbling detective, along with his loyal sidekick and a man in a dog suit, tracks down a sultry chainsaw murderess!
# ID de la película: tt0112526
# Datos extraídos: ('Blondes Have More Guns', '4,5', 'George Merriweather', 'Dan Goodman, Mary Guthrie, George Merriweather', 'A bumbling detective, along with his loyal sidekick and a man in a dog suit, tracks down a sultry chainsaw murderess!', 'tt0112526')
# Accediendo a la película con ID tt0112803
# Nombre de la película: The Darien Gap
# Puntuación de IMDb: 6,6
# Directores: Brad Anderson
# Guionistas: Brad Anderson
# Argumento: A young man hitchhikes through Central America until he is faced with crossing an 80-mile gigantic swamp called the Darien Gap. This comedy adventure from Brad Anderson was a Grand Jury Prize nominee at Sundance.
# ID de la película: tt0112803
# Datos extraídos: ('The Darien Gap', '6,6', 'Brad Anderson', 'Brad Anderson', 'A young man hitchhikes through Central America until he is faced with crossing an 80-mile gigantic swamp called the Darien Gap. This comedy adventure from Brad Anderson was a Grand Jury Prize nominee at Sundance.', 'tt0112803')
# Accediendo a la película con ID tt0113035
# Nombre de la película: Ein fast perfekter Seitensprung
# Puntuación de IMDb: 6,2
# Directores: Reinhard Schwabenitzky
# Guionistas: Reinhard Schwabenitzky
# Argumento: Henny, a self-confident dressmaker, lives with her quirky parents in a village near Cuxhaven. She is involved with Martin, the son of the aristocratic family who owns the local shipyard.
# ID de la película: tt0113035
# Datos extraídos: ('Ein fast perfekter Seitensprung', '6,2', 'Reinhard Schwabenitzky', 'Reinhard Schwabenitzky', 'Henny, a self-confident dressmaker, lives with her quirky parents in a village near Cuxhaven. She is involved with Martin, the son of the aristocratic family who owns the local shipyard.', 'tt0113035')
# Accediendo a la película con ID tt0112946
# Nombre de la película: Eliksir
# Puntuación de IMDb: 6,6
# Directores: Irina Evteeva
# Guionistas: Irina Evteeva
# Argumento: Loosely based on tales by E. T. A. Hoffman. In a wonderland inhabited by fiery salamanders and winged spirits, good fights evil in search of a life-giving talisman whose finder will rule the world.
# ID de la película: tt0112946
# Datos extraídos: ('Eliksir', '6,6', 'Irina Evteeva', 'Irina Evteeva', 'Loosely based on tales by E. T. A. Hoffman. In a wonderland inhabited by fiery salamanders and winged spirits, good fights evil in search of a life-giving talisman whose finder will rule the world.', 'tt0112946')
# Accediendo a la película con ID tt0112923
# Nombre de la película: Eno nakano bokuno mura
# Puntuación de IMDb: 6,9
# Directores: Yôichi Higashi
# Guionistas: Yôichi Higashi, Takehiro Nakajima, Seizo Tashima
# Argumento: Tells of the childhood of nine-year-old twins in a rural village in Japan after World War 2. Includes the boys' relationships with their schoolteacher mother, civil servant father, elderly landlord, a rough new boy at the school, and three mysterious spirits in the form of old women.
# ID de la película: tt0112923
# Datos extraídos: ('Eno nakano bokuno mura', '6,9', 'Yôichi Higashi', 'Yôichi Higashi, Takehiro Nakajima, Seizo Tashima', "Tells of the childhood of nine-year-old twins in a rural village in Japan after World War 2. Includes the boys' relationships with their schoolteacher mother, civil servant father, elderly landlord, a rough new boy at the school, and three mysterious spirits in the form of old women.", 'tt0112923')
# Accediendo a la película con ID tt0112908
# Nombre de la película: Drzewa
# Puntuación de IMDb: 2,5
# Directores: Grzegorz Królikiewicz
# Guionistas: Jerzy Jankowski, Grzegorz Królikiewicz
# Argumento: Ecological horror about the relationship between humans and plants. A 40-year-old biologist conducts unusual experiments. The plants she grows experience physical pain and anxiety.
# ID de la película: tt0112908
# Datos extraídos: ('Drzewa', '2,5', 'Grzegorz Królikiewicz', 'Jerzy Jankowski, Grzegorz Królikiewicz', 'Ecological horror about the relationship between humans and plants. A 40-year-old biologist conducts unusual experiments. The plants she grows experience physical pain and anxiety.', 'tt0112908')
# Accediendo a la película con ID tt0113981
# Nombre de la película: Cazador de medianoche
# Puntuación de IMDb: 3,9
# Directores: Rick Jacobson
# Guionistas: William C. Martell
# Argumento: El cazavampiros Jack Cutter se apresura contra el tiempo para aniquilar a los últimos chupasangres antes de un evento catastrófico. Don "The Dragon" Wilson protagoniza este trepidante thriller de acción.
# ID de la película: tt0113981
# Datos extraídos: ('Cazador de medianoche', '3,9', 'Rick Jacobson', 'William C. Martell', 'El cazavampiros Jack Cutter se apresura contra el tiempo para aniquilar a los últimos chupasangres antes de un evento catastrófico. Don "The Dragon" Wilson protagoniza este trepidante thriller de acción.', 'tt0113981')
# Accediendo a la película con ID tt0114485
# Nombre de la película: Sobrenatural
# Puntuación de IMDb: 6,3
# Directores: Daniel Gruener
# Guionistas: Gabriel González Meléndez, Daniel Gruener
# Argumento: A woman sees her best friend murdered before her eyes, and thus becomes very traumatised. Her husband tells her to stay at home, where she discovers a little gris-gris bag. She opens the bag, without knowing its magical origin, and smells a powder. She begins investigating and discovers a strange address: "Academia #10". She then goes there and meets a witch, who warn... Leer todo
# ID de la película: tt0114485
# Datos extraídos: ('Sobrenatural', '6,3', 'Daniel Gruener', 'Gabriel González Meléndez, Daniel Gruener', 'A woman sees her best friend murdered before her eyes, and thus becomes very traumatised. Her husband tells her to stay at home, where she discovers a little gris-gris bag. She opens the bag, without knowing its magical origin, and smells a powder. She begins investigating and discovers a strange address: "Academia #10". She then goes there and meets a witch, who warn... Leer todo', 'tt0114485')
# Accediendo a la película con ID tt0111305
# Nombre de la película: Sucesos distantes
# Puntuación de IMDb: 6,6
# Directores: Guita Schyfter
# Guionistas: Hugo Hiriart, Alejandro Lubezki
# Argumento: One couple (Carlos & Irene) are having troubles, because he suspects that Irene's hiding something about her past in Russia. To make things worst her ex-husband goes to Mexico and tells Carlos that her other ex-husband also is going to claim her as his property.
# ID de la película: tt0111305
# Datos extraídos: ('Sucesos distantes', '6,6', 'Guita Schyfter', 'Hugo Hiriart, Alejandro Lubezki', "One couple (Carlos & Irene) are having troubles, because he suspects that Irene's hiding something about her past in Russia. To make things worst her ex-husband goes to Mexico and tells Carlos that her other ex-husband also is going to claim her as his property.", 'tt0111305')
# Accediendo a la película con ID tt0112632
# Nombre de la película: Carlos Monzón, el segundo juicio
# Puntuación de IMDb: 5,0
# Directores: Gabriel Arbós
# Guionistas: Pamela Bisserier, Daniel Ginhson, Aníbal Uset
# Argumento: A recreation of the trial and several hypotheses of the death of the model Alicia Muñiz on February 14, 1988 in the city of Mar del Plata starring the world boxing champion Carlos Monzón as the main suspect of the crime.
# ID de la película: tt0112632
# Datos extraídos: ('Carlos Monzón, el segundo juicio', '5,0', 'Gabriel Arbós', 'Pamela Bisserier, Daniel Ginhson, Aníbal Uset', 'A recreation of the trial and several hypotheses of the death of the model Alicia Muñiz on February 14, 1988 in the city of Mar del Plata starring the world boxing champion Carlos Monzón as the main suspect of the crime.', 'tt0112632')
# Accediendo a la película con ID tt0113643
# Nombre de la película: Letters from the East
# Puntuación de IMDb: 6,7
# Directores: Andrew Grieve
# Guionistas: William Grieve
# Argumento: A woman returns to her native Estonia to unravel the complex mysteries of her family's past. Set in 1989, against the background of the Baltic territory's struggle for peace and independence from the Soviet Union.
# ID de la película: tt0113643
# Datos extraídos: ('Letters from the East', '6,7', 'Andrew Grieve', 'William Grieve', "A woman returns to her native Estonia to unravel the complex mysteries of her family's past. Set in 1989, against the background of the Baltic territory's struggle for peace and independence from the Soviet Union.", 'tt0113643')
# Accediendo a la película con ID tt0113591
# Nombre de la película: Labirintos
# Puntuación de IMDb: 4,6
# Directores: Mikael Dovlatyan
# Guionistas: Mikael Dovlatyan, E. Khald-Asoyan
# Argumento:
# ID de la película: tt0113591
# Datos extraídos: ('Labirintos', '4,6', 'Mikael Dovlatyan', 'Mikael Dovlatyan, E. Khald-Asoyan', '', 'tt0113591')
# Accediendo a la película con ID tt0113682
# Nombre de la película: Lago Ness
# Puntuación de IMDb: 5,5
# Directores: John Henderson
# Guionistas: John Fusco
# Argumento: El Dr. Dempsey, científico estadounidense que se ha convertido en un escéptico tras una desastrosa decisión equivocada, no está precisamente entusiasmado con ser enviado a Escocia para probar la existencia del monstruo del lago Ness.
# ID de la película: tt0113682
# Datos extraídos: ('Lago Ness', '5,5', 'John Henderson', 'John Fusco', 'El Dr. Dempsey, científico estadounidense que se ha convertido en un escéptico tras una desastrosa decisión equivocada, no está precisamente entusiasmado con ser enviado a Escocia para probar la existencia del monstruo del lago Ness.', 'tt0113682')
# Accediendo a la película con ID tt0114170
# Nombre de la película: Power 98
# Puntuación de IMDb: 4,5
# Directores: Jaime Hellman
# Guionistas: Jaime Hellman
# Argumento: Un polémico presentador de un programa de entrevistas se ve envuelto en el asesinato de una bella mujer en una guerra por los índices de audiencia.
# ID de la película: tt0114170
# ...
# ID de la película: tt0421237
# Datos extraídos: ('Royal Kill', '2,9', 'Bob Ahmed', 'Bob Ahmed', 'Mujer asesina recibe el encargo de matar al heredero himalayo en EE.UU. Un guardia real es enviado para salvaguardarlo. Cuando se conocen, ambos deben decidir entre el deber y algo más profundo que está surgiendo entre ellos.', 'tt0421237')
# Accediendo a la película con ID tt0293354
# Nombre de la película: The Magic Stone
# Puntuación de IMDb: 6,4
# Directores: Jowita Gondek
# Guionistas: Jowita Gondek, Bozenna 'Bo' Intrator
# Argumento:
# ID de la película: tt0293354
# Datos extraídos: ('The Magic Stone', '6,4', 'Jowita Gondek', "Jowita Gondek, Bozenna 'Bo' Intrator", '', 'tt0293354')
# Accediendo a la película con ID tt0374853
# Nombre de la película: Malice in Wonderland
# Puntuación de IMDb: 5,8
# Directores: Simon Fellows
# Guionistas: Jayson Rothwell
# Argumento: A modern take on the classic fairytale, Alice in Wonderland, set in the North East of England.
# ID de la película: tt0374853
# Datos extraídos: ('Malice in Wonderland', '5,8', 'Simon Fellows', 'Jayson Rothwell', 'A modern take on the classic fairytale, Alice in Wonderland, set in the North East of England.', 'tt0374853')
# Accediendo a la película con ID tt0380510
# Nombre de la película: The Lovely Bones
# Puntuación de IMDb: 6,6
# Directores: Peter Jackson
# Guionistas: Fran Walsh, Philippa Boyens, Peter Jackson
# Argumento: En torno a una niña que ha sido asesinada y cuida de su familia - al tiempo que observa a su asesino - des del purgatorio. Tendrá que encontrar el equilibrio entre su deseo de venganza y su deseo de reconfortar a su familia.
# ID de la película: tt0380510
# Datos extraídos: ('The Lovely Bones', '6,6', 'Peter Jackson', 'Fran Walsh, Philippa Boyens, Peter Jackson', 'En torno a una niña que ha sido asesinada y cuida de su familia - al tiempo que observa a su asesino - des del purgatorio. Tendrá que encontrar el equilibrio entre su deseo de venganza y su deseo de reconfortar a su familia.', 'tt0380510')
# Accediendo a la película con ID tt0386117
# Nombre de la película: Donde viven los monstruos
# Puntuación de IMDb: 6,7
# Directores: Spike Jonze
# Guionistas: Spike Jonze, Dave Eggers, Maurice Sendak
# Argumento: Una adaptación de la historia infantil clásica de Maurice Sendak, en la que Max, un niño pequeño y desobediente es enviado a la cama sin su cena, crea su propio mundo--un bosque habitado por feroces criaturas salvajes quienes coronan Max como su gobernante.Reseña anónima (Traducida por IMDb.es)
# ID de la película: tt0386117
# Datos extraídos: ('Donde viven los monstruos', '6,7', 'Spike Jonze', 'Spike Jonze, Dave Eggers, Maurice Sendak', 'Una adaptación de la historia infantil clásica de Maurice Sendak, en la que Max, un niño pequeño y desobediente es enviado a la cama sin su cena, crea su propio mundo--un bosque habitado por feroces criaturas salvajes quienes coronan Max como su gobernante.Reseña anónima (Traducida por IMDb.es)', 'tt0386117')
# Accediendo a la película con ID tt0289146
# Nombre de la película: T.M.A.
# Puntuación de IMDb: 4,7
# Directores: Juraj Herz
# Guionistas: Martin Nemec, Juraj Herz
# Argumento: A man leaves his busy city life for the peace of the country home where he spent his early childhood. His new life is soon disturbed by strange events.
# ID de la película: tt0289146
# Datos extraídos: ('T.M.A.', '4,7', 'Juraj Herz', 'Martin Nemec, Juraj Herz', 'A man leaves his busy city life for the peace of the country home where he spent his early childhood. His new life is soon disturbed by strange events.', 'tt0289146')
# Accediendo a la película con ID tt0353665
# Nombre de la película: El libro de piedra
# Puntuación de IMDb: 4,1
# Directores: Julio Cesar Estrada
# Guionistas: Julio Cesar Estrada, Gustavo Moheno, Enrique Renteria
# Argumento: Julieta is a young child psychologist hired by millionaire Eugenio Ruvalcaba, to work with his only daughter, Sylvia, who has severe emotional problems, while staying in their isolated island mansion. Once there, she finds out there's much more to Sylvia's imaginary friend than what everybody knows... and the results can be horrifying...
# ID de la película: tt0353665
# Datos extraídos: ('El libro de piedra', '4,1', 'Julio Cesar Estrada', 'Julio Cesar Estrada, Gustavo Moheno, Enrique Renteria', "Julieta is a young child psychologist hired by millionaire Eugenio Ruvalcaba, to work with his only daughter, Sylvia, who has severe emotional problems, while staying in their isolated island mansion. Once there, she finds out there's much more to Sylvia's imaginary friend than what everybody knows... and the results can be horrifying...", 'tt0353665')
# Accediendo a la película con ID tt0368563
# Nombre de la película: Posesión
# Puntuación de IMDb: 5,4
# Directores: Joel Bergvall, Simon Sandquist
# Guionistas: Michael Petroni, Won-mi Byun, Min-ho Song
# Argumento: Jess tiene la desgracia de ver cómo su marido y el hermano de éste caen en coma tras un accidente de coche. Cuando su cuñado despierta, le dice a ella que él es realmente su marido. Ella deberá entender qué es lo que realmente sucede.
# ID de la película: tt0368563
# Datos extraídos: ('Posesión', '5,4', 'Joel Bergvall, Simon Sandquist', 'Michael Petroni, Won-mi Byun, Min-ho Song', 'Jess tiene la desgracia de ver cómo su marido y el hermano de éste caen en coma tras un accidente de coche. Cuando su cuñado despierta, le dice a ella que él es realmente su marido. Ella deberá entender qué es lo que realmente sucede.', 'tt0368563')
# Accediendo a la película con ID tt0425141
# Nombre de la película: It Came from Trafalgar
# Puntuación de IMDb: 7,0
# Directores: Solomon Mortamur
# Guionistas: Solomon Mortamur
# Argumento:
# ID de la película: tt0425141
# Datos extraídos: ('It Came from Trafalgar', '7,0', 'Solomon Mortamur', 'Solomon Mortamur', '', 'tt0425141')
# Accediendo a la película con ID tt0431670
# Nombre de la película: Cabeza de pescado
# Puntuación de IMDb: 7,6
# Directores: July Massaccesi
# Guionistas: Fernando Barrientos, Edgardo Sosa
# Argumento:
# ID de la película: tt0431670
# Datos extraídos: ('Cabeza de pescado', '7,6', 'July Massaccesi', 'Fernando Barrientos, Edgardo Sosa', '', 'tt0431670')
# Accediendo a la película con ID tt0433362
# Nombre de la película: Daybreakers
# Puntuación de IMDb: 6,4
# Directores: Michael Spierig, Peter Spierig
# Guionistas: Michael Spierig, Peter Spierig
# Argumento: En 2019, una plaga ha convertido a casi todos en vampiros. Dado el poco suministro de sangre, la raza dominante planea su supervivencia; mientras, un investigador trabaja con un grupo de vampiros encubiertos para salvar a la humanidad.
# ID de la película: tt0433362
# Datos extraídos: ('Daybreakers', '6,4', 'Michael Spierig, Peter Spierig', 'Michael Spierig, Peter Spierig', 'En 2019, una plaga ha convertido a casi todos en vampiros. Dado el poco suministro de sangre, la raza dominante planea su supervivencia; mientras, un investigador trabaja con un grupo de vampiros encubiertos para salvar a la humanidad.', 'tt0433362')
# Accediendo a la película con ID tt0436154
# Nombre de la película: Cabras
# Puntuación de IMDb: No disponible
# Directores: Fredy Polania
# Guionistas: Fredy Polania
# Argumento: Twenty bands unite from around the world for one film. Twenty months of filming, struggles and peace. Twenty visions one director.
# ID de la película: tt0436154
# Datos extraídos: ('Cabras', 'No disponible', 'Fredy Polania', 'Fredy Polania', 'Twenty bands unite from around the world for one film. Twenty months of filming, struggles and peace. Twenty visions one director.', 'tt0436154')
# Accediendo a la película con ID tt0450336
# Nombre de la película: La masacre de Town Creek
# Puntuación de IMDb: 5,3
# Directores: Joel Schumacher
# Guionistas: David Kajganich
# Argumento: Un hombre y su hermano en una misión de venganza quedan atrapados en un terrible experimento sobrenatural que data del Tercer Reich.
# ID de la película: tt0450336
# Datos extraídos: ('La masacre de Town Creek', '5,3', 'Joel Schumacher', 'David Kajganich', 'Un hombre y su hermano en una misión de venganza quedan atrapados en un terrible experimento sobrenatural que data del Tercer Reich.', 'tt0450336')
# Accediendo a la película con ID tt0121569
# Nombre de la película: Moonlight Blade
# Puntuación de IMDb: No disponible
# Directores: Arthur J. Mangano
# Guionistas: Arthur J. Mangano
# Argumento: A New York newspaperman tracks clues to his missing sister in a small unfriendly hillbilly town.
# ID de la película: tt0121569
# Datos extraídos: ('Moonlight Blade', 'No disponible', 'Arthur J. Mangano', 'Arthur J. Mangano', 'A New York newspaperman tracks clues to his missing sister in a small unfriendly hillbilly town.', 'tt0121569')
# Accediendo a la película con ID tt0381940
# Nombre de la película: Cargo
# Puntuación de IMDb: 6,1
# Directores: Ivan Engler, Ralph Etter
# Guionistas: Arnold Bucher, Ivan Engler, Patrik Steinmann
# Argumento: Dr. Laura P. takes a job on a cargo spaceship for 4 years plus 4 years back. She'll join her sister on Rhea. 44 months later, in Laura's shift, strange things happen in cargo. The crew is reanimated and the captain dies mysteriously.
# ID de la película: tt0381940
# Datos extraídos: ('Cargo', '6,1', 'Ivan Engler, Ralph Etter', 'Arnold Bucher, Ivan Engler, Patrik Steinmann', "Dr. Laura P. takes a job on a cargo spaceship for 4 years plus 4 years back. She'll join her sister on Rhea. 44 months later, in Laura's shift, strange things happen in cargo. The crew is reanimated and the captain dies mysteriously.", 'tt0381940')
# Accediendo a la película con ID tt0405022
# Nombre de la película: House of Boys
# Puntuación de IMDb: 6,5
# Directores: Jean-Claude Schlim
# Guionistas: Jean-Claude Schlim, Christian Thiry, Robert David Graham
# Argumento: Dos jóvenes almas gemelas se encuentran mientras trabajan en un club para hombres. Eventualmente, uno contrae el SIDA.
# ID de la película: tt0405022
# Datos extraídos: ('House of Boys', '6,5', 'Jean-Claude Schlim', 'Jean-Claude Schlim, Christian Thiry, Robert David Graham', 'Dos jóvenes almas gemelas se encuentran mientras trabajan en un club para hombres. Eventualmente, uno contrae el SIDA.', 'tt0405022')
# Accediendo a la película con ID tt0403702
# Nombre de la película: Rebelión adolescente
# Puntuación de IMDb: 6,4
# Directores: Miguel Arteta
# Guionistas: Gustin Nash, C.D. Payne
# Argumento: Mientras sus horribles padres se tambalean al borde del divorcio, Nick Twisp pone su mirada en la chica de sus sueños Sheeni Saunders, con la esperanza de que ella sea la que le quite la virginidad.
# ID de la película: tt0403702
# Datos extraídos: ('Rebelión adolescente', '6,4', 'Miguel Arteta', 'Gustin Nash, C.D. Payne', 'Mientras sus horribles padres se tambalean al borde del divorcio, Nick Twisp pone su mirada en la chica de sus sueños Sheeni Saunders, con la esperanza de que ella sea la que le quite la virginidad.', 'tt0403702')
# Accediendo a la película con ID tt0407852
# Nombre de la película: Utolsó jelentés Annáról
# Puntuación de IMDb: 6,6
# Directores: Márta Mészáros
# Guionistas: Márta Mészáros, Éva Pataki
# Argumento: This film is the first one since the political changes in Hungary to deal with the topic of informants. It vividly depicts the atmosphere of Hungarian society in the seventies. The protagonist is Peter, a literary critic, is tasked by the secret police to persuade Social Democratic politician, Anna Kethly, who has been living in exile for decades, to return home. Keth... Leer todo
# ID de la película: tt0407852
# Datos extraídos: ('Utolsó jelentés Annáról', '6,6', 'Márta Mészáros', 'Márta Mészáros, Éva Pataki', 'This film is the first one since the political changes in Hungary to deal with the topic of informants. It vividly depicts the atmosphere of Hungarian society in the seventies. The protagonist is Peter, a literary critic, is tasked by the secret police to persuade Social Democratic politician, Anna Kethly, who has been living in exile for decades, to return home. Keth... Leer todo', 'tt0407852')
# Accediendo a la película con ID tt0435716
# Nombre de la película: The Perfect Sleep
# Puntuación de IMDb: 4,4
# Directores: Jeremy Alter
# Guionistas: Anton Pardoe
# Argumento: Against the backdrop of a noirish dreamscape, a tortured man returns to the city he swore he would never return to, in order to save the woman he has always loved yet can never have.
# ID de la película: tt0435716
# Datos extraídos: ('The Perfect Sleep', '4,4', 'Jeremy Alter', 'Anton Pardoe', 'Against the backdrop of a noirish dreamscape, a tortured man returns to the city he swore he would never return to, in order to save the woman he has always loved yet can never have.', 'tt0435716')
# Accediendo a la película con ID tt0437065
# Nombre de la película: AmerAsian
# Puntuación de IMDb: 6,7
# Directores: Roger Lim
# Guionistas: Roger Lim
# Argumento: Eric, an American-born Asian college graduate, must steal a younger student's identity to take back the one last year of baseball eligibility that he lost when his dad passed away. Monica, his coach's All-American co-ed daughter, must ascertain her own questionable identity to come to terms with the years of abuse that she suffered after her mother passed away. Throug... Leer todo
# ID de la película: tt0437065
# Datos extraídos: ('AmerAsian', '6,7', 'Roger Lim', 'Roger Lim', "Eric, an American-born Asian college graduate, must steal a younger student's identity to take back the one last year of baseball eligibility that he lost when his dad passed away. Monica, his coach's All-American co-ed daughter, must ascertain her own questionable identity to come to terms with the years of abuse that she suffered after her mother passed away. Throug... Leer todo", 'tt0437065')
# Accediendo a la película con ID tt0437550
# Nombre de la película: Why George?
# Puntuación de IMDb: 8,1
# Directores: David Sonkin
# Guionistas: Shari Umansky
# Argumento:
# ID de la película: tt0437550
# Datos extraídos: ('Why George?', '8,1', 'David Sonkin', 'Shari Umansky', '', 'tt0437550')
# Accediendo a la película con ID tt0438894
# Nombre de la película: Kisse Pyaar Karoon?
# Puntuación de IMDb: 3,5
# Directores: Ajay Chandhok
# Guionistas: Shabbir Ahmed, Yunus Sajawal
# Argumento: Two men abduct a woman who wants to alienate them from their friend.
# ID de la película: tt0438894
# Datos extraídos: ('Kisse Pyaar Karoon?', '3,5', 'Ajay Chandhok', 'Shabbir Ahmed, Yunus Sajawal', 'Two men abduct a woman who wants to alienate them from their friend.', 'tt0438894')
# Accediendo a la película con ID tt0448182
# Nombre de la película: Yesterday Was a Lie
# Puntuación de IMDb: 5,2
# Directores: James Kerwin
# Guionistas: James Kerwin
# Argumento: Hoyle, a girl with a sharp mind and a weakness for bourbon, finds herself on the trail of a reclusive genius. But her work takes a series of unforeseen twists as events around her grow increasingly fragmented... disconnected... surreal. With an ethereal lounge singer and her loyal partner as her only allies, Hoyle is plunged into a dark world of intrigue and earth-sha... Leer todo
# ID de la película: tt0448182
# Datos extraídos: ('Yesterday Was a Lie', '5,2', 'James Kerwin', 'James Kerwin', 'Hoyle, a girl with a sharp mind and a weakness for bourbon, finds herself on the trail of a reclusive genius. But her work takes a series of unforeseen twists as events around her grow increasingly fragmented... disconnected... surreal. With an ethereal lounge singer and her loyal partner as her only allies, Hoyle is plunged into a dark world of intrigue and earth-sha... Leer todo', 'tt0448182')
# Accediendo a la película con ID tt0408060
# Nombre de la película: 1
# Puntuación de IMDb: 6,0
# Directores: Pater Sparrow
# Guionistas: Judit Góczán, Béla Hamvas, Stanislaw Lem
# Argumento: A bookshop renowned for its rare works is mysteriously and completely filled with copies of a book entitled 1, which doesn't appear to have a publisher or author.
# ID de la película: tt0408060
# Datos extraídos: ('1', '6,0', 'Pater Sparrow', 'Judit Góczán, Béla Hamvas, Stanislaw Lem', "A bookshop renowned for its rare works is mysteriously and completely filled with copies of a book entitled 1, which doesn't appear to have a publisher or author.", 'tt0408060')

# %%
#Cerrar el driver después de la extracción.
mi_driver.quit()

# %%
#Convierte la lista de datos extraídos a un DataFrame de pandas.
df_peliculas = pd.DataFrame(datos_peliculas, columns=["Título", "Puntuación IMDb", "Directores", "Guionistas", "Argumento", "ID"])

# %%
#Guarda el DataFrame en un archivo CSV.
df_peliculas.to_csv('data_peliculas_1995_2009.csv', index=False)
print("Archivo 'peliculas_ext_sel_1984.csv' creado exitosamente.")
# Out:
# Archivo 'peliculas_ext_sel_1984.csv' creado exitosamente.
