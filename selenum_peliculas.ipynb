# %% [markdown]
# 1.2. Extracción de Detalles de Películas con Selenium
# Una vez que tengan una lista de películas de la API, el siguiente paso es obtener información más detallada sobre ellas. Utilizarás la herramienta de automatización web Selenium para navegar a sitios web de reseñas de películas, en este caso IMDB, y extraer detalles como calificaciones, actores y directores.
#
# Necesitamos la siguiente información:
#
# Puntuación de IMDB (en caso de que la tenga).
#
# Dirección (director/a o directores/as de cada película).
#
# Guionistas (de cada película).
#
# Argumento.
#
# Nombre de la película.
#
# Id de la película.
#
# Bonus: También puedes extraer la siguiente información:
#
# Duración de la película.
#
# Puntuación de Rotten Tomatoes.

# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)

# %% [markdown]
# PASOS
#
# 1. Generar driver
# 2. Llamamos a una funcion que recibe un navegador y un identificador de película y devuelve los datos de esa pelicula
# 3. Hacemos un bucle que recorra los identificadores de las peliculas que queremos explorar.

# %%
# 1 GENERAR DRIVER

def generar_driver ():

    #Inicializamos el navegador.
    driver = webdriver.Chrome()

    sleep(2)

    #Maximizamos pantalla.
    driver.maximize_window()
    print("Maximizando la web.")

    sleep(2)


    #Navegamos a la página web "https://www.imdb.com/".
    driver.get("https://www.imdb.com/")
    print("Accediendo a la web.")
 

    sleep(2)

    #Aceptamos cookies.
    driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
    print("Cookies aceptadas.")

    sleep(2)

    return driver


# mi_driver = generar_driver()
# type(mi_driver)

# %% [markdown]
# En lugar de pasarle el nombre de la película por un input, se lo pasamos por parámetro a la funcion.
#
# Además, le vamos a pasar el driver por parámetro para que no tenga que estar entrando desde cero a IMDB con cada película.
# 👇

# %%
import re
from time import sleep
 
# Función para extraer los datos de una película usando su ID de IMDb
def extraer_datos_pelicula(driver, id_pelicula):
    # Construimos la URL de la película en IMDb usando su ID
    url_pelicula = f"https://www.imdb.com/title/{id_pelicula}/"
    driver.get(url_pelicula)
    print(f"Accediendo a la película con ID {id_pelicula}")

    sleep(2)

    #Ahora estamos dentro de la info de la película. Vamos a sacar los datos que se nos piden:

    #Nombre de la película.
    titulo_pelicula = driver.find_element("css selector", "h1").text
    print("Nombre de la película:", titulo_pelicula)

    #Puntuación de IMDb.
    try:
        puntuacion_pelicula = driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-afa4bed1-0.iMxoKo > section > div:nth-child(5) > section > section > div.sc-491663c0-3.kNMkxz > div.sc-3a4309f8-0.jJkxPn.sc-1f50b7c-1.doVJqQ > div > div:nth-child(1) > a > span > div > div.sc-eb51e184-0.ghvwpw > div.sc-eb51e184-2.fAhXAe > span.sc-eb51e184-1.ljxVSS").text
    except:
        puntuacion_pelicula = "No disponible"
        print("Puntuación de IMDb:", puntuacion_pelicula)

    #Info dirección.
    try:
        directores = driver.find_elements("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-afa4bed1-0.iMxoKo > section > div:nth-child(5) > section > section > div.sc-491663c0-4.ILcwq > div.sc-491663c0-6.bvzCJs > div.sc-491663c0-10.tkbDg > section > div.sc-1f50b7c-3.gLpgJQ > div > ul > li:nth-child(1) > div")
        nombres_directores = [director.text.strip() for director in directores]
        dato_direccion = ", ".join(nombres_directores)
        print("Dirección:", dato_direccion)
    except:
        dato_direccion = "No disponible."
        print(dato_direccion)

    #Info guionistas.
    try:
        guionistas = driver.find_elements("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-afa4bed1-0.iMxoKo > section > div:nth-child(5) > section > section > div.sc-491663c0-4.ILcwq > div.sc-491663c0-6.bvzCJs > div.sc-491663c0-10.tkbDg > section > div.sc-1f50b7c-3.gLpgJQ > div > ul > li:nth-child(2) > div")
        nombre_guionistas = [guionista.text.strip() for guionista in guionistas]
        
        # Usamos una expresión regular que detecte nombres completos (Nombre Apellido)
        def separar_nombres_completos(texto):
            # Patrón que busca pares de palabras con la estructura de un nombre completo
            return re.sub(r'([A-Z][a-z]+ [A-Z][a-z]+)', r'\1, ', texto)  # Añade coma y espacio
        
        # Aplicamos la función a los guionistas
        nombre_guionistas = [separar_nombres_completos(guionista) for guionista in nombre_guionistas]
        
        # Unimos los guionistas correctamente separados por comas y espacios
        dato_guion = " ".join(nombre_guionistas).rstrip(', ')  # Eliminamos la última coma y espacio, si queda
        print("Guionistas:", dato_guion)
    except:
        dato_guion = "No disponible."
        print(dato_guion)

    #Info argumento.
    try:
        argumento_pelicula = driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-afa4bed1-0.iMxoKo > section > div:nth-child(5) > section > section > div.sc-491663c0-4.ILcwq > div.sc-491663c0-6.bvzCJs > div.sc-491663c0-10.tkbDg > section > p > span.sc-2d37a7c7-2.ggeRnl").text
    except:
        argumento_pelicula = "No disponible"
    print("Argumento:", argumento_pelicula)

    # ID de la película (sacarlo de la URL)
    id_pelicula = driver.current_url.split('/')[4]
    print("ID de la película:", id_pelicula)

    sleep(2)

    # Devolvemos los resultados que hemos obtenido en una tupla
    tupla_datos_pelicula = (titulo_pelicula, puntuacion_pelicula, dato_direccion, dato_guion, argumento_pelicula, id_pelicula)
    
    # Imprimir la tupla de resultados
    print("Datos extraídos:", tupla_datos_pelicula)
    
    return tupla_datos_pelicula

# %% [markdown]
# 'tt0102362', 'tt0113092', 'tt0113086', 'tt0116748', 'tt0116391', 'tt0115937',
#     'tt0118694', 'tt0119495', 'tt0119806', 'tt0120202', 'tt0123003', 'tt0120263', 'tt0123055',
#     'tt0120630', 'tt0116628', 'tt0119273', 'tt0120755', 'tt0120913', 'tt0120673', 'tt0120903',
#     'tt0120917', 'tt0130623', 'tt0132910', 'tt0131704', 'tt0138749', 'tt0144964', 'tt0144574', 'tt0146984',
#     'tt0128158', 'tt0134084', 'tt0134983', 'tt0134847', 'tt0137115', 'tt0144084', 'tt0148120', 'tt0156020',
#     'tt0120753', 'tt0127349', 'tt0160495', 'tt0160644', 'tt0160289', 'tt0161081', 'tt0162711', 'tt0113026',
#     'tt0119866', 'tt0122459', 'tt0119966', 'tt0120467', 'tt0122161', 'tt0120117', 'tt0120698'

# %%
def extractor_idowners (archivo_csv) :
    # Esta función recibe un archivo .csv y devuelve una lista con todos los idowners que hay en el archivo.
    df_pelis_API = pd.read_csv(archivo_csv) 
    lista_idowners = df_pelis_API['IdOwner'].tolist()
    return lista_idowners

# %%
#En un inicio raneamos para probar con varios ids:
ids_peliculas = ['tt0102362', 'tt0113092', 'tt0113086', 'tt0116748', 'tt0116391', 'tt0115937', 
    'tt0118694', 'tt0119495', 'tt0119806', 'tt0120202', 'tt0123003', 'tt0120263', 'tt0123055', 
    'tt0120630', 'tt0116628', 'tt0119273', 'tt0120755', 'tt0120913', 'tt0120673', 'tt0120903', 
    'tt0120917', 'tt0130623', 'tt0132910', 'tt0131704']
    
mi_driver = generar_driver()

#Lista para almacenar los datos
datos_peliculas = []

for ids in ids_peliculas:
    mis_datos = extraer_datos_pelicula(mi_driver, ids)
    datos_peliculas.append(mis_datos)

mi_driver.quit()

# Crear un DataFrame con los datos extraídos
columnas = ["Título", "Puntuación IMDb", "Directores", "Guionistas", "Argumento", "ID"]
df_peliculas = pd.DataFrame(datos_peliculas, columns=columnas)

# Mostrar el DataFrame
print(df_peliculas)
# Out:
# Maximizando la web.
# Accediendo a la web.
# Cookies aceptadas.
# Accediendo a la película con ID tt0102362
# Nombre de la película: Istota
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0102362
# Datos extraídos: ('Istota', '6,3', '', '', 'No disponible', 'tt0102362')
# Accediendo a la película con ID tt0113092
# Nombre de la película: Por la causa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113092
# Datos extraídos: ('Por la causa', '3,4', '', '', 'No disponible', 'tt0113092')
# Accediendo a la película con ID tt0113086
# Nombre de la película: Florentino y el diablo
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113086
# Datos extraídos: ('Florentino y el diablo', '7,0', '', '', 'No disponible', 'tt0113086')
# Accediendo a la película con ID tt0116748
# Nombre de la película: Karobaar: The Business of Love
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116748
# Datos extraídos: ('Karobaar: The Business of Love', '3,7', '', '', 'No disponible', 'tt0116748')
# Accediendo a la película con ID tt0116391
# Nombre de la película: Gang
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116391
# Datos extraídos: ('Gang', '6,3', '', '', 'No disponible', 'tt0116391')
# Accediendo a la película con ID tt0115937
# Nombre de la película: Consequence
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115937
# Datos extraídos: ('Consequence', '7,7', '', '', 'No disponible', 'tt0115937')
# Accediendo a la película con ID tt0118694
# Nombre de la película: Deseando amar
# Dirección: Kar-Wai Wong
# Guionistas: Kar-Wai Wong
# Argumento: Dos vecinos forman un fuerte vínculo después de que ambos sospechen de actividades extramatrimoniales de sus cónyuges. Sin embargo, acuerdan mantener su vínculo platónico para no cometer errores similares.
# ID de la película: tt0118694
# Datos extraídos: ('Deseando amar', '8,1', 'Kar-Wai Wong', 'Kar-Wai Wong', 'Dos vecinos forman un fuerte vínculo después de que ambos sospechen de actividades extramatrimoniales de sus cónyuges. Sin embargo, acuerdan mantener su vínculo platónico para no cometer errores similares.', 'tt0118694')
# Accediendo a la película con ID tt0119495
# Nombre de la película: Love 101
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119495
# Datos extraídos: ('Love 101', '5,1', '', '', 'No disponible', 'tt0119495')
# Accediendo a la película con ID tt0119806
# Nombre de la película: Nothing Sacred
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119806
# Datos extraídos: ('Nothing Sacred', '5,8', '', '', 'No disponible', 'tt0119806')
# Accediendo a la película con ID tt0120202
# Nombre de la película: State and Main
# Dirección: David Mamet
# Guionistas: David Mamet
# Argumento: A movie crew invades a small town whose residents are all too ready to give up their values for showbiz glitz.
# ID de la película: tt0120202
# Datos extraídos: ('State and Main', '6,7', 'David Mamet', 'David Mamet', 'A movie crew invades a small town whose residents are all too ready to give up their values for showbiz glitz.', 'tt0120202')
# Accediendo a la película con ID tt0123003
# Nombre de la película: Bruno
# Dirección: Shirley MacLaine
# Guionistas: David Ciminello
# Argumento: Bruno es un joven genio único, cuya expresión de su propia individualidad lleva a su familia y comunidad a lo largo de un viaje emocional.
# ID de la película: tt0123003
# Datos extraídos: ('Bruno', '6,0', 'Shirley MacLaine', 'David Ciminello', 'Bruno es un joven genio único, cuya expresión de su propia individualidad lleva a su familia y comunidad a lo largo de un viaje emocional.', 'tt0123003')
# Accediendo a la película con ID tt0120263
# Nombre de la película: Canciones del segundo piso
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120263
# Datos extraídos: ('Canciones del segundo piso', '7,5', '', '', 'No disponible', 'tt0120263')
# Accediendo a la película con ID tt0123055
# Nombre de la película: The Elf Who Didn't Believe
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0123055
# Datos extraídos: ("The Elf Who Didn't Believe", '3,8', '', '', 'No disponible', 'tt0123055')
# Accediendo a la película con ID tt0120630
# Nombre de la película: Chicken Run: Evasión en la granja
# Dirección: Peter LordNick Park
# Guionistas: Peter Lord, Nick Park, Karey Kirkpatrick
# Argumento: Cuando un gallo entra aparentemente volando en una granja de pollos, las gallinas lo ven como una oportunidad para escapar de sus malvados dueños.
# ID de la película: tt0120630
# Datos extraídos: ('Chicken Run: Evasión en la granja', '7,1', 'Peter LordNick Park', 'Peter Lord, Nick Park, Karey Kirkpatrick', 'Cuando un gallo entra aparentemente volando en una granja de pollos, las gallinas lo ven como una oportunidad para escapar de sus malvados dueños.', 'tt0120630')
# Accediendo a la película con ID tt0116628
# Nombre de la película: Sociedad anónima
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116628
# Datos extraídos: ('Sociedad anónima', '6,3', '', '', 'No disponible', 'tt0116628')
# Accediendo a la película con ID tt0119273
# Nombre de la película: Heavy Metal 2
# Dirección: Michael ColdeweyMichel Lemire
# Guionistas: Kevin Eastman, Simon Bisley, Eric Talbot
# Argumento: After surviving an invasion on her peaceful homeworld, a beautiful avenger must stop a powerful psychopath from gaining immortality and rescue her kidnapped sister.
# ID de la película: tt0119273
# Datos extraídos: ('Heavy Metal 2', '5,4', 'Michael ColdeweyMichel Lemire', 'Kevin Eastman, Simon Bisley, Eric Talbot', 'After surviving an invasion on her peaceful homeworld, a beautiful avenger must stop a powerful psychopath from gaining immortality and rescue her kidnapped sister.', 'tt0119273')
# Accediendo a la película con ID tt0120755
# Nombre de la película: Misión: Imposible 2
# Dirección: John Woo
# Guionistas: Bruce Geller, Ronald D. MooreBrannon Braga
# Argumento: "El agente del FMI Ethan Hunt es enviado a Sydney, para encontrar y destruir una enfermedad genéticamente modificada llamada ""Quimera""."
# ID de la película: tt0120755
# Datos extraídos: ('Misión: Imposible 2', '6,1', 'John Woo', 'Bruce Geller, Ronald D. MooreBrannon Braga', '"El agente del FMI Ethan Hunt es enviado a Sydney, para encontrar y destruir una enfermedad genéticamente modificada llamada ""Quimera""."', 'tt0120755')
# Accediendo a la película con ID tt0120913
# Nombre de la película: Titan A.E.
# Dirección: Don BluthGary Goldman
# Guionistas: Hans Bauer, Randall Mc, CormickBen Edlund
# Argumento: Un joven descubre que tiene que encontrar una nave terrestre oculta antes que una especie alienígena enemiga para asegurar la supervivencia de la humanidad.
# ID de la película: tt0120913
# Datos extraídos: ('Titan A.E.', '6,6', 'Don BluthGary Goldman', 'Hans Bauer, Randall Mc, CormickBen Edlund', 'Un joven descubre que tiene que encontrar una nave terrestre oculta antes que una especie alienígena enemiga para asegurar la supervivencia de la humanidad.', 'tt0120913')
# Accediendo a la película con ID tt0120673
# Nombre de la película: Foiled
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120673
# Datos extraídos: ('Foiled', '6,6', '', '', 'No disponible', 'tt0120673')
# Accediendo a la película con ID tt0120903
# Nombre de la película: X-Men
# Dirección: Bryan Singer
# Guionistas: Tom De, SantoBryan Singer, David Hayter
# Argumento: En un mundo donde los mutantes (humanos superpoderosos evolucionados) existen y son discriminados, dos grupos se forman para un choque inevitable: la supremacista Hermandad y los pacifistas X-Men.
# ID de la película: tt0120903
# Datos extraídos: ('X-Men', '7,3', 'Bryan Singer', 'Tom De, SantoBryan Singer, David Hayter', 'En un mundo donde los mutantes (humanos superpoderosos evolucionados) existen y son discriminados, dos grupos se forman para un choque inevitable: la supremacista Hermandad y los pacifistas X-Men.', 'tt0120903')
# Accediendo a la película con ID tt0120917
# Nombre de la película: El emperador y sus locuras
# Dirección: Mark Dindal
# Guionistas: Chris Williams, Mark Dindal, David Reynolds
# Argumento: El emperador Kuzco fue convertido en una llama por su exadministradora Yzma, y ahora debe recuperar su trono con la ayuda de Pacha, un amable pastor de llamas.
# ID de la película: tt0120917
# Datos extraídos: ('El emperador y sus locuras', '7,4', 'Mark Dindal', 'Chris Williams, Mark Dindal, David Reynolds', 'El emperador Kuzco fue convertido en una llama por su exadministradora Yzma, y ahora debe recuperar su trono con la ayuda de Pacha, un amable pastor de llamas.', 'tt0120917')
# Accediendo a la película con ID tt0130623
# Nombre de la película: Dinosaurio
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0130623
# Datos extraídos: ('Dinosaurio', '6,4', '', '', 'No disponible', 'tt0130623')
# Accediendo a la película con ID tt0132910
# Nombre de la película: El Cuervo: Salvación
# Dirección: Bharat Nalluri
# Guionistas: James O'BarrChip Johannessen
# Argumento: Alex Corvis returns to the world of the living to solve the murder of a young woman that he was wrongly accused of.
# ID de la película: tt0132910
# Datos extraídos: ('El Cuervo: Salvación', '4,9', 'Bharat Nalluri', "James O'BarrChip Johannessen", 'Alex Corvis returns to the world of the living to solve the murder of a young woman that he was wrongly accused of.', 'tt0132910')
# Accediendo a la película con ID tt0131704
# Nombre de la película: Las aventuras de Rocky y Bullwinkle
# Dirección: Des McAnuff
# Guionistas: Jay Ward, Kenneth Lonergan
# Argumento: Cuando los enemigos Boris, Natasha y Líder Temerario escapan al mundo real con un plan nefasto, Rocky y Bullwinkle hacen lo mismo, y se unen a un joven agente del FBI para detener al trío.
# ID de la película: tt0131704
# Datos extraídos: ('Las aventuras de Rocky y Bullwinkle', '4,3', 'Des McAnuff', 'Jay Ward, Kenneth Lonergan', 'Cuando los enemigos Boris, Natasha y Líder Temerario escapan al mundo real con un plan nefasto, Rocky y Bullwinkle hacen lo mismo, y se unen a un joven agente del FBI para detener al trío.', 'tt0131704')
#                                  Título Puntuación IMDb  \
# 0                                Istota             6,3
# 1                          Por la causa             3,4
# 2                Florentino y el diablo             7,0
# 3        Karobaar: The Business of Love             3,7
# 4                                  Gang             6,3
# 5                           Consequence             7,7
# 6                         Deseando amar             8,1
# 7                              Love 101             5,1
# 8                        Nothing Sacred             5,8
# 9                        State and Main             6,7
# 10                                Bruno             6,0
# 11           Canciones del segundo piso             7,5
# 12           The Elf Who Didn't Believe             3,8
# 13    Chicken Run: Evasión en la granja             7,1
# 14                     Sociedad anónima             6,3
# 15                        Heavy Metal 2             5,4
# 16                  Misión: Imposible 2             6,1
# 17                           Titan A.E.             6,6
# 18                               Foiled             6,6
# 19                                X-Men             7,3
# 20           El emperador y sus locuras             7,4
# 21                           Dinosaurio             6,4
# 22                 El Cuervo: Salvación             4,9
# 23  Las aventuras de Rocky y Bullwinkle             4,3
#
#                        Directores  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6                    Kar-Wai Wong
# 7
# 8
# 9                     David Mamet
# 10               Shirley MacLaine
# 11
# 12
# 13            Peter LordNick Park
# 14
# 15  Michael ColdeweyMichel Lemire
# 16                       John Woo
# 17          Don BluthGary Goldman
# 18
# 19                   Bryan Singer
# 20                    Mark Dindal
# 21
# 22                 Bharat Nalluri
# 23                    Des McAnuff
#
#                                      Guionistas  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6                                  Kar-Wai Wong
# 7
# 8
# 9                                   David Mamet
# 10                              David Ciminello
# 11
# 12
# 13     Peter Lord, Nick Park, Karey Kirkpatrick
# 14
# 15     Kevin Eastman, Simon Bisley, Eric Talbot
# 16   Bruce Geller, Ronald D. MooreBrannon Braga
# 17    Hans Bauer, Randall Mc, CormickBen Edlund
# 18
# 19      Tom De, SantoBryan Singer, David Hayter
# 20  Chris Williams, Mark Dindal, David Reynolds
# 21
# 22                 James O'BarrChip Johannessen
# 23                   Jay Ward, Kenneth Lonergan
#
#                                             Argumento         ID
# 0                                       No disponible  tt0102362
# 1                                       No disponible  tt0113092
# 2                                       No disponible  tt0113086
# 3                                       No disponible  tt0116748
# 4                                       No disponible  tt0116391
# 5                                       No disponible  tt0115937
# 6   Dos vecinos forman un fuerte vínculo después d...  tt0118694
# 7                                       No disponible  tt0119495
# 8                                       No disponible  tt0119806
# 9   A movie crew invades a small town whose reside...  tt0120202
# 10  Bruno es un joven genio único, cuya expresión ...  tt0123003
# 11                                      No disponible  tt0120263
# 12                                      No disponible  tt0123055
# 13  Cuando un gallo entra aparentemente volando en...  tt0120630
# 14                                      No disponible  tt0116628
# 15  After surviving an invasion on her peaceful ho...  tt0119273
# 16  "El agente del FMI Ethan Hunt es enviado a Syd...  tt0120755
# 17  Un joven descubre que tiene que encontrar una ...  tt0120913
# 18                                      No disponible  tt0120673
# 19  En un mundo donde los mutantes (humanos superp...  tt0120903
# 20  El emperador Kuzco fue convertido en una llama...  tt0120917
# 21                                      No disponible  tt0130623
# 22  Alex Corvis returns to the world of the living...  tt0132910
# 23  Cuando los enemigos Boris, Natasha y Líder Tem...  tt0131704

# %%
#Y separados Dataframe:
df_peliculas.head()
# Out:
#                            Título Puntuación IMDb Directores Guionistas  \
# 0                          Istota             6,3
# 1                    Por la causa             3,4
# 2          Florentino y el diablo             7,0
# 3  Karobaar: The Business of Love             3,7
# 4                            Gang             6,3
#
#        Argumento         ID
# 0  No disponible  tt0102362
# 1  No disponible  tt0113092
# 2  No disponible  tt0113086
# 3  No disponible  tt0116748
# 4  No disponible  tt0116391

# %%
import pandas as pd

df_peliculas.to_csv('extraccion_peliculas_selenium.csv')
print("Archivo 'extraccion_peliculas_selenium.csv'' creado exitosamente.")
# Out:
# Archivo 'extraccion_peliculas_selenium.csv'' creado exitosamente.

# %% [markdown]
# def webscrapping_imbd

# %%
#Peliculas de 1995 a 1999:

ids_peliculas = extractor_idowners('peliculas_1995_1999.csv')

# Crear el driver de Selenium
mi_driver = generar_driver()

# Lista para almacenar los datos extraídos
datos_peliculas = []

# Bucle para recorrer todos los IDs Owners y extraer la información
for id_owner in ids_peliculas:
    mis_datos = extraer_datos_pelicula(mi_driver, id_owner)
    datos_peliculas.append(mis_datos)

# Cerrar el driver después de la extracción
mi_driver.quit()

# Convertir los datos extraídos a un DataFrame
df_peliculas = pd.DataFrame(datos_peliculas, columns=["Título", "Puntuación IMDb", "Directores", "Guionistas", "Argumento", "ID"])
# Out:
# Maximizando la web.
# Accediendo a la web.
# Cookies aceptadas.
# Accediendo a la película con ID tt0100267
# Nombre de la película: Nobat e Asheghi
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0100267
# Datos extraídos: ('Nobat e Asheghi', '6,4', '', '', 'No disponible', 'tt0100267')
# Accediendo a la película con ID tt0102739
# Nombre de la película: ¡Que vivan los crotos!
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0102739
# Datos extraídos: ('¡Que vivan los crotos!', '6,7', '', '', 'No disponible', 'tt0102739')
# Accediendo a la película con ID tt0105096
# Nombre de la película: Paraíso Perdido
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0105096
# Datos extraídos: ('Paraíso Perdido', '6,4', '', '', 'No disponible', 'tt0105096')
# Accediendo a la película con ID tt0105298
# Nombre de la película: Nacidos para la libertad
# Dirección: Dee McLachlan
# Guionistas: John Varty, Andrea Buck, Dee Mc, Lachlan
# Argumento: A filmmaker determines to document the story of a conservationist who is struggling to save wild leopards in Africa from extinction.
# ID de la película: tt0105298
# Datos extraídos: ('Nacidos para la libertad', '5,5', 'Dee McLachlan', 'John Varty, Andrea Buck, Dee Mc, Lachlan', 'A filmmaker determines to document the story of a conservationist who is struggling to save wild leopards in Africa from extinction.', 'tt0105298')
# Accediendo a la película con ID tt0106616
# Nombre de la película: Las cosas del querer 2ª parte
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0106616
# Datos extraídos: ('Las cosas del querer 2ª parte', '5,1', '', '', 'No disponible', 'tt0106616')
# Accediendo a la película con ID tt0107070
# Nombre de la película: Halbe Welt
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0107070
# Datos extraídos: ('Halbe Welt', '6,6', '', '', 'No disponible', 'tt0107070')
# Accediendo a la película con ID tt0102952
# Nombre de la película: ¡Que rollo de madre!
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0102952
# Datos extraídos: ('¡Que rollo de madre!', '4,9', '', '', 'No disponible', 'tt0102952')
# Accediendo a la película con ID tt0101616
# Nombre de la película: Coolie No. 1
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0101616
# Datos extraídos: ('Coolie No. 1', '6,6', '', '', 'No disponible', 'tt0101616')
# Accediendo a la película con ID tt0102532
# Nombre de la película: Night Visions
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0102532
# Datos extraídos: ('Night Visions', '5,3', '', '', 'No disponible', 'tt0102532')
# Accediendo a la película con ID tt0108576
# Nombre de la película: Witch Academy
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0108576
# Datos extraídos: ('Witch Academy', '3,8', '', '', 'No disponible', 'tt0108576')
# Accediendo a la película con ID tt0107537
# Nombre de la película: Mecánicas celestes
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0107537
# Datos extraídos: ('Mecánicas celestes', '6,7', '', '', 'No disponible', 'tt0107537')
# Accediendo a la película con ID tt0105881
# Nombre de la película: Magkasangga 2000
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0105881
# Datos extraídos: ('Magkasangga 2000', '4,1', '', '', 'No disponible', 'tt0105881')
# Accediendo a la película con ID tt0109178
# Nombre de la película: Automatic
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109178
# Datos extraídos: ('Automatic', '5,2', '', '', 'No disponible', 'tt0109178')
# Accediendo a la película con ID tt0109033
# Nombre de la película: Secuestradas
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109033
# Datos extraídos: ('Secuestradas', '3,6', '', '', 'No disponible', 'tt0109033')
# Accediendo a la película con ID tt0109536
# Nombre de la película: Peligroso
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109536
# Datos extraídos: ('Peligroso', '4,0', '', '', 'No disponible', 'tt0109536')
# Accediendo a la película con ID tt0109400
# Nombre de la película: El misterioso fantasma de un niño muy normalito
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109400
# Datos extraídos: ('El misterioso fantasma de un niño muy normalito', '4,7', '', '', 'No disponible', 'tt0109400')
# Accediendo a la película con ID tt0109746
# Nombre de la película: Esti Kornél csodálatos utazása
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109746
# Datos extraídos: ('Esti Kornél csodálatos utazása', '7,0', '', '', 'No disponible', 'tt0109746')
# Accediendo a la película con ID tt0109905
# Nombre de la película: El policía gladiador
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109905
# Datos extraídos: ('El policía gladiador', '3,1', '', '', 'No disponible', 'tt0109905')
# Accediendo a la película con ID tt0110252
# Nombre de la película: Keïta! L'héritage du griot
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110252
# Datos extraídos: ("Keïta! L'héritage du griot", '6,4', '', '', 'No disponible', 'tt0110252')
# Accediendo a la película con ID tt0110826
# Nombre de la película: The Phoenix and the Magic Carpet
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110826
# Datos extraídos: ('The Phoenix and the Magic Carpet', '4,9', '', '', 'No disponible', 'tt0110826')
# Accediendo a la película con ID tt0111359
# Nombre de la película: Un cuento: El mito de Pecos Bill
# Dirección: Jeremiah S. Chechik
# Guionistas: Steve Bloom, Robert Rodat
# Argumento: A young boy's imagination summons cowboy legend Pecos Bill, who helps him save the family farm from a greedy land-grabber. With the help of a lumberjack and a railroad worker, they all embark on a surprise-filled adventure.
# ID de la película: tt0111359
# Datos extraídos: ('Un cuento: El mito de Pecos Bill', '5,9', 'Jeremiah S. Chechik', 'Steve Bloom, Robert Rodat', "A young boy's imagination summons cowboy legend Pecos Bill, who helps him save the family farm from a greedy land-grabber. With the help of a lumberjack and a railroad worker, they all embark on a surprise-filled adventure.", 'tt0111359')
# Accediendo a la película con ID tt0109546
# Nombre de la película: Tentación
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109546
# Datos extraídos: ('Tentación', '4,2', '', '', 'No disponible', 'tt0109546')
# Accediendo a la película con ID tt0109415
# Nombre de la película: Los chicos del maíz 3: La cosecha urbana
# Dirección: James D.R. Hickox
# Guionistas: Dode B. LevensonStephen King, Matt Greenberg
# Argumento: Dos sobrevivientes de eventos anteriores son adoptados por una familia de Chicago. En la gran ciudad, intentan adaptarse, pero uno de ellos es en realidad un emisario del mal y pronto comienza una nueva cosecha.
# ID de la película: tt0109415
# Datos extraídos: ('Los chicos del maíz 3: La cosecha urbana', '4,3', 'James D.R. Hickox', 'Dode B. LevensonStephen King, Matt Greenberg', 'Dos sobrevivientes de eventos anteriores son adoptados por una familia de Chicago. En la gran ciudad, intentan adaptarse, pero uno de ellos es en realidad un emisario del mal y pronto comienza una nueva cosecha.', 'tt0109415')
# Accediendo a la película con ID tt0109723
# Nombre de la película: El abrazo del vampiro
# Dirección: Anne Goursaud
# Guionistas: Halle Eaton, Nicole Coady, Rick Bitzelberger
# Argumento: Una estudiante de primer año de la universidad, es seducida por un apuesto vampiro que la introduce en un oscuro mundo de deseos carnales.
# ID de la película: tt0109723
# Datos extraídos: ('El abrazo del vampiro', '4,4', 'Anne Goursaud', 'Halle Eaton, Nicole Coady, Rick Bitzelberger', 'Una estudiante de primer año de la universidad, es seducida por un apuesto vampiro que la introduce en un oscuro mundo de deseos carnales.', 'tt0109723')
# Accediendo a la película con ID tt0110604
# Nombre de la película: Testigo mudo
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110604
# Datos extraídos: ('Testigo mudo', '6,7', '', '', 'No disponible', 'tt0110604')
# Accediendo a la película con ID tt0111574
# Nombre de la película: The Upstairs Neighbour
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111574
# Datos extraídos: ('The Upstairs Neighbour', '6,6', '', '', 'No disponible', 'tt0111574')
# Accediendo a la película con ID tt0111464
# Nombre de la película: Jugando a morir
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111464
# Datos extraídos: ('Jugando a morir', '3,5', '', '', 'No disponible', 'tt0111464')
# Accediendo a la película con ID tt0111244
# Nombre de la película: Satánica, todo el mal en ella
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111244
# Datos extraídos: ('Satánica, todo el mal en ella', '4,1', '', '', 'No disponible', 'tt0111244')
# Accediendo a la película con ID tt0109028
# Nombre de la película: Fiebre helada
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109028
# Datos extraídos: ('Fiebre helada', '7,0', '', '', 'No disponible', 'tt0109028')
# Accediendo a la película con ID tt0109642
# Nombre de la película: Eclipse total (Dolores Claiborne)
# Dirección: Taylor Hackford
# Guionistas: Stephen King, Tony Gilroy
# Argumento: Una periodista de una gran ciudad viaja a un pequeño pueblo en el que su madre ha sido detenida por el asesinato de una anciana para la que trabaja como sirvienta.
# ID de la película: tt0109642
# Datos extraídos: ('Eclipse total (Dolores Claiborne)', '7,4', 'Taylor Hackford', 'Stephen King, Tony Gilroy', 'Una periodista de una gran ciudad viaja a un pequeño pueblo en el que su madre ha sido detenida por el asesinato de una anciana para la que trabaja como sirvienta.', 'tt0109642')
# Accediendo a la película con ID tt0110217
# Nombre de la película: Jupiter's Wife
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110217
# Datos extraídos: ("Jupiter's Wife", '7,1', '', '', 'No disponible', 'tt0110217')
# Accediendo a la película con ID tt0111151
# Nombre de la película: Mad Dogs and Englishmen
# Dirección: Henry Cole
# Guionistas: Tim Sewell, Henry Cole
# Argumento: Antonia is a cute drug addict in London, who meets a nice motorbike courier. They get caught between a corrupt drug cop and a drug dealer.
# ID de la película: tt0111151
# Datos extraídos: ('Mad Dogs and Englishmen', '3,9', 'Henry Cole', 'Tim Sewell, Henry Cole', 'Antonia is a cute drug addict in London, who meets a nice motorbike courier. They get caught between a corrupt drug cop and a drug dealer.', 'tt0111151')
# Accediendo a la película con ID tt0111269
# Nombre de la película: Die Knickerbocker-Bande: Das sprechende Grab
# Dirección: Marijan David Vajda
# Guionistas: Thomas Brezina, Milan Dor
# Argumento: Get set for the adventure of a lifetime when a "dare" leads four curious kids into a hair-raising investigation. While four friends meet at an old cemetery, they stumble over the grave of a famous magician. Things soon turn spooky as they're haunted by a cloaked stranger and mysterious voices begin erupting from the magician's grave. When they discover a magnificent s... Leer todo
# ID de la película: tt0111269
# Datos extraídos: ('Die Knickerbocker-Bande: Das sprechende Grab', '4,7', 'Marijan David Vajda', 'Thomas Brezina, Milan Dor', 'Get set for the adventure of a lifetime when a "dare" leads four curious kids into a hair-raising investigation. While four friends meet at an old cemetery, they stumble over the grave of a famous magician. Things soon turn spooky as they\'re haunted by a cloaked stranger and mysterious voices begin erupting from the magician\'s grave. When they discover a magnificent s... Leer todo', 'tt0111269')
# Accediendo a la película con ID tt0109363
# Nombre de la película: Seeking the Cafe Bob
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109363
# Datos extraídos: ('Seeking the Cafe Bob', '7,2', '', '', 'No disponible', 'tt0109363')
# Accediendo a la película con ID tt0109489
# Nombre de la película: Costa Brava
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109489
# Datos extraídos: ('Costa Brava', '6,3', '', '', 'No disponible', 'tt0109489')
# Accediendo a la película con ID tt0095102
# Nombre de la película: Les ennemis de la mafia
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0095102
# Datos extraídos: ('Les ennemis de la mafia', '7,6', '', '', 'No disponible', 'tt0095102')
# Accediendo a la película con ID tt0109034
# Nombre de la película: Libre de sospecha
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109034
# Datos extraídos: ('Libre de sospecha', '6,7', '', '', 'No disponible', 'tt0109034')
# Accediendo a la película con ID tt0109532
# Nombre de la película: Indiscrección peligrosa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109532
# Datos extraídos: ('Indiscrección peligrosa', '4,7', '', '', 'No disponible', 'tt0109532')
# Accediendo a la película con ID tt0099840
# Nombre de la película: In the Shadow of the Sandcastles
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0099840
# Datos extraídos: ('In the Shadow of the Sandcastles', '5,5', '', '', 'No disponible', 'tt0099840')
# Accediendo a la película con ID tt0103655
# Nombre de la película: Almost Blue
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0103655
# Datos extraídos: ('Almost Blue', '4,8', '', '', 'No disponible', 'tt0103655')
# Accediendo a la película con ID tt0106322
# Nombre de la película: Augustitango
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0106322
# Datos extraídos: ('Augustitango', '4,4', '', '', 'No disponible', 'tt0106322')
# Accediendo a la película con ID tt0106621
# Nombre de la película: Marcada por el recuerdo
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0106621
# Datos extraídos: ('Marcada por el recuerdo', '6,8', '', '', 'No disponible', 'tt0106621')
# Accediendo a la película con ID tt0106421
# Nombre de la película: Burakku jakku
# Dirección: Osamu Dezaki
# Guionistas: Osamu Dezaki, Udo Lindenberg, Eto Mori
# Argumento: The adventures of the unlicensed but genius doctor Black Jack, who encounters extraordinary people and phenomena as he attends to unusual medical cases.
# ID de la película: tt0106421
# Datos extraídos: ('Burakku jakku', '6,7', 'Osamu Dezaki', 'Osamu Dezaki, Udo Lindenberg, Eto Mori', 'The adventures of the unlicensed but genius doctor Black Jack, who encounters extraordinary people and phenomena as he attends to unusual medical cases.', 'tt0106421')
# Accediendo a la película con ID tt0107025
# Nombre de la película: God's Lonely Man
# Dirección: Francis von Zerneck
# Guionistas: Francis von Zerneck
# Argumento: As each relentless night turns towards day, Ernest Rackman turns towards violence to escape thoughts of loneliness and suicide. Then he poses as a police officer and rescues a young girl from her parent's apartment, where she was forced into a compromising life. Having discharged his violence, he plans to move forward with this new relationship, but the demons of lone... Leer todo
# ID de la película: tt0107025
# Datos extraídos: ("God's Lonely Man", '6,4', 'Francis von Zerneck', 'Francis von Zerneck', "As each relentless night turns towards day, Ernest Rackman turns towards violence to escape thoughts of loneliness and suicide. Then he poses as a police officer and rescues a young girl from her parent's apartment, where she was forced into a compromising life. Having discharged his violence, he plans to move forward with this new relationship, but the demons of lone... Leer todo", 'tt0107025')
# Accediendo a la película con ID tt0109239
# Nombre de la película: Belyy prazdnik
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109239
# Datos extraídos: ('Belyy prazdnik', '7,3', '', '', 'No disponible', 'tt0109239')
# Accediendo a la película con ID tt0110028
# Nombre de la película: Highway of Heartache
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110028
# Datos extraídos: ('Highway of Heartache', '8,0', '', '', 'No disponible', 'tt0110028')
# Accediendo a la película con ID tt0110294
# Nombre de la película: Ladri di cinema
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110294
# Datos extraídos: ('Ladri di cinema', '6,6', '', '', 'No disponible', 'tt0110294')
# Accediendo a la película con ID tt0110910
# Nombre de la película: Pterodactyl Woman from Beverly Hills
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110910
# Datos extraídos: ('Pterodactyl Woman from Beverly Hills', '4,6', '', '', 'No disponible', 'tt0110910')
# Accediendo a la película con ID tt0110463
# Nombre de la película: Mo him wong
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110463
# Datos extraídos: ('Mo him wong', '5,7', '', '', 'No disponible', 'tt0110463')
# Accediendo a la película con ID tt0111678
# Nombre de la película: The Wedding Tape
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111678
# Datos extraídos: ('The Wedding Tape', 'No disponible', '', '', 'No disponible', 'tt0111678')
# Accediendo a la película con ID tt0111129
# Nombre de la película: La serva amorosa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111129
# Datos extraídos: ('La serva amorosa', '6,7', '', '', 'No disponible', 'tt0111129')
# Accediendo a la película con ID tt0112526
# Nombre de la película: Blondes Have More Guns
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112526
# Datos extraídos: ('Blondes Have More Guns', '4,5', '', '', 'No disponible', 'tt0112526')
# Accediendo a la película con ID tt0112803
# Nombre de la película: The Darien Gap
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112803
# Datos extraídos: ('The Darien Gap', '6,6', '', '', 'No disponible', 'tt0112803')
# Accediendo a la película con ID tt0113035
# Nombre de la película: Ein fast perfekter Seitensprung
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113035
# Datos extraídos: ('Ein fast perfekter Seitensprung', '6,2', '', '', 'No disponible', 'tt0113035')
# Accediendo a la película con ID tt0112946
# Nombre de la película: Eliksir
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112946
# Datos extraídos: ('Eliksir', '6,6', '', '', 'No disponible', 'tt0112946')
# Accediendo a la película con ID tt0112923
# Nombre de la película: Eno nakano bokuno mura
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112923
# Datos extraídos: ('Eno nakano bokuno mura', '6,9', '', '', 'No disponible', 'tt0112923')
# Accediendo a la película con ID tt0112908
# Nombre de la película: Drzewa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112908
# Datos extraídos: ('Drzewa', '2,5', '', '', 'No disponible', 'tt0112908')
# Accediendo a la película con ID tt0113981
# Nombre de la película: Cazador de medianoche
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113981
# Datos extraídos: ('Cazador de medianoche', '3,9', '', '', 'No disponible', 'tt0113981')
# Accediendo a la película con ID tt0114485
# Nombre de la película: Sobrenatural
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0114485
# Datos extraídos: ('Sobrenatural', '6,3', '', '', 'No disponible', 'tt0114485')
# Accediendo a la película con ID tt0111305
# Nombre de la película: Sucesos distantes
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111305
# Datos extraídos: ('Sucesos distantes', '6,6', '', '', 'No disponible', 'tt0111305')
# Accediendo a la película con ID tt0112632
# Nombre de la película: Carlos Monzón, el segundo juicio
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112632
# Datos extraídos: ('Carlos Monzón, el segundo juicio', '5,0', '', '', 'No disponible', 'tt0112632')
# Accediendo a la película con ID tt0113643
# Nombre de la película: Letters from the East
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113643
# Datos extraídos: ('Letters from the East', '6,7', '', '', 'No disponible', 'tt0113643')
# Accediendo a la película con ID tt0113591
# Nombre de la película: Labirintos
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113591
# Datos extraídos: ('Labirintos', '4,6', '', '', 'No disponible', 'tt0113591')
# Accediendo a la película con ID tt0113682
# Nombre de la película: Lago Ness
# Dirección: John Henderson
# Guionistas: John Fusco
# Argumento: El Dr. Dempsey, científico estadounidense que se ha convertido en un escéptico tras una desastrosa decisión equivocada, no está precisamente entusiasmado con ser enviado a Escocia para probar la existencia del monstruo del lago Ness.
# ID de la película: tt0113682
# Datos extraídos: ('Lago Ness', '5,5', 'John Henderson', 'John Fusco', 'El Dr. Dempsey, científico estadounidense que se ha convertido en un escéptico tras una desastrosa decisión equivocada, no está precisamente entusiasmado con ser enviado a Escocia para probar la existencia del monstruo del lago Ness.', 'tt0113682')
# Accediendo a la película con ID tt0114170
# Nombre de la película: Power 98
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0114170
# Datos extraídos: ('Power 98', '4,5', '', '', 'No disponible', 'tt0114170')
# Accediendo a la película con ID tt0111645
# Nombre de la película: Los vuelcos del corazón
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111645
# Datos extraídos: ('Los vuelcos del corazón', '5,8', '', '', 'No disponible', 'tt0111645')
# Accediendo a la película con ID tt0113443
# Nombre de la película: It's My Party (Fiesta de despedida)
# Dirección: Randal Kleiser
# Guionistas: Randal Kleiser
# Argumento: Nick "Eric Roberts", is nearing the end of a 3-year battle with AIDS and makes arrangements to die. He hosts a party to say goodbye to friends and family. His ex-partner, Brandon "Gregory Harrison", attends and things get complicated.
# ID de la película: tt0113443
# Datos extraídos: ("It's My Party (Fiesta de despedida)", '7,1', 'Randal Kleiser', 'Randal Kleiser', 'Nick "Eric Roberts", is nearing the end of a 3-year battle with AIDS and makes arrangements to die. He hosts a party to say goodbye to friends and family. His ex-partner, Brandon "Gregory Harrison", attends and things get complicated.', 'tt0113443')
# Accediendo a la película con ID tt0113314
# Nombre de la película: Tras el silencio
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113314
# Datos extraídos: ('Tras el silencio', '7,2', '', '', 'No disponible', 'tt0113314')
# Accediendo a la película con ID tt0112675
# Nombre de la película: Cilantro y perejil
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112675
# Datos extraídos: ('Cilantro y perejil', '6,3', '', '', 'No disponible', 'tt0112675')
# Accediendo a la película con ID tt0113033
# Nombre de la película: Dinero sucio
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113033
# Datos extraídos: ('Dinero sucio', '5,7', '', '', 'No disponible', 'tt0113033')
# Accediendo a la película con ID tt0113489
# Nombre de la película: Le journal du séducteur
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113489
# Datos extraídos: ('Le journal du séducteur', '6,8', '', '', 'No disponible', 'tt0113489')
# Accediendo a la película con ID tt0109827
# Nombre de la película: Foreign Bodies
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109827
# Datos extraídos: ('Foreign Bodies', '5,9', '', '', 'No disponible', 'tt0109827')
# Accediendo a la película con ID tt0110125
# Nombre de la película: The Cold Light of Day
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110125
# Datos extraídos: ('The Cold Light of Day', '6,2', '', '', 'No disponible', 'tt0110125')
# Accediendo a la película con ID tt0102267
# Nombre de la película: Lifebreath
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0102267
# Datos extraídos: ('Lifebreath', '5,4', '', '', 'No disponible', 'tt0102267')
# Accediendo a la película con ID tt0108233
# Nombre de la película: Strawberry Fields
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0108233
# Datos extraídos: ('Strawberry Fields', '6,5', '', '', 'No disponible', 'tt0108233')
# Accediendo a la película con ID tt0109136
# Nombre de la película: Annie's Garden
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0109136
# Datos extraídos: ("Annie's Garden", '4,8', '', '', 'No disponible', 'tt0109136')
# Accediendo a la película con ID tt0110331
# Nombre de la película: Lethal Seduction
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110331
# Datos extraídos: ('Lethal Seduction', '4,2', '', '', 'No disponible', 'tt0110331')
# Accediendo a la película con ID tt0111416
# Nombre de la película: This Is the Sea
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111416
# Datos extraídos: ('This Is the Sea', '6,1', '', '', 'No disponible', 'tt0111416')
# Accediendo a la película con ID tt0112974
# Nombre de la película: Alien Visitor
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112974
# Datos extraídos: ('Alien Visitor', '5,7', '', '', 'No disponible', 'tt0112974')
# Accediendo a la película con ID tt0111632
# Nombre de la película: Visidela
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0111632
# Datos extraídos: ('Visidela', '6,9', '', '', 'No disponible', 'tt0111632')
# Accediendo a la película con ID tt0108294
# Nombre de la película: Taranthriller
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0108294
# Datos extraídos: ('Taranthriller', '2,4', '', '', 'No disponible', 'tt0108294')
# Accediendo a la película con ID tt0112810
# Nombre de la película: Day at the Beach
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112810
# Datos extraídos: ('Day at the Beach', '5,9', '', '', 'No disponible', 'tt0112810')
# Accediendo a la película con ID tt0113513
# Nombre de la película: Kabel und Liebe
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113513
# Datos extraídos: ('Kabel und Liebe', '6,8', '', '', 'No disponible', 'tt0113513')
# Accediendo a la película con ID tt0113162
# Nombre de la película: Gettin' Up
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113162
# Datos extraídos: ("Gettin' Up", '3,0', '', '', 'No disponible', 'tt0113162')
# Accediendo a la película con ID tt0113646
# Nombre de la película: Lewis & Clark & George
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113646
# Datos extraídos: ('Lewis & Clark & George', '5,3', '', '', 'No disponible', 'tt0113646')
# Accediendo a la película con ID tt0113031
# Nombre de la película: Farmer & Chase
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113031
# Datos extraídos: ('Farmer & Chase', '5,0', '', '', 'No disponible', 'tt0113031')
# Accediendo a la película con ID tt0112629
# Nombre de la película: Atrapados
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112629
# Datos extraídos: ('Atrapados', '4,1', '', '', 'No disponible', 'tt0112629')
# Accediendo a la película con ID tt0112308
# Nombre de la película: Agnichakra
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112308
# Datos extraídos: ('Agnichakra', '2,8', '', '', 'No disponible', 'tt0112308')
# Accediendo a la película con ID tt0113067
# Nombre de la película: Tormenta de fuego
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113067
# Datos extraídos: ('Tormenta de fuego', '3,4', '', '', 'No disponible', 'tt0113067')
# Accediendo a la película con ID tt0115447
# Nombre de la película: A tres bandas
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115447
# Datos extraídos: ('A tres bandas', '5,8', '', '', 'No disponible', 'tt0115447')
# Accediendo a la película con ID tt0115647
# Nombre de la película: Código nuclear
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115647
# Datos extraídos: ('Código nuclear', '4,2', '', '', 'No disponible', 'tt0115647')
# Accediendo a la película con ID tt0115864
# Nombre de la película: Champions
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115864
# Datos extraídos: ('Champions', '3,8', '', '', 'No disponible', 'tt0115864')
# Accediendo a la película con ID tt0112856
# Nombre de la película: Las dos huérfanas vampiras
# Dirección: Jean Rollin
# Guionistas: Jean Rollin
# Argumento: A pair of teenage girls, who are blind by day, but when the sun goes down, they roam the streets to quench their thirst for blood.
# ID de la película: tt0112856
# Datos extraídos: ('Las dos huérfanas vampiras', '5,1', 'Jean Rollin', 'Jean Rollin', 'A pair of teenage girls, who are blind by day, but when the sun goes down, they roam the streets to quench their thirst for blood.', 'tt0112856')
# Accediendo a la película con ID tt0116960
# Nombre de la película: Magic in the Mirror: Fowl Play
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116960
# Datos extraídos: ('Magic in the Mirror: Fowl Play', '4,9', '', '', 'No disponible', 'tt0116960')
# Accediendo a la película con ID tt0115696
# Nombre de la película: Black Scorpion II: Aftershock
# Dirección: Jonathan Winfrey
# Guionistas: Craig J. Nevius
# Argumento: Darcy is back on the force, but still fights on as the Black Scorpion because "it's in her nature." This time, she fights Gangster Prankster; and a new villian emerges when the Mayor tries to protect his federal earthquake relief money: Aftershock. When the two villians team up and kidnap Argyle's girlfriend, Black Scorpion is faced with the theft of the Scorpionmobil... Leer todo
# ID de la película: tt0115696
# Datos extraídos: ('Black Scorpion II: Aftershock', '3,7', 'Jonathan Winfrey', 'Craig J. Nevius', 'Darcy is back on the force, but still fights on as the Black Scorpion because "it\'s in her nature." This time, she fights Gangster Prankster; and a new villian emerges when the Mayor tries to protect his federal earthquake relief money: Aftershock. When the two villians team up and kidnap Argyle\'s girlfriend, Black Scorpion is faced with the theft of the Scorpionmobil... Leer todo', 'tt0115696')
# Accediendo a la película con ID tt0117264
# Nombre de la película: A Ostra e o Vento
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0117264
# Datos extraídos: ('A Ostra e o Vento', '7,2', '', '', 'No disponible', 'tt0117264')
# Accediendo a la película con ID tt0118604
# Nombre de la película: Un hombre lobo americano en París
# Dirección: Anthony Waller
# Guionistas: John Landis, Tim Burns, Tom Stern
# Argumento: Un joven estadounidense establece contacto involuntariamente con hombres lobo franceses que han creado un suero que les permite transformarse cuando quieran.
# ID de la película: tt0118604
# Datos extraídos: ('Un hombre lobo americano en París', '5,1', 'Anthony Waller', 'John Landis, Tim Burns, Tom Stern', 'Un joven estadounidense establece contacto involuntariamente con hombres lobo franceses que han creado un suero que les permite transformarse cuando quieran.', 'tt0118604')
# Accediendo a la película con ID tt0116048
# Nombre de la película: Muerte inocente
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116048
# Datos extraídos: ('Muerte inocente', '5,2', '', '', 'No disponible', 'tt0116048')
# Accediendo a la película con ID tt0115813
# Nombre de la película: Historias de medianoche
# Dirección: Matt CooperMartin KunertDavid Semel
# Guionistas: Martin Kunert, Eric Manes, Matt Cooper
# Argumento: Un grupo de adolescentes se entretiene contando una antología de famosas leyendas urbanas con un toque moderno; incluyendo puntos de besos, monstruos, psicópatas y fantasmas.
# ID de la película: tt0115813
# Datos extraídos: ('Historias de medianoche', '5,8', 'Matt CooperMartin KunertDavid Semel', 'Martin Kunert, Eric Manes, Matt Cooper', 'Un grupo de adolescentes se entretiene contando una antología de famosas leyendas urbanas con un toque moderno; incluyendo puntos de besos, monstruos, psicópatas y fantasmas.', 'tt0115813')
# Accediendo a la película con ID tt0115584
# Nombre de la película: Perversión asesina
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115584
# Datos extraídos: ('Perversión asesina', '4,9', '', '', 'No disponible', 'tt0115584')
# Accediendo a la película con ID tt0116611
# Nombre de la película: Illicit Dreams 2
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116611
# Datos extraídos: ('Illicit Dreams 2', '3,7', '', '', 'No disponible', 'tt0116611')
# Accediendo a la película con ID tt0117041
# Nombre de la película: Midnight Blue
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0117041
# Datos extraídos: ('Midnight Blue', '4,7', '', '', 'No disponible', 'tt0117041')
# Accediendo a la película con ID tt0116922
# Nombre de la película: Carretera perdida
# Dirección: David Lynch
# Guionistas: David Lynch, Barry Gifford
# Argumento: Tras un extraño encuentro en una fiesta, un saxofonista de jazz se ve incriminado en el asesinato de su mujer y es enviado a prisión, donde inexplicablemente cambia de forma y se convierte en un joven mecánico.
# ID de la película: tt0116922
# Datos extraídos: ('Carretera perdida', '7,6', 'David Lynch', 'David Lynch, Barry Gifford', 'Tras un extraño encuentro en una fiesta, un saxofonista de jazz se ve incriminado en el asesinato de su mujer y es enviado a prisión, donde inexplicablemente cambia de forma y se convierte en un joven mecánico.', 'tt0116922')
# Accediendo a la película con ID tt0118713
# Nombre de la película: The Big Empty
# Dirección: Jack Perez
# Guionistas: James Mc, ManusJack Perez
# Argumento: A woman hires P.I. Lloyd Meadows to investigate her husband, a respectable social worker. What seemed to be a simple case of adultery turns into an ugly mess fast.
# ID de la película: tt0118713
# Datos extraídos: ('The Big Empty', '5,9', 'Jack Perez', 'James Mc, ManusJack Perez', 'A woman hires P.I. Lloyd Meadows to investigate her husband, a respectable social worker. What seemed to be a simple case of adultery turns into an ugly mess fast.', 'tt0118713')
# Accediendo a la película con ID tt0118886
# Nombre de la película: Convict 762
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118886
# Datos extraídos: ('Convict 762', '3,3', '', '', 'No disponible', 'tt0118886')
# Accediendo a la película con ID tt0114502
# Nombre de la película: Der Unfisch
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0114502
# Datos extraídos: ('Der Unfisch', '6,4', '', '', 'No disponible', 'tt0114502')
# Accediendo a la película con ID tt0115865
# Nombre de la película: Cambio de hábitos
# Dirección: Lynn Roth
# Guionistas: Scott Davis,  Jones
# Argumento: Una artista decide dejar atrás sus problemas con los hombres y los desalojos mudándose a un convento, para poder trabajar para ganarse la vida. ¿Es su arte una oportunidad para que las hermanas salven el convento del cierre?
# ID de la película: tt0115865
# Datos extraídos: ('Cambio de hábitos', '5,8', 'Lynn Roth', 'Scott Davis,  Jones', 'Una artista decide dejar atrás sus problemas con los hombres y los desalojos mudándose a un convento, para poder trabajar para ganarse la vida. ¿Es su arte una oportunidad para que las hermanas salven el convento del cierre?', 'tt0115865')
# Accediendo a la película con ID tt0115524
# Nombre de la película: Always Say Goodbye
# Dirección: Joshua Beckett
# Guionistas: Joshua Beckett
# Argumento: A sexy, free spirit meets her match in a photographer and serial bachelor. Both of them turn up the personal fires, but neither can commit. Starring Marcia Cross and Joshua Beckett.
# ID de la película: tt0115524
# Datos extraídos: ('Always Say Goodbye', '5,0', 'Joshua Beckett', 'Joshua Beckett', 'A sexy, free spirit meets her match in a photographer and serial bachelor. Both of them turn up the personal fires, but neither can commit. Starring Marcia Cross and Joshua Beckett.', 'tt0115524')
# Accediendo a la película con ID tt0116914
# Nombre de la película: Loose Women
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116914
# Datos extraídos: ('Loose Women', '4,4', '', '', 'No disponible', 'tt0116914')
# Accediendo a la película con ID tt0116193
# Nombre de la película: En brazos de la mujer madura
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116193
# Datos extraídos: ('En brazos de la mujer madura', '6,2', '', '', 'No disponible', 'tt0116193')
# Accediendo a la película con ID tt0116826
# Nombre de la película: Last Chance Love
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116826
# Datos extraídos: ('Last Chance Love', '4,9', '', '', 'No disponible', 'tt0116826')
# Accediendo a la película con ID tt0116577
# Nombre de la película: Hufters & Hofdames
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116577
# Datos extraídos: ('Hufters & Hofdames', '6,8', '', '', 'No disponible', 'tt0116577')
# Accediendo a la película con ID tt0112904
# Nombre de la película: Madera a la deriva
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112904
# Datos extraídos: ('Madera a la deriva', '5,4', '', '', 'No disponible', 'tt0112904')
# Accediendo a la película con ID tt0108098
# Nombre de la película: El pequeño ladrón de Ulan Bator
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0108098
# Datos extraídos: ('El pequeño ladrón de Ulan Bator', '6,5', '', '', 'No disponible', 'tt0108098')
# Accediendo a la película con ID tt0110404
# Nombre de la película: Luces de la noche
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110404
# Datos extraídos: ('Luces de la noche', '4,6', '', '', 'No disponible', 'tt0110404')
# Accediendo a la película con ID tt0112784
# Nombre de la película: La dame du jeu
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112784
# Datos extraídos: ('La dame du jeu', '7,0', '', '', 'No disponible', 'tt0112784')
# Accediendo a la película con ID tt0115005
# Nombre de la película: Xiu Xiu
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115005
# Datos extraídos: ('Xiu Xiu', '7,5', '', '', 'No disponible', 'tt0115005')
# Accediendo a la película con ID tt0115770
# Nombre de la película: The Brylcreem Boys
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115770
# Datos extraídos: ('The Brylcreem Boys', '6,2', '', '', 'No disponible', 'tt0115770')
# Accediendo a la película con ID tt0116202
# Nombre de la película: Enemy
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116202
# Datos extraídos: ('Enemy', '5,3', '', '', 'No disponible', 'tt0116202')
# Accediendo a la película con ID tt0116675
# Nombre de la película: Jaded
# Dirección: Caryn Krooth
# Guionistas: Wendy Olinger, Caryn Krooth
# Argumento: At the local bar, one drink leads to another, and Megan ends up skinny-dipping with Pat and Alex. And then, comes the rape. Now, she wants justice; but is she as innocent as she thinks? In the end, what really happened that fateful night?
# ID de la película: tt0116675
# Datos extraídos: ('Jaded', '5,4', 'Caryn Krooth', 'Wendy Olinger, Caryn Krooth', 'At the local bar, one drink leads to another, and Megan ends up skinny-dipping with Pat and Alex. And then, comes the rape. Now, she wants justice; but is she as innocent as she thinks? In the end, what really happened that fateful night?', 'tt0116675')
# Accediendo a la película con ID tt0116753
# Nombre de la película: Die kaukasische Nacht
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116753
# Datos extraídos: ('Die kaukasische Nacht', '8,0', '', '', 'No disponible', 'tt0116753')
# Accediendo a la película con ID tt0095469
# Nombre de la película: Ku jia tian xia
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0095469
# Datos extraídos: ('Ku jia tian xia', '6,3', '', '', 'No disponible', 'tt0095469')
# Accediendo a la película con ID tt0112901
# Nombre de la película: Drei Herren
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112901
# Datos extraídos: ('Drei Herren', '6,9', '', '', 'No disponible', 'tt0112901')
# Accediendo a la película con ID tt0118301
# Nombre de la película: Cláusula de escape
# Dirección: Alan Cohn
# Guionistas: Anthony Abrams, Adam Larson,  BroderMichael Traeger
# Argumento: Josh es estudioso, Cooper es vida más holgazán, contagia a Josh, y pronto están en peligro de reprobar. Pero una regla de la universidad le otorga un 10 a quienes hayan sufrido el trauma del suicidio de un compañero de cuarto.
# ID de la película: tt0118301
# Datos extraídos: ('Cláusula de escape', '6,0', 'Alan Cohn', 'Anthony Abrams, Adam Larson,  BroderMichael Traeger', 'Josh es estudioso, Cooper es vida más holgazán, contagia a Josh, y pronto están en peligro de reprobar. Pero una regla de la universidad le otorga un 10 a quienes hayan sufrido el trauma del suicidio de un compañero de cuarto.', 'tt0118301')
# Accediendo a la película con ID tt0118635
# Nombre de la película: Abril
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118635
# Datos extraídos: ('Abril', '6,9', '', '', 'No disponible', 'tt0118635')
# Accediendo a la película con ID tt0118863
# Nombre de la película: Demasiado profundo
# Dirección: David Dobkin
# Guionistas: Matthew L. Healy
# Argumento: After hearing that his wife sleeps with Clay, Earl kills himself, making it look like Clay shot him. The widow doesn't like it when Clay starts sees another woman instead. Bodies start piling up.
# ID de la película: tt0118863
# Datos extraídos: ('Demasiado profundo', '6,6', 'David Dobkin', 'Matthew L. Healy', "After hearing that his wife sleeps with Clay, Earl kills himself, making it look like Clay shot him. The widow doesn't like it when Clay starts sees another woman instead. Bodies start piling up.", 'tt0118863')
# Accediendo a la película con ID tt0118798
# Nombre de la película: Bulworth
# Dirección: Warren Beatty
# Guionistas: Warren Beatty, Jeremy Pikser
# Argumento: Un político liberal suicidamente desilusionado firma un contrato consigo mismo y aprovecha la oportunidad para ser francamente honesto con sus votantes, afectando a los ritmos y al discurso de la música y la cultura hip-hop.
# ID de la película: tt0118798
# Datos extraídos: ('Bulworth', '6,8', 'Warren Beatty', 'Warren Beatty, Jeremy Pikser', 'Un político liberal suicidamente desilusionado firma un contrato consigo mismo y aprovecha la oportunidad para ser francamente honesto con sus votantes, afectando a los ritmos y al discurso de la música y la cultura hip-hop.', 'tt0118798')
# Accediendo a la película con ID tt0118978
# Nombre de la película: Dieu seul me voit
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118978
# Datos extraídos: ('Dieu seul me voit', '6,9', '', '', 'No disponible', 'tt0118978')
# Accediendo a la película con ID tt0112340
# Nombre de la película: Amaneció de golpe
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0112340
# Datos extraídos: ('Amaneció de golpe', '5,8', '', '', 'No disponible', 'tt0112340')
# Accediendo a la película con ID tt0116737
# Nombre de la película: Kabhi Na Kabhi
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116737
# Datos extraídos: ('Kabhi Na Kabhi', '4,2', '', '', 'No disponible', 'tt0116737')
# Accediendo a la película con ID tt0118966
# Nombre de la película: Medidas desesperadas
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118966
# Datos extraídos: ('Medidas desesperadas', '6,1', '', '', 'No disponible', 'tt0118966')
# Accediendo a la película con ID tt0118782
# Nombre de la película: El espíritu de Brooklyn
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118782
# Datos extraídos: ('El espíritu de Brooklyn', '5,5', '', '', 'No disponible', 'tt0118782')
# Accediendo a la película con ID tt0118569
# Nombre de la película: Airboss II: Preemptive Strike
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118569
# Datos extraídos: ('Airboss II: Preemptive Strike', '3,5', '', '', 'No disponible', 'tt0118569')
# Accediendo a la película con ID tt0118956
# Nombre de la película: Deep Rising: El misterio de las profundidades
# Dirección: Stephen Sommers
# Guionistas: Stephen Sommers
# Argumento: Un grupo de secuestradores fuertemente armados aborda un lujoso transatlántico para saquearlo, solo para luchar contra una serie de criaturas marinas de gran tamaño, con tentáculos y devoradoras de hombres, que ya habían invadido el barco.
# ID de la película: tt0118956
# Datos extraídos: ('Deep Rising: El misterio de las profundidades', '6,1', 'Stephen Sommers', 'Stephen Sommers', 'Un grupo de secuestradores fuertemente armados aborda un lujoso transatlántico para saquearlo, solo para luchar contra una serie de criaturas marinas de gran tamaño, con tentáculos y devoradoras de hombres, que ya habían invadido el barco.', 'tt0118956')
# Accediendo a la película con ID tt0118869
# Nombre de la película: Juego mortal
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118869
# Datos extraídos: ('Juego mortal', '4,6', '', '', 'No disponible', 'tt0118869')
# Accediendo a la película con ID tt0118736
# Nombre de la película: Holocausto samurai
# Dirección: Lance Mungia
# Guionistas: Jeffrey Falcon, Lance Mungia
# Argumento: In the post-apocalyptic world of 1990s Nevada, a rock 'n' roll samurai on his way to Lost Vegas takes a young orphan boy under his protection as Death and his metalhead Horsemen chase after them.
# ID de la película: tt0118736
# Datos extraídos: ('Holocausto samurai', '6,4', 'Lance Mungia', 'Jeffrey Falcon, Lance Mungia', "In the post-apocalyptic world of 1990s Nevada, a rock 'n' roll samurai on his way to Lost Vegas takes a young orphan boy under his protection as Death and his metalhead Horsemen chase after them.", 'tt0118736')
# Accediendo a la película con ID tt0116943
# Nombre de la película: Lurid Tales: The Castle Queen
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116943
# Datos extraídos: ('Lurid Tales: The Castle Queen', '3,7', '', '', 'No disponible', 'tt0116943')
# Accediendo a la película con ID tt0115412
# Nombre de la película: Vino iz oduvanchikov
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115412
# Datos extraídos: ('Vino iz oduvanchikov', '7,1', '', '', 'No disponible', 'tt0115412')
# Accediendo a la película con ID tt0116727
# Nombre de la película: El chico de la selva
# Dirección: Allan A. Goldstein
# Guionistas: John Lawson, Damian Lee, Ashok Amritraj
# Argumento: A boy living harmoniously with animals in the jungles of India helps an archaeologist thwart a greedy treasure hunter.
# ID de la película: tt0116727
# Datos extraídos: ('El chico de la selva', '3,6', 'Allan A. Goldstein', 'John Lawson, Damian Lee, Ashok Amritraj', 'A boy living harmoniously with animals in the jungles of India helps an archaeologist thwart a greedy treasure hunter.', 'tt0116727')
# Accediendo a la película con ID tt0118621
# Nombre de la película: Animals with the Tollkeeper
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118621
# Datos extraídos: ('Animals with the Tollkeeper', '6,7', '', '', 'No disponible', 'tt0118621')
# Accediendo a la película con ID tt0118929
# Nombre de la película: Dark City
# Dirección: Alex Proyas
# Guionistas: Alex Proyas, Lem Dobbs, David S. Goyer
# Argumento: Un hombre lucha con los recuerdos de su pasado, que incluyen una esposa que no recuerda y un mundo de pesadilla del que nadie parece despertar.
# ID de la película: tt0118929
# Datos extraídos: ('Dark City', '7,6', 'Alex Proyas', 'Alex Proyas, Lem Dobbs, David S. Goyer', 'Un hombre lucha con los recuerdos de su pasado, que incluyen una esposa que no recuerda y un mundo de pesadilla del que nadie parece despertar.', 'tt0118929')
# Accediendo a la película con ID tt0118998
# Nombre de la película: Dr. Dolittle
# Dirección: Betty Thomas
# Guionistas: Hugh Lofting, Nat Mauldin, Larry Levin
# ...
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0117148
# Datos extraídos: ('Naisen logiikka', '3,3', '', '', 'No disponible', 'tt0117148')
# Accediendo a la película con ID tt0119936
# Nombre de la película: Predators from Beyond Neptune
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119936
# Datos extraídos: ('Predators from Beyond Neptune', '4,7', '', '', 'No disponible', 'tt0119936')
# Accediendo a la película con ID tt0119413
# Nombre de la película: Las bodas de Dios
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119413
# Datos extraídos: ('Las bodas de Dios', '7,2', '', '', 'No disponible', 'tt0119413')
# Accediendo a la película con ID tt0119163
# Nombre de la película: Full Blast
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119163
# Datos extraídos: ('Full Blast', '5,9', '', '', 'No disponible', 'tt0119163')
# Accediendo a la película con ID tt0118853
# Nombre de la película: Armageddon Boulevard
# Dirección: Donald G. JacksonScott Shaw
# Guionistas: Donald G. JacksonScott Shaw
# Argumento:
# ID de la película: tt0118853
# Datos extraídos: ('Armageddon Boulevard', '6,3', 'Donald G. JacksonScott Shaw', 'Donald G. JacksonScott Shaw', '', 'tt0118853')
# Accediendo a la película con ID tt0120784
# Nombre de la película: Payback
# Dirección: Brian Helgeland
# Guionistas: Donald E. WestlakeBrian Helgeland, Terry Hayes
# Argumento: Tras un exitoso atraco, Porter es dado por muerto. Una vez recuperado, busca venganza y quiere su parte del dinero.
# ID de la película: tt0120784
# Datos extraídos: ('Payback', '7,1', 'Brian Helgeland', 'Donald E. WestlakeBrian Helgeland, Terry Hayes', 'Tras un exitoso atraco, Porter es dado por muerto. Una vez recuperado, busca venganza y quiere su parte del dinero.', 'tt0120784')
# Accediendo a la película con ID tt0120435
# Nombre de la película: Velocity Trap
# Dirección: Phillip J. Roth
# Guionistas: Patrick Phillips, Phillip J. Roth
# Argumento: A cop framed for murder is the only one not in cryosleep when a team of thieves boards the armored treasury spaceship he's on to steal its load - 40 billion universal dollars - and then ram the ship into a comet to cover their tracks.
# ID de la película: tt0120435
# Datos extraídos: ('Velocity Trap', '4,5', 'Phillip J. Roth', 'Patrick Phillips, Phillip J. Roth', "A cop framed for murder is the only one not in cryosleep when a team of thieves boards the armored treasury spaceship he's on to steal its load - 40 billion universal dollars - and then ram the ship into a comet to cover their tracks.", 'tt0120435')
# Accediendo a la película con ID tt0120458
# Nombre de la película: Virus
# Dirección: John Bruno
# Guionistas: Chuck Pfarrer, Dennis Feldman
# Argumento: Cuando la tripulación de un remolcador estadounidense aborda un barco de investigación ruso abandonado, la forma de vida extraterrestre a bordo los considera un virus que debe ser destruido.
# ID de la película: tt0120458
# Datos extraídos: ('Virus', '5,0', 'John Bruno', 'Chuck Pfarrer, Dennis Feldman', 'Cuando la tripulación de un remolcador estadounidense aborda un barco de investigación ruso abandonado, la forma de vida extraterrestre a bordo los considera un virus que debe ser destruido.', 'tt0120458')
# Accediendo a la película con ID tt0120915
# Nombre de la película: Star Wars: Episodio I - La amenaza fantasma
# Dirección: George Lucas
# Guionistas: George Lucas
# Argumento: Dos caballeros jedi escapan de un bloqueo hostil para ir en busca de aliados y conocen a un joven que podría restaurar el equilibrio en la Fuerza. Pero los previamente inactivos sith resurgen para reclamar su antigua gloria.
# ID de la película: tt0120915
# Datos extraídos: ('Star Wars: Episodio I - La amenaza fantasma', '6,5', 'George Lucas', 'George Lucas', 'Dos caballeros jedi escapan de un bloqueo hostil para ir en busca de aliados y conocen a un joven que podría restaurar el equilibrio en la Fuerza. Pero los previamente inactivos sith resurgen para reclamar su antigua gloria.', 'tt0120915')
# Accediendo a la película con ID tt0118664
# Nombre de la película: Babel
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118664
# Datos extraídos: ('Babel', '3,6', '', '', 'No disponible', 'tt0118664')
# Accediendo a la película con ID tt0119751
# Nombre de la película: Nachtvlinder
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119751
# Datos extraídos: ('Nachtvlinder', '4,9', '', '', 'No disponible', 'tt0119751')
# Accediendo a la película con ID tt0120363
# Nombre de la película: Toy Story 2
# Dirección: John LasseterAsh BrannonLee Unkrich
# Guionistas: John Lasseter, Pete Docter, Ash Brannon
# Argumento: Cuando Woody es secuestrado por un coleccionista de juguetes, Buzz y sus amigos emprenden una misión de rescate, pero Woody encuentra tentadora la idea de ser inmortalizado en un museo.
# ID de la película: tt0120363
# Datos extraídos: ('Toy Story 2', '7,9', 'John LasseterAsh BrannonLee Unkrich', 'John Lasseter, Pete Docter, Ash Brannon', 'Cuando Woody es secuestrado por un coleccionista de juguetes, Buzz y sus amigos emprenden una misión de rescate, pero Woody encuentra tentadora la idea de ser inmortalizado en un museo.', 'tt0120363')
# Accediendo a la película con ID tt0120910
# Nombre de la película: Fantasía 2000
# Dirección: James AlgarGaëtan BrizziPaul Brizzi
# Guionistas: Eric Goldberg, James Fujii, Joe Grant
# Argumento: Actualización de la película original con nuevas interpretaciones de grandes obras de la música clásica.
# ID de la película: tt0120910
# Datos extraídos: ('Fantasía 2000', '7,1', 'James AlgarGaëtan BrizziPaul Brizzi', 'Eric Goldberg, James Fujii, Joe Grant', 'Actualización de la película original con nuevas interpretaciones de grandes obras de la música clásica.', 'tt0120910')
# Accediendo a la película con ID tt0120601
# Nombre de la película: Cómo ser John Malkovich
# Dirección: Spike Jonze
# Guionistas: Charlie Kaufman
# Argumento: Un titiritero descubre un portal que conduce literalmente al jefe de la estrella de cine John Malkovich.
# ID de la película: tt0120601
# Datos extraídos: ('Cómo ser John Malkovich', '7,7', 'Spike Jonze', 'Charlie Kaufman', 'Un titiritero descubre un portal que conduce literalmente al jefe de la estrella de cine John Malkovich.', 'tt0120601')
# Accediendo a la película con ID tt0120604
# Nombre de la película: Beowulf, la leyenda
# Dirección: Graham Baker
# Guionistas: AnonymousMark Leahy, David Chappe
# Argumento: En una tierra sitiada, Beowulf debe luchar contra la espantosa criatura Grendel y su madre que busca venganza.
# ID de la película: tt0120604
# Datos extraídos: ('Beowulf, la leyenda', '4,1', 'Graham Baker', 'AnonymousMark Leahy, David Chappe', 'En una tierra sitiada, Beowulf debe luchar contra la espantosa criatura Grendel y su madre que busca venganza.', 'tt0120604')
# Accediendo a la película con ID tt0120616
# Nombre de la película: The Mummy (La momia)
# Dirección: Stephen Sommers
# Guionistas: Stephen Sommers, Lloyd Fonvielle, Kevin Jarre
# Argumento: En una excavación arqueológica en la antigua ciudad de Hamunaptra, un estadounidense despierta accidentalmente a una momia que comienza a causar estragos mientras busca la reencarnación de su amor perdido.
# ID de la película: tt0120616
# Datos extraídos: ('The Mummy (La momia)', '7,1', 'Stephen Sommers', 'Stephen Sommers, Lloyd Fonvielle, Kevin Jarre', 'En una excavación arqueológica en la antigua ciudad de Hamunaptra, un estadounidense despierta accidentalmente a una momia que comienza a causar estragos mientras busca la reencarnación de su amor perdido.', 'tt0120616')
# Accediendo a la película con ID tt0119277
# Nombre de la película: Hellblock 13
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119277
# Datos extraídos: ('Hellblock 13', '4,1', '', '', 'No disponible', 'tt0119277')
# Accediendo a la película con ID tt0120361
# Nombre de la película: Townies
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120361
# Datos extraídos: ('Townies', '4,5', '', '', 'No disponible', 'tt0120361')
# Accediendo a la película con ID tt0121152
# Nombre de la película: The Coroner
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0121152
# Datos extraídos: ('The Coroner', '2,8', '', '', 'No disponible', 'tt0121152')
# Accediendo a la película con ID tt0120500
# Nombre de la película: La sombra del silencio
# Dirección: Allan A. Goldstein
# Guionistas: Tony Kayden
# Argumento: A detective (Jeff Fahey) investigating the murders of two sex offenders gets involved with a beautiful district attorney (Marlee Matlin), who becomes the main suspect.
# ID de la película: tt0120500
# Datos extraídos: ('La sombra del silencio', '4,6', 'Allan A. Goldstein', 'Tony Kayden', 'A detective (Jeff Fahey) investigating the murders of two sex offenders gets involved with a beautiful district attorney (Marlee Matlin), who becomes the main suspect.', 'tt0120500')
# Accediendo a la película con ID tt0120620
# Nombre de la película: Sueños rotos
# Dirección: Jonathan Kaplan
# Guionistas: Adam Fields, David Arata
# Argumento: Dos mujeres son arrestadas por contrabando durante sus vacaciones en Tailandia.
# ID de la película: tt0120620
# Datos extraídos: ('Sueños rotos', '6,4', 'Jonathan Kaplan', 'Adam Fields, David Arata', 'Dos mujeres son arrestadas por contrabando durante sus vacaciones en Tailandia.', 'tt0120620')
# Accediendo a la película con ID tt0123078
# Nombre de la película: Foreign Correspondents
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0123078
# Datos extraídos: ('Foreign Correspondents', '6,2', '', '', 'No disponible', 'tt0123078')
# Accediendo a la película con ID tt0120663
# Nombre de la película: Eyes Wide Shut
# Dirección: Stanley Kubrick
# Guionistas: Stanley Kubrick, Frederic Raphael, Arthur Schnitzler
# Argumento: Un médico de la ciudad de Nueva York se embarca en una angustiosa odisea nocturna de descubrimiento sexual y moral después de que su esposa le revele un doloroso secreto.
# ID de la película: tt0120663
# Datos extraídos: ('Eyes Wide Shut', '7,5', 'Stanley Kubrick', 'Stanley Kubrick, Frederic Raphael, Arthur Schnitzler', 'Un médico de la ciudad de Nueva York se embarca en una angustiosa odisea nocturna de descubrimiento sexual y moral después de que su esposa le revele un doloroso secreto.', 'tt0120663')
# Accediendo a la película con ID tt0120662
# Nombre de la película: Ojos que te acechan
# Dirección: Stephan Elliott
# Guionistas: Marc Behm, Stephan Elliott
# Argumento: Un experto en espionaje trabaja para los servicios secretos cuando una mujer mata a uno de los sujetos que está custodiando. En lugar de denunciar el hecho, el hombre acaba enamorándose de ella.
# ID de la película: tt0120662
# Datos extraídos: ('Ojos que te acechan', '5,0', 'Stephan Elliott', 'Marc Behm, Stephan Elliott', 'Un experto en espionaje trabaja para los servicios secretos cuando una mujer mata a uno de los sujetos que está custodiando. En lugar de denunciar el hecho, el hombre acaba enamorándose de ella.', 'tt0120662')
# Accediendo a la película con ID tt0120689
# Nombre de la película: La milla verde
# Dirección: Frank Darabont
# Guionistas: Stephen King, Frank Darabont
# Argumento: Las vidas de los guardias del corredor de la muerte se ven afectadas por uno de sus reclusos: un hombre negro acusado de asesinato y violación de niños, pero que tiene un misterioso don.
# ID de la película: tt0120689
# Datos extraídos: ('La milla verde', '8,6', 'Frank Darabont', 'Stephen King, Frank Darabont', 'Las vidas de los guardias del corredor de la muerte se ven afectadas por uno de sus reclusos: un hombre negro acusado de asesinato y violación de niños, pero que tiene un misterioso don.', 'tt0120689')
# Accediendo a la película con ID tt0120798
# Nombre de la película: ...Quando Troveja
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120798
# Datos extraídos: ('...Quando Troveja', '5,5', '', '', 'No disponible', 'tt0120798')
# Accediendo a la película con ID tt0120834
# Nombre de la película: Mientras nieva sobre los cedros
# Dirección: Scott Hicks
# Guionistas: David Guterson, Ron Bass, Scott Hicks
# Argumento: Un japonés es acusado del asesinato de un pescador. Durante el juicio, el periodista que se encarga de efectuar la cobertura del proceso, reconoce a la esposa del acusado, su gran amor de juventud interrumpido cuando estalló la S.G.M.
# ID de la película: tt0120834
# Datos extraídos: ('Mientras nieva sobre los cedros', '6,7', 'Scott Hicks', 'David Guterson, Ron Bass, Scott Hicks', 'Un japonés es acusado del asesinato de un pescador. Durante el juicio, el periodista que se encarga de efectuar la cobertura del proceso, reconoce a la esposa del acusado, su gran amor de juventud interrumpido cuando estalló la S.G.M.', 'tt0120834')
# Accediendo a la película con ID tt0120907
# Nombre de la película: eXistenZ
# Dirección: David Cronenberg
# Guionistas: David Cronenberg
# Argumento: Una diseñadora de videojuegos que se esconde de unos asesinos tiene que jugar su última creación de realidad virtual con un aprendiz de marketing para ver si el juego ha sido dañado.
# ID de la película: tt0120907
# Datos extraídos: ('eXistenZ', '6,8', 'David Cronenberg', 'David Cronenberg', 'Una diseñadora de videojuegos que se esconde de unos asesinos tiene que jugar su última creación de realidad virtual con un aprendiz de marketing para ver si el juego ha sido dañado.', 'tt0120907')
# Accediendo a la película con ID tt0119079
# Nombre de la película: Onegin
# Dirección: Martha Fiennes
# Guionistas: Peter Ettedgui, Alexander Pushkin, Michael Ignatieff
# Argumento: Onegin hereda la finca de su tío y se muda allí desde San Petersburgo. Se hace amigo de su vecino, Lensky, y conoce a Tatyana a través de él. Ella se enamora de Onegin pero él solo quiere amistad.
# ID de la película: tt0119079
# Datos extraídos: ('Onegin', '6,8', 'Martha Fiennes', 'Peter Ettedgui, Alexander Pushkin, Michael Ignatieff', 'Onegin hereda la finca de su tío y se muda allí desde San Petersburgo. Se hace amigo de su vecino, Lensky, y conoce a Tatyana a través de él. Ella se enamora de Onegin pero él solo quiere amistad.', 'tt0119079')
# Accediendo a la película con ID tt0119740
# Nombre de la película: My Girlfriend's Boyfriend
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119740
# Datos extraídos: ("My Girlfriend's Boyfriend", '4,9', '', '', 'No disponible', 'tt0119740')
# Accediendo a la película con ID tt0122541
# Nombre de la película: Un marido ideal
# Dirección: Oliver Parker
# Guionistas: Oscar Wilde, Oliver Parker
# Argumento: Londres, 1895: El ministro del gabinete, Sir Chiltern, y el soltero, Lord Goring, son víctimas de mujeres confabuladoras.
# ID de la película: tt0122541
# Datos extraídos: ('Un marido ideal', '6,8', 'Oliver Parker', 'Oscar Wilde, Oliver Parker', 'Londres, 1895: El ministro del gabinete, Sir Chiltern, y el soltero, Lord Goring, son víctimas de mujeres confabuladoras.', 'tt0122541')
# Accediendo a la película con ID tt0117617
# Nombre de la película: Pasión salvaje
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0117617
# Datos extraídos: ('Pasión salvaje', '3,6', '', '', 'No disponible', 'tt0117617')
# Accediendo a la película con ID tt0119705
# Nombre de la película: Morella
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119705
# Datos extraídos: ('Morella', '3,6', '', '', 'No disponible', 'tt0119705')
# Accediendo a la película con ID tt0119208
# Nombre de la película: Godmoney
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119208
# Datos extraídos: ('Godmoney', '4,5', '', '', 'No disponible', 'tt0119208')
# Accediendo a la película con ID tt0119786
# Nombre de la película: Night of the Coyote
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119786
# Datos extraídos: ('Night of the Coyote', '8,1', '', '', 'No disponible', 'tt0119786')
# Accediendo a la película con ID tt0120416
# Nombre de la película: Dementia
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120416
# Datos extraídos: ('Dementia', '4,4', '', '', 'No disponible', 'tt0120416')

# %%
# Guardar el DataFrame en un nuevo archivo CSV
df_peliculas.to_csv('peliculas_ext_sel_1995_1999.csv', index=False)
print("Archivo 'peliculas_ext_sel_1995_1999.csv' creado exitosamente.")
# Out:
# Archivo 'peliculas_ext_sel_1995_1999.csv' creado exitosamente.

# %%
#Peliculas de 2000 a 2004:

ids_peliculas = extractor_idowners('peliculas_2000_2004.csv')

# Crear el driver de Selenium
mi_driver = generar_driver()

# Lista para almacenar los datos extraídos
datos_peliculas = []

# Bucle para recorrer todos los IDs Owners y extraer la información
for id_owner in ids_peliculas:
    mis_datos = extraer_datos_pelicula(mi_driver, id_owner)
    datos_peliculas.append(mis_datos)

# Cerrar el driver después de la extracción
mi_driver.quit()

# Convertir los datos extraídos a un DataFrame
df_peliculas = pd.DataFrame(datos_peliculas, columns=["Título", "Puntuación IMDb", "Directores", "Guionistas", "Argumento", "ID"])
# Out:
# Maximizando la web.
# Accediendo a la web.
# Cookies aceptadas.
# Accediendo a la película con ID tt0102362
# Nombre de la película: Istota
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0102362
# Datos extraídos: ('Istota', '6,3', '', '', 'No disponible', 'tt0102362')
# Accediendo a la película con ID tt0113092
# Nombre de la película: Por la causa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113092
# Datos extraídos: ('Por la causa', '3,4', '', '', 'No disponible', 'tt0113092')
# Accediendo a la película con ID tt0113086
# Nombre de la película: Florentino y el diablo
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0113086
# Datos extraídos: ('Florentino y el diablo', '7,0', '', '', 'No disponible', 'tt0113086')
# Accediendo a la película con ID tt0116748
# Nombre de la película: Karobaar: The Business of Love
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116748
# Datos extraídos: ('Karobaar: The Business of Love', '3,7', '', '', 'No disponible', 'tt0116748')
# Accediendo a la película con ID tt0116391
# Nombre de la película: Gang
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116391
# Datos extraídos: ('Gang', '6,3', '', '', 'No disponible', 'tt0116391')
# Accediendo a la película con ID tt0115937
# Nombre de la película: Consequence
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0115937
# Datos extraídos: ('Consequence', '7,7', '', '', 'No disponible', 'tt0115937')
# Accediendo a la película con ID tt0118694
# Nombre de la película: Deseando amar
# Dirección: Kar-Wai Wong
# Guionistas: Kar-Wai Wong
# Argumento: Dos vecinos forman un fuerte vínculo después de que ambos sospechen de actividades extramatrimoniales de sus cónyuges. Sin embargo, acuerdan mantener su vínculo platónico para no cometer errores similares.
# ID de la película: tt0118694
# Datos extraídos: ('Deseando amar', '8,1', 'Kar-Wai Wong', 'Kar-Wai Wong', 'Dos vecinos forman un fuerte vínculo después de que ambos sospechen de actividades extramatrimoniales de sus cónyuges. Sin embargo, acuerdan mantener su vínculo platónico para no cometer errores similares.', 'tt0118694')
# Accediendo a la película con ID tt0119495
# Nombre de la película: Love 101
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119495
# Datos extraídos: ('Love 101', '5,1', '', '', 'No disponible', 'tt0119495')
# Accediendo a la película con ID tt0119806
# Nombre de la película: Nothing Sacred
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119806
# Datos extraídos: ('Nothing Sacred', '5,8', '', '', 'No disponible', 'tt0119806')
# Accediendo a la película con ID tt0120202
# Nombre de la película: State and Main
# Dirección: David Mamet
# Guionistas: David Mamet
# Argumento: A movie crew invades a small town whose residents are all too ready to give up their values for showbiz glitz.
# ID de la película: tt0120202
# Datos extraídos: ('State and Main', '6,7', 'David Mamet', 'David Mamet', 'A movie crew invades a small town whose residents are all too ready to give up their values for showbiz glitz.', 'tt0120202')
# Accediendo a la película con ID tt0123003
# Nombre de la película: Bruno
# Dirección: Shirley MacLaine
# Guionistas: David Ciminello
# Argumento: Bruno es un joven genio único, cuya expresión de su propia individualidad lleva a su familia y comunidad a lo largo de un viaje emocional.
# ID de la película: tt0123003
# Datos extraídos: ('Bruno', '6,0', 'Shirley MacLaine', 'David Ciminello', 'Bruno es un joven genio único, cuya expresión de su propia individualidad lleva a su familia y comunidad a lo largo de un viaje emocional.', 'tt0123003')
# Accediendo a la película con ID tt0120263
# Nombre de la película: Canciones del segundo piso
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120263
# Datos extraídos: ('Canciones del segundo piso', '7,5', '', '', 'No disponible', 'tt0120263')
# Accediendo a la película con ID tt0123055
# Nombre de la película: The Elf Who Didn't Believe
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0123055
# Datos extraídos: ("The Elf Who Didn't Believe", '3,8', '', '', 'No disponible', 'tt0123055')
# Accediendo a la película con ID tt0120630
# Nombre de la película: Chicken Run: Evasión en la granja
# Dirección: Peter LordNick Park
# Guionistas: Peter Lord, Nick Park, Karey Kirkpatrick
# Argumento: Cuando un gallo entra aparentemente volando en una granja de pollos, las gallinas lo ven como una oportunidad para escapar de sus malvados dueños.
# ID de la película: tt0120630
# Datos extraídos: ('Chicken Run: Evasión en la granja', '7,1', 'Peter LordNick Park', 'Peter Lord, Nick Park, Karey Kirkpatrick', 'Cuando un gallo entra aparentemente volando en una granja de pollos, las gallinas lo ven como una oportunidad para escapar de sus malvados dueños.', 'tt0120630')
# Accediendo a la película con ID tt0116628
# Nombre de la película: Sociedad anónima
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0116628
# Datos extraídos: ('Sociedad anónima', '6,3', '', '', 'No disponible', 'tt0116628')
# Accediendo a la película con ID tt0119273
# Nombre de la película: Heavy Metal 2
# Dirección: Michael ColdeweyMichel Lemire
# Guionistas: Kevin Eastman, Simon Bisley, Eric Talbot
# Argumento: After surviving an invasion on her peaceful homeworld, a beautiful avenger must stop a powerful psychopath from gaining immortality and rescue her kidnapped sister.
# ID de la película: tt0119273
# Datos extraídos: ('Heavy Metal 2', '5,4', 'Michael ColdeweyMichel Lemire', 'Kevin Eastman, Simon Bisley, Eric Talbot', 'After surviving an invasion on her peaceful homeworld, a beautiful avenger must stop a powerful psychopath from gaining immortality and rescue her kidnapped sister.', 'tt0119273')
# Accediendo a la película con ID tt0120755
# Nombre de la película: Misión: Imposible 2
# Dirección: John Woo
# Guionistas: Bruce Geller, Ronald D. MooreBrannon Braga
# Argumento: "El agente del FMI Ethan Hunt es enviado a Sydney, para encontrar y destruir una enfermedad genéticamente modificada llamada ""Quimera""."
# ID de la película: tt0120755
# Datos extraídos: ('Misión: Imposible 2', '6,1', 'John Woo', 'Bruce Geller, Ronald D. MooreBrannon Braga', '"El agente del FMI Ethan Hunt es enviado a Sydney, para encontrar y destruir una enfermedad genéticamente modificada llamada ""Quimera""."', 'tt0120755')
# Accediendo a la película con ID tt0120913
# Nombre de la película: Titan A.E.
# Dirección: Don BluthGary Goldman
# Guionistas: Hans Bauer, Randall Mc, CormickBen Edlund
# Argumento: Un joven descubre que tiene que encontrar una nave terrestre oculta antes que una especie alienígena enemiga para asegurar la supervivencia de la humanidad.
# ID de la película: tt0120913
# Datos extraídos: ('Titan A.E.', '6,6', 'Don BluthGary Goldman', 'Hans Bauer, Randall Mc, CormickBen Edlund', 'Un joven descubre que tiene que encontrar una nave terrestre oculta antes que una especie alienígena enemiga para asegurar la supervivencia de la humanidad.', 'tt0120913')
# Accediendo a la película con ID tt0120673
# Nombre de la película: Foiled
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120673
# Datos extraídos: ('Foiled', '6,6', '', '', 'No disponible', 'tt0120673')
# Accediendo a la película con ID tt0120903
# Nombre de la película: X-Men
# Dirección: Bryan Singer
# Guionistas: Tom De, SantoBryan Singer, David Hayter
# Argumento: En un mundo donde los mutantes (humanos superpoderosos evolucionados) existen y son discriminados, dos grupos se forman para un choque inevitable: la supremacista Hermandad y los pacifistas X-Men.
# ID de la película: tt0120903
# Datos extraídos: ('X-Men', '7,3', 'Bryan Singer', 'Tom De, SantoBryan Singer, David Hayter', 'En un mundo donde los mutantes (humanos superpoderosos evolucionados) existen y son discriminados, dos grupos se forman para un choque inevitable: la supremacista Hermandad y los pacifistas X-Men.', 'tt0120903')
# Accediendo a la película con ID tt0120917
# Nombre de la película: El emperador y sus locuras
# Dirección: Mark Dindal
# Guionistas: Chris Williams, Mark Dindal, David Reynolds
# Argumento: El emperador Kuzco fue convertido en una llama por su exadministradora Yzma, y ahora debe recuperar su trono con la ayuda de Pacha, un amable pastor de llamas.
# ID de la película: tt0120917
# Datos extraídos: ('El emperador y sus locuras', '7,4', 'Mark Dindal', 'Chris Williams, Mark Dindal, David Reynolds', 'El emperador Kuzco fue convertido en una llama por su exadministradora Yzma, y ahora debe recuperar su trono con la ayuda de Pacha, un amable pastor de llamas.', 'tt0120917')
# Accediendo a la película con ID tt0130623
# Nombre de la película: Dinosaurio
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0130623
# Datos extraídos: ('Dinosaurio', '6,4', '', '', 'No disponible', 'tt0130623')
# Accediendo a la película con ID tt0132910
# Nombre de la película: El Cuervo: Salvación
# Dirección: Bharat Nalluri
# Guionistas: James O'BarrChip Johannessen
# Argumento: Alex Corvis returns to the world of the living to solve the murder of a young woman that he was wrongly accused of.
# ID de la película: tt0132910
# Datos extraídos: ('El Cuervo: Salvación', '4,9', 'Bharat Nalluri', "James O'BarrChip Johannessen", 'Alex Corvis returns to the world of the living to solve the murder of a young woman that he was wrongly accused of.', 'tt0132910')
# Accediendo a la película con ID tt0131704
# Nombre de la película: Las aventuras de Rocky y Bullwinkle
# Dirección: Des McAnuff
# Guionistas: Jay Ward, Kenneth Lonergan
# Argumento: Cuando los enemigos Boris, Natasha y Líder Temerario escapan al mundo real con un plan nefasto, Rocky y Bullwinkle hacen lo mismo, y se unen a un joven agente del FBI para detener al trío.
# ID de la película: tt0131704
# Datos extraídos: ('Las aventuras de Rocky y Bullwinkle', '4,3', 'Des McAnuff', 'Jay Ward, Kenneth Lonergan', 'Cuando los enemigos Boris, Natasha y Líder Temerario escapan al mundo real con un plan nefasto, Rocky y Bullwinkle hacen lo mismo, y se unen a un joven agente del FBI para detener al trío.', 'tt0131704')
# Accediendo a la película con ID tt0138749
# Nombre de la película: La ruta hacia El Dorado
# Dirección: Bibo BergeronDon PaulJeffrey Katzenberg
# Guionistas: Ted Elliott, Terry Rossio, Karey Kirkpatrick
# Argumento: Dos estafadores consiguen un mapa que les llevará a la famosa ciudad de oro, El Dorado.
# ID de la película: tt0138749
# Datos extraídos: ('La ruta hacia El Dorado', '6,9', 'Bibo BergeronDon PaulJeffrey Katzenberg', 'Ted Elliott, Terry Rossio, Karey Kirkpatrick', 'Dos estafadores consiguen un mapa que les llevará a la famosa ciudad de oro, El Dorado.', 'tt0138749')
# Accediendo a la película con ID tt0144964
# Nombre de la película: Los inmortales: Juego final
# Dirección: Douglas Aarniokoski
# Guionistas: Gregory Widen, Eric Bernt, Gillian Horvath
# Argumento: Los inmortales Connor y Duncan MacLeod deben unir sus fuerzas contra Kell, un inmortal malvado que es demasiado fuerte para que nadie se le enfrente solo.
# ID de la película: tt0144964
# Datos extraídos: ('Los inmortales: Juego final', '4,6', 'Douglas Aarniokoski', 'Gregory Widen, Eric Bernt, Gillian Horvath', 'Los inmortales Connor y Duncan MacLeod deben unir sus fuerzas contra Kell, un inmortal malvado que es demasiado fuerte para que nadie se le enfrente solo.', 'tt0144964')
# Accediendo a la película con ID tt0144574
# Nombre de la película: Red Lipstick
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0144574
# Datos extraídos: ('Red Lipstick', '6,5', '', '', 'No disponible', 'tt0144574')
# Accediendo a la película con ID tt0146984
# Nombre de la película: La leyenda de Bagger Vance
# Dirección: Robert Redford
# Guionistas: Steven Pressfield, Jeremy Leven
# Argumento: Un golfista venido a menos intenta recuperar su juego y su vida con la ayuda de un cadi místico.
# ID de la película: tt0146984
# Datos extraídos: ('La leyenda de Bagger Vance', '6,7', 'Robert Redford', 'Steven Pressfield, Jeremy Leven', 'Un golfista venido a menos intenta recuperar su juego y su vida con la ayuda de un cadi místico.', 'tt0146984')
# Accediendo a la película con ID tt0128158
# Nombre de la película: Deadfall
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0128158
# Datos extraídos: ('Deadfall', '4,9', '', '', 'No disponible', 'tt0128158')
# Accediendo a la película con ID tt0134084
# Nombre de la película: Scream 3
# Dirección: Wes Craven
# Guionistas: Kevin Williamson, Ehren Kruger
# Argumento: Mientras Sidney y sus amigos visitan el set de Hollywood de Apuñalada 3, la tercera película basada en los asesinatos de Woodsboro, otro asesino, Ghostface, se presenta para aterrorizarlos.
# ID de la película: tt0134084
# Datos extraídos: ('Scream 3', '5,7', 'Wes Craven', 'Kevin Williamson, Ehren Kruger', 'Mientras Sidney y sus amigos visitan el set de Hollywood de Apuñalada 3, la tercera película basada en los asesinatos de Woodsboro, otro asesino, Ghostface, se presenta para aterrorizarlos.', 'tt0134084')
# Accediendo a la película con ID tt0134983
# Nombre de la película: Supernova (El fin del universo)
# Dirección: Walter HillFrancis Ford CoppolaJack Sholder
# Guionistas: William Malone, Daniel Chuba, David C. Wilson
# Argumento: La crónica de una operación de búsqueda y rescate por una nave interestelar médica con seis tripulantes en el siglo XXII.
# ID de la película: tt0134983
# Datos extraídos: ('Supernova (El fin del universo)', '4,8', 'Walter HillFrancis Ford CoppolaJack Sholder', 'William Malone, Daniel Chuba, David C. Wilson', 'La crónica de una operación de búsqueda y rescate por una nave interestelar médica con seis tripulantes en el siglo XXII.', 'tt0134983')
# Accediendo a la película con ID tt0134847
# Nombre de la película: Pitch Black
# Dirección: David Twohy
# Guionistas: Jim Wheat, Ken Wheat, David Twohy
# Argumento: Una nave comercial y su tripulación quedan aislados en un planeta lleno de criaturas sedientas de sangre que cazan de noche.
# ID de la película: tt0134847
# Datos extraídos: ('Pitch Black', '7,0', 'David Twohy', 'Jim Wheat, Ken Wheat, David Twohy', 'Una nave comercial y su tripulación quedan aislados en un planeta lleno de criaturas sedientas de sangre que cazan de noche.', 'tt0134847')
# Accediendo a la película con ID tt0137115
# Nombre de la película: Mothman
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0137115
# Datos extraídos: ('Mothman', '7,2', '', '', 'No disponible', 'tt0137115')
# Accediendo a la película con ID tt0144084
# Nombre de la película: American Psycho
# Dirección: Mary Harron
# Guionistas: Bret Easton,  EllisMary Harron, Guinevere Turner
# Argumento: Patrick Bateman, un rico ejecutivo de banca de inversión de Nueva York, esconde su ego psicopático alternativo de sus compañeros de trabajo y amigos al tiempo que profundiza en sus violentas fantasías hedonistas.
# ID de la película: tt0144084
# Datos extraídos: ('American Psycho', '7,6', 'Mary Harron', 'Bret Easton,  EllisMary Harron, Guinevere Turner', 'Patrick Bateman, un rico ejecutivo de banca de inversión de Nueva York, esconde su ego psicopático alternativo de sus compañeros de trabajo y amigos al tiempo que profundiza en sus violentas fantasías hedonistas.', 'tt0144084')
# Accediendo a la película con ID tt0148120
# Nombre de la película: Eyes to Heaven
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0148120
# Datos extraídos: ('Eyes to Heaven', '6,8', '', '', 'No disponible', 'tt0148120')
# Accediendo a la película con ID tt0156020
# Nombre de la película: Ricky 6
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0156020
# Datos extraídos: ('Ricky 6', '6,0', '', '', 'No disponible', 'tt0156020')
# Accediendo a la película con ID tt0120753
# Nombre de la película: The Million Dollar Hotel
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120753
# Datos extraídos: ('The Million Dollar Hotel', '5,7', '', '', 'No disponible', 'tt0120753')
# Accediendo a la película con ID tt0127349
# Nombre de la película: Resucitar un amor
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0127349
# Datos extraídos: ('Resucitar un amor', '6,4', '', '', 'No disponible', 'tt0127349')
# Accediendo a la película con ID tt0160495
# Nombre de la película: Luckytown blues
# Dirección: Paul Nicholas
# Guionistas: Brendan Beseth
# Argumento: Kirsten Dunst plays a young woman (Lidda), who is searching for her father (James Caan). She finds herself at odds with her boyfriend who wants nothing but a carefree lifestyle.
# ID de la película: tt0160495
# Datos extraídos: ('Luckytown blues', '4,7', 'Paul Nicholas', 'Brendan Beseth', 'Kirsten Dunst plays a young woman (Lidda), who is searching for her father (James Caan). She finds herself at odds with her boyfriend who wants nothing but a carefree lifestyle.', 'tt0160495')
# Accediendo a la película con ID tt0160644
# Nombre de la película: Pasión por vivir
# Dirección: Alain Berliner
# Guionistas: Ron Bass, David Field
# Argumento: A psychological romantic thriller where fantasy and reality become indistinguishable for a woman leading a double life in her dreams.
# ID de la película: tt0160644
# Datos extraídos: ('Pasión por vivir', '5,5', 'Alain Berliner', 'Ron Bass, David Field', 'A psychological romantic thriller where fantasy and reality become indistinguishable for a woman leading a double life in her dreams.', 'tt0160644')
# Accediendo a la película con ID tt0160289
# Nombre de la película: Muerte a la carta
# Dirección: Paul Rachman
# Guionistas: Shawn David,  ThompsonWilliam Quist
# Argumento: Four friends steal a valuable statuette for a dangerous black market art dealer, lose it, and are forced to play a deadly bluffing game to save their lives.
# ID de la película: tt0160289
# Datos extraídos: ('Muerte a la carta', '5,5', 'Paul Rachman', 'Shawn David,  ThompsonWilliam Quist', 'Four friends steal a valuable statuette for a dangerous black market art dealer, lose it, and are forced to play a deadly bluffing game to save their lives.', 'tt0160289')
# Accediendo a la película con ID tt0161081
# Nombre de la película: Lo que la verdad esconde
# Dirección: Robert Zemeckis
# Guionistas: Clark Gregg, Sarah Kernochan
# Argumento: La esposa de un investigador universitario cree que su casa en el lago de Vermont está embrujada por un fantasma, o que está perdiendo la cabeza.
# ID de la película: tt0161081
# Datos extraídos: ('Lo que la verdad esconde', '6,6', 'Robert Zemeckis', 'Clark Gregg, Sarah Kernochan', 'La esposa de un investigador universitario cree que su casa en el lago de Vermont está embrujada por un fantasma, o que está perdiendo la cabeza.', 'tt0161081')
# Accediendo a la película con ID tt0162711
# Nombre de la película: Trixie
# Dirección: Alan Rudolph
# Guionistas: Alan Rudolph, John Binder
# Argumento: An eccentric, unconventional woman whose naive aspirations to rise from her job as a security guard to full-fledged private eye lead her into a tangled PL: mess.
# ID de la película: tt0162711
# Datos extraídos: ('Trixie', '4,9', 'Alan Rudolph', 'Alan Rudolph, John Binder', 'An eccentric, unconventional woman whose naive aspirations to rise from her job as a security guard to full-fledged private eye lead her into a tangled PL: mess.', 'tt0162711')
# Accediendo a la película con ID tt0113026
# Nombre de la película: The Fantasticks
# Dirección: Michael Ritchie
# Guionistas: Tom Jones, Harvey Schmidt
# Argumento: A mysterious fair that comes to a small community in the countryside could make real the illusions of two teenagers.
# ID de la película: tt0113026
# Datos extraídos: ('The Fantasticks', '5,6', 'Michael Ritchie', 'Tom Jones, Harvey Schmidt', 'A mysterious fair that comes to a small community in the countryside could make real the illusions of two teenagers.', 'tt0113026')
# Accediendo a la película con ID tt0119866
# Nombre de la película: Passionnément
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119866
# Datos extraídos: ('Passionnément', '5,4', '', '', 'No disponible', 'tt0119866')
# Accediendo a la película con ID tt0122459
# Nombre de la película: Hechizo del corazón
# Dirección: Bonnie Hunt
# Guionistas: Bonnie Hunt, Don Lake, Andrew Stern
# Argumento: A man who falls in love with the woman who received his wife's heart must decide which woman it is who holds his heart.
# ID de la película: tt0122459
# Datos extraídos: ('Hechizo del corazón', '6,9', 'Bonnie Hunt', 'Bonnie Hunt, Don Lake, Andrew Stern', "A man who falls in love with the woman who received his wife's heart must decide which woman it is who holds his heart.", 'tt0122459')
# Accediendo a la película con ID tt0119966
# Nombre de la película: Pushing the Envelope
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119966
# Datos extraídos: ('Pushing the Envelope', '6,6', '', '', 'No disponible', 'tt0119966')
# Accediendo a la película con ID tt0120467
# Nombre de la película: Vulgar
# Dirección: Bryan Johnson
# Guionistas: Bryan Johnson
# Argumento: A man who performs as a children's birthday party clown tries to piece his life back together after being gang-raped.
# ID de la película: tt0120467
# Datos extraídos: ('Vulgar', '5,2', 'Bryan Johnson', 'Bryan Johnson', "A man who performs as a children's birthday party clown tries to piece his life back together after being gang-raped.", 'tt0120467')
# Accediendo a la película con ID tt0122161
# Nombre de la película: Falsa inocencia
# Dirección: Kikuo Kawasaki
# Guionistas: Kikuo Kawasaki
# Argumento: The entangled stories around the life of Elsie Taryn Townsendz, who becomes rich from being a country town's girl.
# ID de la película: tt0122161
# Datos extraídos: ('Falsa inocencia', '4,9', 'Kikuo Kawasaki', 'Kikuo Kawasaki', "The entangled stories around the life of Elsie Taryn Townsendz, who becomes rich from being a country town's girl.", 'tt0122161')
# Accediendo a la película con ID tt0120117
# Nombre de la película: Shikari
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120117
# Datos extraídos: ('Shikari', '4,6', '', '', 'No disponible', 'tt0120117')
# Accediendo a la película con ID tt0120698
# Nombre de la película: Traición inminente
# Dirección: Keoni Waxman
# Guionistas: Richard Beattie
# Argumento: A dark, comedic thriller about fraud, bank robbers, and a search for love.
# ID de la película: tt0120698
# Datos extraídos: ('Traición inminente', '4,4', 'Keoni Waxman', 'Richard Beattie', 'A dark, comedic thriller about fraud, bank robbers, and a search for love.', 'tt0120698')
# Accediendo a la película con ID tt0079644
# Nombre de la película: November 1828
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0079644
# Datos extraídos: ('November 1828', '6,9', '', '', 'No disponible', 'tt0079644')
# Accediendo a la película con ID tt0118578
# Nombre de la película: Albela
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118578
# Datos extraídos: ('Albela', '3,7', '', '', 'No disponible', 'tt0118578')
# Accediendo a la película con ID tt0119004
# Nombre de la película: Don's Plum
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119004
# Datos extraídos: ("Don's Plum", '5,5', '', '', 'No disponible', 'tt0119004')
# Accediendo a la película con ID tt0118589
# Nombre de la película: Glitter, todo lo que brilla
# Dirección: Vondie Curtis-Hall
# Guionistas: Cheryl L. WestKate Lanier
# Argumento: Una joven cantante sale con un disc jockey que la ayuda a entrar en el negocio de la música, pero su relación se complica a medida que ella asciende al estrellato.
# ID de la película: tt0118589
# Datos extraídos: ('Glitter, todo lo que brilla', '2,4', 'Vondie Curtis-Hall', 'Cheryl L. WestKate Lanier', 'Una joven cantante sale con un disc jockey que la ayuda a entrar en el negocio de la música, pero su relación se complica a medida que ella asciende al estrellato.', 'tt0118589')
# Accediendo a la película con ID tt0120624
# Nombre de la película: Camarate
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120624
# Datos extraídos: ('Camarate', '6,6', '', '', 'No disponible', 'tt0120624')
# Accediendo a la película con ID tt0120605
# Nombre de la película: Berlin Diaries, 1940-45
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0120605
# Datos extraídos: ('Berlin Diaries, 1940-45', 'No disponible', '', '', 'No disponible', 'tt0120605')
# Accediendo a la película con ID tt0120807
# Nombre de la película: Ricochet River
# Dirección: Deborah Del Prete
# Guionistas: Robin Cody, Patrick O'Connor
# Argumento: High school seniors Wade and Lorna have spent all their lives in the small logging town of Calamus Grove, a conservative place where change comes slowly. Jesse Howl, a teenager of Native American ancestry.
# ID de la película: tt0120807
# Datos extraídos: ('Ricochet River', '4,7', 'Deborah Del Prete', "Robin Cody, Patrick O'Connor", 'High school seniors Wade and Lorna have spent all their lives in the small logging town of Calamus Grove, a conservative place where change comes slowly. Jesse Howl, a teenager of Native American ancestry.', 'tt0120807')
# Accediendo a la película con ID tt0120737
# Nombre de la película: El señor de los anillos: La comunidad del anillo
# Dirección: Peter Jackson
# Guionistas: J.R.R. TolkienFran Walsh, Philippa Boyens
# Argumento: Un hobbit de la Comarca y ocho compañeros emprenden un viaje para destruir el poderoso Anillo Único y salvar la Tierra Media del Señor Oscuro Sauron.
# ID de la película: tt0120737
# Datos extraídos: ('El señor de los anillos: La comunidad del anillo', '8,9', 'Peter Jackson', 'J.R.R. TolkienFran Walsh, Philippa Boyens', 'Un hobbit de la Comarca y ocho compañeros emprenden un viaje para destruir el poderoso Anillo Único y salvar la Tierra Media del Señor Oscuro Sauron.', 'tt0120737')
# Accediendo a la película con ID tt0035423
# Nombre de la película: Kate & Leopold
# Dirección: James Mangold
# Guionistas: Steven Rogers, James Mangold
# Argumento: Un duque inglés de 1876 es arrastrado accidentalmente al Nueva York actual, donde se enamora de una valiente ejecutiva de publicidad.
# ID de la película: tt0035423
# Datos extraídos: ('Kate & Leopold', '6,4', 'James Mangold', 'Steven Rogers, James Mangold', 'Un duque inglés de 1876 es arrastrado accidentalmente al Nueva York actual, donde se enamora de una valiente ejecutiva de publicidad.', 'tt0035423')
# Accediendo a la película con ID tt0089067
# Nombre de la película: El día de los albañiles 2
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0089067
# Datos extraídos: ('El día de los albañiles 2', '5,1', '', '', 'No disponible', 'tt0089067')
# Accediendo a la película con ID tt0118652
# Nombre de la película: Horror in the Attic (Terror en el ático)
# Dirección: Jeremy Kasten
# Guionistas: Rogan Russell,  Marshall
# Argumento: An amnesiac awakens in an asylum for the criminally insane and must find answers as those around him die one by one.
# ID de la película: tt0118652
# Datos extraídos: ('Horror in the Attic (Terror en el ático)', '4,9', 'Jeremy Kasten', 'Rogan Russell,  Marshall', 'An amnesiac awakens in an asylum for the criminally insane and must find answers as those around him die one by one.', 'tt0118652')
# Accediendo a la película con ID tt0123581
# Nombre de la película: Burning Down the House
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0123581
# Datos extraídos: ('Burning Down the House', '4,9', '', '', 'No disponible', 'tt0123581')
# Accediendo a la película con ID tt0124889
# Nombre de la película: Sticks
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0124889
# Datos extraídos: ('Sticks', '5,4', '', '', 'No disponible', 'tt0124889')
# Accediendo a la película con ID tt0125022
# Nombre de la película: Las seductoras
# Dirección: David Mirkin
# Guionistas: Robert Dunn, Paul Guay, Stephen Mazur
# Argumento: Un equipo de estafadores de madre e hija seducen y estafan a hombres ricos.
# ID de la película: tt0125022
# Datos extraídos: ('Las seductoras', '6,2', 'David Mirkin', 'Robert Dunn, Paul Guay, Stephen Mazur', 'Un equipo de estafadores de madre e hija seducen y estafan a hombres ricos.', 'tt0125022')
# Accediendo a la película con ID tt0126029
# Nombre de la película: Shrek
# Dirección: Andrew AdamsonVicky Jenson
# Guionistas: William Steig, Ted Elliott, Terry Rossio
# Argumento: Un malvado señor exilia a las criaturas de los cuentos de hadas al pantano de un ogro gruñón, que debe emprender una búsqueda y rescatar a una princesa para el señor con el fin de recuperar sus tierras.
# ID de la película: tt0126029
# Datos extraídos: ('Shrek', '7,9', 'Andrew AdamsonVicky Jenson', 'William Steig, Ted Elliott, Terry Rossio', 'Un malvado señor exilia a las criaturas de los cuentos de hadas al pantano de un ogro gruñón, que debe emprender una búsqueda y rescatar a una princesa para el señor con el fin de recuperar sus tierras.', 'tt0126029')
# Accediendo a la película con ID tt0114447
# Nombre de la película: Fuerza silenciosa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0114447
# Datos extraídos: ('Fuerza silenciosa', '4,1', '', '', 'No disponible', 'tt0114447')
# Accediendo a la película con ID tt0128165
# Nombre de la película: Blazin'
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0128165
# Datos extraídos: ("Blazin'", '3,9', '', '', 'No disponible', 'tt0128165')
# Accediendo a la película con ID tt0132245
# Nombre de la película: Driven
# Dirección: Renny Harlin
# Guionistas: Jan Skrentny, Neal Tabachnick, Sylvester Stallone
# Argumento: Cuando un joven piloto está en medio de una temporada de campeonato y se está desmoronando llama a un ex campeón de CART para que le oriente.
# ID de la película: tt0132245
# Datos extraídos: ('Driven', '4,6', 'Renny Harlin', 'Jan Skrentny, Neal Tabachnick, Sylvester Stallone', 'Cuando un joven piloto está en medio de una temporada de campeonato y se está desmoronando llama a un ex campeón de CART para que le oriente.', 'tt0132245')
# Accediendo a la película con ID tt0133152
# Nombre de la película: El planeta de los simios
# Dirección: Tim Burton
# Guionistas: Pierre Boulle, William Broyles,  Jr.Lawrence Konner
# Argumento: En 2029, un astronauta se estrella en un misterioso planeta donde simios parlantes evolucionados dominan a una raza de humanos primitivos.
# ID de la película: tt0133152
# Datos extraídos: ('El planeta de los simios', '5,7', 'Tim Burton', 'Pierre Boulle, William Broyles,  Jr.Lawrence Konner', 'En 2029, un astronauta se estrella en un misterioso planeta donde simios parlantes evolucionados dominan a una raza de humanos primitivos.', 'tt0133152')
# Accediendo a la película con ID tt0141120
# Nombre de la película: The ghost (Muerte silenciosa)
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0141120
# Datos extraídos: ('The ghost (Muerte silenciosa)', '3,9', '', '', 'No disponible', 'tt0141120')
# Accediendo a la película con ID tt0146316
# Nombre de la película: Lara Croft: Tomb Raider
# Dirección: Simon West
# Guionistas: Sara B. CooperMike Werb, Michael Colleary
# Argumento: La aventurera de los videojuegos, Lara Croft, cobra vida en una película en la que compite contra el tiempo y los villanos para recuperar poderosos artefactos antiguos.
# ID de la película: tt0146316
# Datos extraídos: ('Lara Croft: Tomb Raider', '5,8', 'Simon West', 'Sara B. CooperMike Werb, Michael Colleary', 'La aventurera de los videojuegos, Lara Croft, cobra vida en una película en la que compite contra el tiempo y los villanos para recuperar poderosos artefactos antiguos.', 'tt0146316')
# Accediendo a la película con ID tt0150021
# Nombre de la película: Camouflage
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0150021
# Datos extraídos: ('Camouflage', '4,6', '', '', 'No disponible', 'tt0150021')
# Accediendo a la película con ID tt0120166
# Nombre de la película: El aprendiz de brujo
# Dirección: David Lister
# Guionistas: Brett Morris
# Argumento: When his new neighbour turns out to be the wizard Merlin, young Ben Clark is enlisted in an ancient battle to save the world.
# ID de la película: tt0120166
# Datos extraídos: ('El aprendiz de brujo', '4,2', 'David Lister', 'Brett Morris', 'When his new neighbour turns out to be the wizard Merlin, young Ben Clark is enlisted in an ancient battle to save the world.', 'tt0120166')
# Accediendo a la película con ID tt0133063
# Nombre de la película: Lightmaker
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0133063
# Datos extraídos: ('Lightmaker', '7,5', '', '', 'No disponible', 'tt0133063')
# Accediendo a la película con ID tt0148415
# Nombre de la película: Little Shop of Erotica
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0148415
# Datos extraídos: ('Little Shop of Erotica', '4,1', '', '', 'No disponible', 'tt0148415')
# Accediendo a la película con ID tt0164961
# Nombre de la película: Vidocq: El mito
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0164961
# Datos extraídos: ('Vidocq: El mito', '6,4', '', '', 'No disponible', 'tt0164961')
# Accediendo a la película con ID tt0166276
# Nombre de la película: Monkeybone
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0166276
# Datos extraídos: ('Monkeybone', '4,8', '', '', 'No disponible', 'tt0166276')
# Accediendo a la película con ID tt0120681
# Nombre de la película: Desde el infierno
# Dirección: Albert HughesAllen Hughes
# Guionistas: Alan Moore, Eddie Campbell, Terry Hayes
# Argumento: En la época del Londres victoriano, un detective de la policía clarividente investiga los asesinatos de Jack el Destripador.
# ID de la película: tt0120681
# Datos extraídos: ('Desde el infierno', '6,7', 'Albert HughesAllen Hughes', 'Alan Moore, Eddie Campbell, Terry Hayes', 'En la época del Londres victoriano, un detective de la policía clarividente investiga los asesinatos de Jack el Destripador.', 'tt0120681')
# Accediendo a la película con ID tt0153533
# Nombre de la película: Victoria's Shadow
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0153533
# Datos extraídos: ("Victoria's Shadow", '3,4', '', '', 'No disponible', 'tt0153533')
# Accediendo a la película con ID tt0162030
# Nombre de la película: Unseen Evil
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0162030
# Datos extraídos: ('Unseen Evil', '3,3', '', '', 'No disponible', 'tt0162030')
# Accediendo a la película con ID tt0166110
# Nombre de la película: Bones
# Dirección: Ernest R. Dickerson
# Guionistas: Adam Simon, Tim Metcalfe
# Argumento: Over 20 years after his death by a gunshot, Jimmy Bones comes back as a ghost to wreak revenge on those who killed him and to clean up his neighborhood.
# ID de la película: tt0166110
# Datos extraídos: ('Bones', '4,4', 'Ernest R. Dickerson', 'Adam Simon, Tim Metcalfe', 'Over 20 years after his death by a gunshot, Jimmy Bones comes back as a ghost to wreak revenge on those who killed him and to clean up his neighborhood.', 'tt0166110')
# Accediendo a la película con ID tt0171339
# Nombre de la película: Generation Ax
# Dirección: Tommy Faircloth
# Guionistas: Tommy Faircloth
# Argumento: Two giggly high school lovebirds playfully throw pieces of bloody human brain at one another, then take a messy shower, in the latest horror flick out of South Carolina, which is fast becoming the Gruesome Gus capital of the world. The flick is called GENERATION AX, and it's HEATHERS meets SCREAM meets THE TEXAS CHEERLEADER MOM meets BONNIE AND CLYDE. Tommy Faircloth ... Leer todo
# ID de la película: tt0171339
# Datos extraídos: ('Generation Ax', '3,0', 'Tommy Faircloth', 'Tommy Faircloth', "Two giggly high school lovebirds playfully throw pieces of bloody human brain at one another, then take a messy shower, in the latest horror flick out of South Carolina, which is fast becoming the Gruesome Gus capital of the world. The flick is called GENERATION AX, and it's HEATHERS meets SCREAM meets THE TEXAS CHEERLEADER MOM meets BONNIE AND CLYDE. Tommy Faircloth ... Leer todo", 'tt0171339')
# Accediendo a la película con ID tt0157583
# Nombre de la película: Enigma
# Dirección: Michael Apted
# Guionistas: Robert Harris, Tom Stoppard
# Argumento: Un joven genio corre frenéticamente contra el tiempo para descifrar un código enemigo y resolver el misterio que rodea a la mujer que ama.
# ID de la película: tt0157583
# Datos extraídos: ('Enigma', '6,4', 'Michael Apted', 'Robert Harris, Tom Stoppard', 'Un joven genio corre frenéticamente contra el tiempo para descifrar un código enemigo y resolver el misterio que rodea a la mujer que ama.', 'tt0157583')
# Accediendo a la película con ID tt0160399
# Nombre de la película: Infiltrado
# Dirección: Gary Fleder
# Guionistas: Philip K. DickScott Rosenberg, Caroline Case
# Argumento: En el futuro, una raza alienígena utiliza androides como bombas para atacar la Tierra. Un especialista en armamento del Gobierno es acusado de ser uno de esos androides y se propone demostrar su inocencia.
# ID de la película: tt0160399
# Datos extraídos: ('Infiltrado', '6,1', 'Gary Fleder', 'Philip K. DickScott Rosenberg, Caroline Case', 'En el futuro, una raza alienígena utiliza androides como bombas para atacar la Tierra. Un especialista en armamento del Gobierno es acusado de ser uno de esos androides y se propone demostrar su inocencia.', 'tt0160399')
# Accediendo a la película con ID tt0163596
# Nombre de la película: Dark Water
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0163596
# Datos extraídos: ('Dark Water', '5,1', '', '', 'No disponible', 'tt0163596')
# Accediendo a la película con ID tt0166924
# Nombre de la película: Mulholland Drive
# Dirección: David Lynch
# Guionistas: David Lynch
# Argumento: Tras un accidente en Mulholland Drive, una mujer amnésica y una aspirante a actriz recorrerán Los Ángeles buscando respuestas en un viaje más allá de los sueños y la realidad.
# ID de la película: tt0166924
# Datos extraídos: ('Mulholland Drive', '7,9', 'David Lynch', 'David Lynch', 'Tras un accidente en Mulholland Drive, una mujer amnésica y una aspirante a actriz recorrerán Los Ángeles buscando respuestas en un viaje más allá de los sueños y la realidad.', 'tt0166924')
# Accediendo a la película con ID tt0179735
# Nombre de la película: The Confidence Man
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0179735
# Datos extraídos: ('The Confidence Man', '5,4', '', '', 'No disponible', 'tt0179735')
# Accediendo a la película con ID tt0182000
# Nombre de la película: Muerte de un ángel
# Dirección: Kasi Lemmons
# Guionistas: George Dawes,  Green
# Argumento: Un hombre que vive en una cueva se propone localizar al asesino de un niño sin hogar y llevarlo ante la justicia.
# ID de la película: tt0182000
# Datos extraídos: ('Muerte de un ángel', '5,8', 'Kasi Lemmons', 'George Dawes,  Green', 'Un hombre que vive en una cueva se propone localizar al asesino de un niño sin hogar y llevarlo ante la justicia.', 'tt0182000')
# Accediendo a la película con ID tt0124359
# Nombre de la película: 404 Error
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0124359
# Datos extraídos: ('404 Error', 'No disponible', '', '', 'No disponible', 'tt0124359')
# Accediendo a la película con ID tt0141907
# Nombre de la película: Enredos de sociedad
# Dirección: Peter Chelsom
# Guionistas: Michael Laughlin, Buck Henry
# Argumento: Two loving middle aged couples get caught in a series of marital misadventures over reasons of fidelity.
# ID de la película: tt0141907
# Datos extraídos: ('Enredos de sociedad', '4,5', 'Peter Chelsom', 'Michael Laughlin, Buck Henry', 'Two loving middle aged couples get caught in a series of marital misadventures over reasons of fidelity.', 'tt0141907')
# Accediendo a la película con ID tt0160480
# Nombre de la película: Long Lost Love
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0160480
# Datos extraídos: ('Long Lost Love', '7,0', '', '', 'No disponible', 'tt0160480')
# Accediendo a la película con ID tt0114722
# Nombre de la película: 3 noches
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0114722
# Datos extraídos: ('3 noches', '7,1', '', '', 'No disponible', 'tt0114722')
# Accediendo a la película con ID tt0126899
# Nombre de la película: Eyes Are Upon You
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0126899
# Datos extraídos: ('Eyes Are Upon You', '2,8', '', '', 'No disponible', 'tt0126899')
# Accediendo a la película con ID tt0139654
# Nombre de la película: Training Day (Día de entrenamiento)
# Dirección: Antoine Fuqua
# Guionistas: David Ayer
# Argumento: En su primer día de trabajo como oficial de narcóticos, un policía novato acaba con un inusual detective que no es lo que parece.
# ID de la película: tt0139654
# Datos extraídos: ('Training Day (Día de entrenamiento)', '7,8', 'Antoine Fuqua', 'David Ayer', 'En su primer día de trabajo como oficial de narcóticos, un policía novato acaba con un inusual detective que no es lo que parece.', 'tt0139654')
# Accediendo a la película con ID tt0096056
# Nombre de la película: Crimen y castigo
# Dirección: Menahem Golan
# Guionistas: Fyodor Dostoevsky, Menahem Golan
# Argumento: A modern day adaptation of Dostoyevsky's classic novel about a young student who is forever haunted by the murder he has committed.
# ID de la película: tt0096056
# Datos extraídos: ('Crimen y castigo', '5,5', 'Menahem Golan', 'Fyodor Dostoevsky, Menahem Golan', "A modern day adaptation of Dostoyevsky's classic novel about a young student who is forever haunted by the murder he has committed.", 'tt0096056')
# Accediendo a la película con ID tt0118926
# Nombre de la película: Pasos de baile
# Dirección: John Malkovich
# Guionistas: Nicholas Shakespeare
# Argumento: Un detective de la policía de un país sudamericano se dedica a dar caza a un líder guerrillero revolucionario.
# ID de la película: tt0118926
# Datos extraídos: ('Pasos de baile', '6,8', 'John Malkovich', 'Nicholas Shakespeare', 'Un detective de la policía de un país sudamericano se dedica a dar caza a un líder guerrillero revolucionario.', 'tt0118926')
# Accediendo a la película con ID tt0119980
# Nombre de la película: Random Shooting in L.A.
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0119980
# Datos extraídos: ('Random Shooting in L.A.', '6,5', '', '', 'No disponible', 'tt0119980')
# Accediendo a la película con ID tt0120679
# Nombre de la película: Frida
# Dirección: Julie Taymor
# Guionistas: Hayden Herrera, Clancy Sigal, Diane Lake
# Argumento: Una biografía de la artista Frida Kahlo, que canalizó el dolor de una lesión debilitante y de su tempestuoso matrimonio en su trabajo.
# ID de la película: tt0120679
# Datos extraídos: ('Frida', '7,3', 'Julie Taymor', 'Hayden Herrera, Clancy Sigal, Diane Lake', 'Una biografía de la artista Frida Kahlo, que canalizó el dolor de una lesión debilitante y de su tempestuoso matrimonio en su trabajo.', 'tt0120679')
# Accediendo a la película con ID tt0130255
# Nombre de la película: Shivam
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0130255
# Datos extraídos: ('Shivam', '5,1', '', '', 'No disponible', 'tt0130255')
# Accediendo a la película con ID tt0149253
# Nombre de la película: The Good War
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0149253
# Datos extraídos: ('The Good War', '5,9', '', '', 'No disponible', 'tt0149253')
# Accediendo a la película con ID tt0154187
# Nombre de la película: The Bacchae
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0154187
# Datos extraídos: ('The Bacchae', '6,7', '', '', 'No disponible', 'tt0154187')
# Accediendo a la película con ID tt0120912
# Nombre de la película: Men in Black II (Hombres de negro II)
# Dirección: Barry Sonnenfeld
# Guionistas: Lowell Cunningham, Robert Gordon, Barry Fanaro
# Argumento: El agente J es enviado para encontrar al agente K y devolverle la memoria tras la reapariciÃfÂ³n de un caso del pasado de K.
# ID de la película: tt0120912
# Datos extraídos: ('Men in Black II (Hombres de negro II)', '6,2', 'Barry Sonnenfeld', 'Lowell Cunningham, Robert Gordon, Barry Fanaro', 'El agente J es enviado para encontrar al agente K y devolverle la memoria tras la reapariciÃfÂ³n de un caso del pasado de K.', 'tt0120912')
# Accediendo a la película con ID tt0120870
# Nombre de la película: Trance
# Dirección: Gary Dean Orona
# Guionistas: Tane Mc, ClureGary Dean,  OronaTyke Caravelli
# Argumento: Trapped in a lover's triangle of lust, greed, and betrayal we follow one woman's journey to discover her true self... Magic, where everything is an Illusion... and nothing is as it seems.
# ID de la película: tt0120870
# Datos extraídos: ('Trance', '5,2', 'Gary Dean Orona', 'Tane Mc, ClureGary Dean,  OronaTyke Caravelli', "Trapped in a lover's triangle of lust, greed, and betrayal we follow one woman's journey to discover her true self... Magic, where everything is an Illusion... and nothing is as it seems.", 'tt0120870')
# Accediendo a la película con ID tt0128216
# Nombre de la película: Flophouse
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0128216
# Datos extraídos: ('Flophouse', '2,6', '', '', 'No disponible', 'tt0128216')
# Accediendo a la película con ID tt0156376
# Nombre de la película: Book of Love: The Definitive Reason Why Men Are Dogs
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0156376
# Datos extraídos: ('Book of Love: The Definitive Reason Why Men Are Dogs', '5,6', '', '', 'No disponible', 'tt0156376')
# Accediendo a la película con ID tt0157472
# Nombre de la película: Clockstoppers
# Dirección: Jonathan Frakes
# Guionistas: Rob Hedden, Andy Hedden, J. David Stem
# Argumento: Zak Gibbs (Jesse Bradford) es un adolescente normal y corriente que de repente recibe unos poderes extraordinarios cuando se encuentra un misterioso artilugio en forma de reloj de pulsera ¡capaz de detener el tiempo!
# ID de la película: tt0157472
# Datos extraídos: ('Clockstoppers', '5,2', 'Jonathan Frakes', 'Rob Hedden, Andy Hedden, J. David Stem', 'Zak Gibbs (Jesse Bradford) es un adolescente normal y corriente que de repente recibe unos poderes extraordinarios cuando se encuentra un misterioso artilugio en forma de reloj de pulsera ¡capaz de detener el tiempo!', 'tt0157472')
# Accediendo a la película con ID tt0160905
# Nombre de la película: Spooky House
# Dirección: William Sachs
# Guionistas: Margaret Sachs, William Sachs
# Argumento: Max is a lonely, recently orphaned young boy who is frequently bullied by his classmates. One night after accepting a dare, Max wanders into a mysterious mansion, where he meets the Great Zamboni, an eccentric magician.
# ID de la película: tt0160905
# Datos extraídos: ('Spooky House', '5,2', 'William Sachs', 'Margaret Sachs, William Sachs', 'Max is a lonely, recently orphaned young boy who is frequently bullied by his classmates. One night after accepting a dare, Max wanders into a mysterious mansion, where he meets the Great Zamboni, an eccentric magician.', 'tt0160905')
# Accediendo a la película con ID tt0160240
# Nombre de la película: Easter
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0160240
# Datos extraídos: ('Easter', '7,8', '', '', 'No disponible', 'tt0160240')
# Accediendo a la película con ID tt0121765
# Nombre de la película: Star Wars: Episodio II - El ataque de los clones
# Dirección: George Lucas
# Guionistas: George Lucas, Jonathan Hales
# Argumento: Tras diez años de su primer encuentro, Anakin Skywalker y Padmé Amidala disfrutan de un romance prohibido, mientras Obi-Wan Kenobi investiga el intento de asesinato de un senador y descubre una armada secreta de clones creada por los jedi.
# ID de la película: tt0121765
# Datos extraídos: ('Star Wars: Episodio II - El ataque de los clones', '6,6', 'George Lucas', 'George Lucas, Jonathan Hales', 'Tras diez años de su primer encuentro, Anakin Skywalker y Padmé Amidala disfrutan de un romance prohibido, mientras Obi-Wan Kenobi investiga el intento de asesinato de un senador y descubre una armada secreta de clones creada por los jedi.', 'tt0121765')
# Accediendo a la película con ID tt0120804
# Nombre de la película: Resident Evil
# Dirección: Paul W.S. Anderson
# Guionistas: Paul W.S. Anderson
# ...
# Accediendo a la película con ID tt0242888
# Nombre de la película: El lenguaje de los sueños
# Dirección: Guy Jenkin
# Guionistas: Guy Jenkin
# Argumento: A young Englishman is sent to Malaysian Borneo in the 1930s to stay with a tribe as UK's colonial representative. A local woman (J.Alba) helps him understand local tradition and language. He falls in love with her etc. despite the taboo.
# ID de la película: tt0242888
# Datos extraídos: ('El lenguaje de los sueños', '6,5', 'Guy Jenkin', 'Guy Jenkin', "A young Englishman is sent to Malaysian Borneo in the 1930s to stay with a tribe as UK's colonial representative. A local woman (J.Alba) helps him understand local tradition and language. He falls in love with her etc. despite the taboo.", 'tt0242888')
# Accediendo a la película con ID tt0160870
# Nombre de la película: Silent Screamplay
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0160870
# Datos extraídos: ('Silent Screamplay', '5,2', '', '', 'No disponible', 'tt0160870')
# Accediendo a la película con ID tt0201934
# Nombre de la película: Pasado oculto
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0201934
# Datos extraídos: ('Pasado oculto', '4,6', '', '', 'No disponible', 'tt0201934')
# Accediendo a la película con ID tt0215244
# Nombre de la película: Terror in the Darkness
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0215244
# Datos extraídos: ('Terror in the Darkness', '4,2', '', '', 'No disponible', 'tt0215244')
# Accediendo a la película con ID tt0243652
# Nombre de la película: How It All Went Down
# Dirección: Silvio Pollio
# Guionistas: Silvio Pollio, Danny Wattley
# Argumento: A struggling filmmaker finds himself involved in a dark world of guns, drugs and prostitution.
# ID de la película: tt0243652
# Datos extraídos: ('How It All Went Down', '4,0', 'Silvio Pollio', 'Silvio Pollio, Danny Wattley', 'A struggling filmmaker finds himself involved in a dark world of guns, drugs and prostitution.', 'tt0243652')
# Accediendo a la película con ID tt0092960
# Nombre de la película: En tres y dos
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0092960
# Datos extraídos: ('En tres y dos', '6,6', '', '', 'No disponible', 'tt0092960')
# Accediendo a la película con ID tt0146803
# Nombre de la película: Goodnight, Joseph Parker
# Dirección: Dennis Brooks
# Guionistas: Dennis Brooks
# Argumento: "Unapologetically brash in dialogue and texture GOODNIGHT JOSEPH PARKER is the classic love story brought to a no-pleasantries bar room. Girl loves man who loves woman, woman isn't worth his time. Into that mix throw in a hopeless drunk with a good heart and weak stomach, a bartender who's more desperate than his customers and Steven Tyler as a shameless bad boy looki... Leer todo
# ID de la película: tt0146803
# Datos extraídos: ('Goodnight, Joseph Parker', '5,7', 'Dennis Brooks', 'Dennis Brooks', '"Unapologetically brash in dialogue and texture GOODNIGHT JOSEPH PARKER is the classic love story brought to a no-pleasantries bar room. Girl loves man who loves woman, woman isn\'t worth his time. Into that mix throw in a hopeless drunk with a good heart and weak stomach, a bartender who\'s more desperate than his customers and Steven Tyler as a shameless bad boy looki... Leer todo', 'tt0146803')
# Accediendo a la película con ID tt0159290
# Nombre de la película: Bluebird
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0159290
# Datos extraídos: ('Bluebird', '7,4', '', '', 'No disponible', 'tt0159290')
# Accediendo a la película con ID tt0168064
# Nombre de la película: El Maya
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0168064
# Datos extraídos: ('El Maya', '6,9', '', '', 'No disponible', 'tt0168064')
# Accediendo a la película con ID tt0170508
# Nombre de la película: El resto de nada
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0170508
# Datos extraídos: ('El resto de nada', '6,8', '', '', 'No disponible', 'tt0170508')
# Accediendo a la película con ID tt0186785
# Nombre de la película: Greener
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0186785
# Datos extraídos: ('Greener', '7,7', '', '', 'No disponible', 'tt0186785')
# Accediendo a la película con ID tt0196811
# Nombre de la película: Olga
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0196811
# Datos extraídos: ('Olga', '6,5', '', '', 'No disponible', 'tt0196811')
# Accediendo a la película con ID tt0203912
# Nombre de la película: El caldero de los pecados
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0203912
# Datos extraídos: ('El caldero de los pecados', '5,3', '', '', 'No disponible', 'tt0203912')
# Accediendo a la película con ID tt0211070
# Nombre de la película: Tricks
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0211070
# Datos extraídos: ('Tricks', '7,1', '', '', 'No disponible', 'tt0211070')
# Accediendo a la película con ID tt0108549
# Nombre de la película: West from North Goes South
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0108549
# Datos extraídos: ('West from North Goes South', '8,0', '', '', 'No disponible', 'tt0108549')
# Accediendo a la película con ID tt0122247
# Nombre de la película: Manual del Serial Killer para principiantes
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0122247
# Datos extraídos: ('Manual del Serial Killer para principiantes', '5,2', '', '', 'No disponible', 'tt0122247')
# Accediendo a la película con ID tt0167456
# Nombre de la película: Thunderbirds
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0167456
# Datos extraídos: ('Thunderbirds', '4,3', '', '', 'No disponible', 'tt0167456')
# Accediendo a la película con ID tt0169084
# Nombre de la película: A Night at Sophie's
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0169084
# Datos extraídos: ("A Night at Sophie's", '7,5', '', '', 'No disponible', 'tt0169084')
# Accediendo a la película con ID tt0177882
# Nombre de la película: Kebab Connection
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0177882
# Datos extraídos: ('Kebab Connection', '6,6', '', '', 'No disponible', 'tt0177882')
# Accediendo a la película con ID tt0187279
# Nombre de la película: Meri Biwi Ka Jawab Nahin
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0187279
# Datos extraídos: ('Meri Biwi Ka Jawab Nahin', '3,5', '', '', 'No disponible', 'tt0187279')
# Accediendo a la película con ID tt0198013
# Nombre de la película: 29 and Holding
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0198013
# Datos extraídos: ('29 and Holding', '8,6', '', '', 'No disponible', 'tt0198013')
# Accediendo a la película con ID tt0220322
# Nombre de la película: B Movie
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0220322
# Datos extraídos: ('B Movie', '7,2', '', '', 'No disponible', 'tt0220322')
# Accediendo a la película con ID tt0131597
# Nombre de la película: Split
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0131597
# Datos extraídos: ('Split', '5,3', '', '', 'No disponible', 'tt0131597')
# Accediendo a la película con ID tt0167190
# Nombre de la película: Hellboy
# Dirección: Guillermo del Toro
# Guionistas: Guillermo del ToroPeter Briggs, Mike Mignola
# Argumento: Un demonio, criado desde la infancia tras ser conjurado y rescatado de los nazis, crece hasta convertirse en un defensor de las fuerzas de la oscuridad.
# ID de la película: tt0167190
# Datos extraídos: ('Hellboy', '6,8', 'Guillermo del Toro', 'Guillermo del ToroPeter Briggs, Mike Mignola', 'Un demonio, criado desde la infancia tras ser conjurado y rescatado de los nazis, crece hasta convertirse en un defensor de las fuerzas de la oscuridad.', 'tt0167190')
# Accediendo a la película con ID tt0235853
# Nombre de la película: Vampire Lesbian Kickboxers
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0235853
# Datos extraídos: ('Vampire Lesbian Kickboxers', '8,1', '', '', 'No disponible', 'tt0235853')
# Accediendo a la película con ID tt0239235
# Nombre de la película: Indiano Jones y el agua de la eternidad
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0239235
# Datos extraídos: ('Indiano Jones y el agua de la eternidad', '6,3', '', '', 'No disponible', 'tt0239235')
# Accediendo a la película con ID tt0205513
# Nombre de la película: Warrior Sisters
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0205513
# Datos extraídos: ('Warrior Sisters', '7,7', '', '', 'No disponible', 'tt0205513')
# Accediendo a la película con ID tt0222790
# Nombre de la película: Raspberry & Lavender: The Lavender Girl
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0222790
# Datos extraídos: ('Raspberry & Lavender: The Lavender Girl', '6,3', '', '', 'No disponible', 'tt0222790')
# Accediendo a la película con ID tt0264410
# Nombre de la película: Berserker
# Dirección: Paul Matthews
# Guionistas: Paul Matthews
# Argumento: El hijo de un caudillo está maldito a renacer una vida tras otra y destinado a amar y perder hasta que se levante la maldición.
# ID de la película: tt0264410
# Datos extraídos: ('Berserker', '3,1', 'Paul Matthews', 'Paul Matthews', 'El hijo de un caudillo está maldito a renacer una vida tras otra y destinado a amar y perder hasta que se levante la maldición.', 'tt0264410')
# Accediendo a la película con ID tt0286857
# Nombre de la película: Off the Pages
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0286857
# Datos extraídos: ('Off the Pages', 'No disponible', '', '', 'No disponible', 'tt0286857')
# Accediendo a la película con ID tt0293708
# Nombre de la película: Mothers Little Murderer
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0293708
# Datos extraídos: ('Mothers Little Murderer', 'No disponible', '', '', 'No disponible', 'tt0293708')
# Accediendo a la película con ID tt0298148
# Nombre de la película: Shrek 2
# Dirección: Andrew AdamsonKelly AsburyConrad Vernon
# Guionistas: William Steig, Andrew Adamson, Joe Stillman
# Argumento: Shrek y Fiona viajan al reino de Muy Muy Lejano, donde los padres de Fiona son reyes, para celebrar su matrimonio. Cuando llegan, descubren que no son tan bienvenidos como pensaban.
# ID de la película: tt0298148
# Datos extraídos: ('Shrek 2', '7,3', 'Andrew AdamsonKelly AsburyConrad Vernon', 'William Steig, Andrew Adamson, Joe Stillman', 'Shrek y Fiona viajan al reino de Muy Muy Lejano, donde los padres de Fiona son reyes, para celebrar su matrimonio. Cuando llegan, descubren que no son tan bienvenidos como pensaban.', 'tt0298148')
# Accediendo a la película con ID tt0202360
# Nombre de la película: Frost
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0202360
# Datos extraídos: ('Frost', '5,2', '', '', 'No disponible', 'tt0202360')
# Accediendo a la película con ID tt0204313
# Nombre de la película: El exorcista: El comienzo
# Dirección: Renny Harlin
# Guionistas: William Peter,  BlattyWilliam Wisher, Caleb Carr
# Argumento: Años antes de que el padre Lankester ayudara a salvar el alma de Regan, se encuentra por primera vez con el demonio Pazuzu en África Oriental.
# ID de la película: tt0204313
# Datos extraídos: ('El exorcista: El comienzo', '5,1', 'Renny Harlin', 'William Peter,  BlattyWilliam Wisher, Caleb Carr', 'Años antes de que el padre Lankester ayudara a salvar el alma de Regan, se encuentra por primera vez con el demonio Pazuzu en África Oriental.', 'tt0204313')
# Accediendo a la película con ID tt0286669
# Nombre de la película: Habitaciones para turistas
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0286669
# Datos extraídos: ('Habitaciones para turistas', '5,2', '', '', 'No disponible', 'tt0286669')
# Accediendo a la película con ID tt0287733
# Nombre de la película: Directos al infierno
# Dirección: Jeff Burr
# Guionistas: Jeff Burr, Mark Hannah
# Argumento: When two young American GIs desert their platoon in the final days of World War II, they will find themselves struggling against all odds to stay alive.
# ID de la película: tt0287733
# Datos extraídos: ('Directos al infierno', '5,0', 'Jeff Burr', 'Jeff Burr, Mark Hannah', 'When two young American GIs desert their platoon in the final days of World War II, they will find themselves struggling against all odds to stay alive.', 'tt0287733')
# Accediendo a la película con ID tt0287795
# Nombre de la película: Killer Weekend
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0287795
# Datos extraídos: ('Killer Weekend', '3,5', '', '', 'No disponible', 'tt0287795')
# Accediendo a la película con ID tt0289933
# Nombre de la película: Suske en Wiske: De duistere diamant
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0289933
# Datos extraídos: ('Suske en Wiske: De duistere diamant', '4,8', '', '', 'No disponible', 'tt0289933')
# Accediendo a la película con ID tt0305632
# Nombre de la película: Fascinación
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0305632
# Datos extraídos: ('Fascinación', '3,8', '', '', 'No disponible', 'tt0305632')
# Accediendo a la película con ID tt0304141
# Nombre de la película: Harry Potter y el prisionero de Azkaban
# Dirección: Alfonso Cuarón
# Guionistas: J.K. RowlingSteve Kloves
# Argumento: Harry Potter, Ron y Hermione regresan al Colegio Hogwarts de Magia y Hechicería para cursar su tercer año de estudios, donde se adentran en el misterio que rodea a un preso fugado que supone una peligrosa amenaza para el joven mago.
# ID de la película: tt0304141
# Datos extraídos: ('Harry Potter y el prisionero de Azkaban', '7,9', 'Alfonso Cuarón', 'J.K. RowlingSteve Kloves', 'Harry Potter, Ron y Hermione regresan al Colegio Hogwarts de Magia y Hechicería para cursar su tercer año de estudios, donde se adentran en el misterio que rodea a un preso fugado que supone una peligrosa amenaza para el joven mago.', 'tt0304141')
# Accediendo a la película con ID tt0206771
# Nombre de la película: Abuso de poder
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0206771
# Datos extraídos: ('Abuso de poder', '5,1', '', '', 'No disponible', 'tt0206771')
# Accediendo a la película con ID tt0212712
# Nombre de la película: 2046
# Dirección: Kar-Wai Wong
# Guionistas: Kar-Wai Wong
# Argumento: Varias mujeres entran en la vida de un autor de ciencia ficción en el transcurso de unos años, después de que el autor haya perdido a la mujer que él considera su único amor verdadero.
# ID de la película: tt0212712
# Datos extraídos: ('2046', '7,4', 'Kar-Wai Wong', 'Kar-Wai Wong', 'Varias mujeres entran en la vida de un autor de ciencia ficción en el transcurso de unos años, después de que el autor haya perdido a la mujer que él considera su único amor verdadero.', 'tt0212712')
# Accediendo a la película con ID tt0224025
# Nombre de la película: Roomies
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0224025
# Datos extraídos: ('Roomies', '4,1', '', '', 'No disponible', 'tt0224025')
# Accediendo a la película con ID tt0229792
# Nombre de la película: True Vinyl
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0229792
# Datos extraídos: ('True Vinyl', '5,0', '', '', 'No disponible', 'tt0229792')
# Accediendo a la película con ID tt0218400
# Nombre de la película: Life Sentence
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0218400
# Datos extraídos: ('Life Sentence', '6,3', '', '', 'No disponible', 'tt0218400')
# Accediendo a la película con ID tt0235219
# Nombre de la película: Till Proven Innocent
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0235219
# Datos extraídos: ('Till Proven Innocent', '5,0', '', '', 'No disponible', 'tt0235219')
# Accediendo a la película con ID tt0246404
# Nombre de la película: The 24th Day
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0246404
# Datos extraídos: ('The 24th Day', '6,4', '', '', 'No disponible', 'tt0246404')

# %%
# Guardar el DataFrame en un nuevo archivo CSV
df_peliculas.to_csv('peliculas_ext_sel_2000_2004.csv', index=False)
print("Archivo 'peliculas_ext_sel_2000_2004.csv' creado exitosamente.")
# Out:
# Archivo 'peliculas_ext_sel_2000_2004.csv' creado exitosamente.

# %%
#Peliculas de 2005 a 2009:

ids_peliculas = extractor_idowners('peliculas_2005_2009.csv')

# Crear el driver de Selenium
mi_driver = generar_driver()

# Lista para almacenar los datos extraídos
datos_peliculas = []

# Bucle para recorrer todos los IDs Owners y extraer la información
for id_owner in ids_peliculas:
    mis_datos = extraer_datos_pelicula(mi_driver, id_owner)
    datos_peliculas.append(mis_datos)

# Cerrar el driver después de la extracción
mi_driver.quit()

# Convertir los datos extraídos a un DataFrame
df_peliculas = pd.DataFrame(datos_peliculas, columns=["Título", "Puntuación IMDb", "Directores", "Guionistas", "Argumento", "ID"])
# Out:
# Maximizando la web.
# Accediendo a la web.
# Cookies aceptadas.
# Accediendo a la película con ID tt0118141
# Nombre de la película: What Is It?
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0118141
# Datos extraídos: ('What Is It?', '5,3', '', '', 'No disponible', 'tt0118141')
# Accediendo a la película con ID tt0121164
# Nombre de la película: La novia cadáver
# Dirección: Tim BurtonMike Johnson
# Guionistas: Tim Burton, Carlos Grangel, John August
# Argumento: Cuando un tímido novio practica sus votos matrimoniales ante la presencia inadvertida de una joven fallecida, esta se levanta de la tumba asumiendo que la ha tomado por esposa.
# ID de la película: tt0121164
# Datos extraídos: ('La novia cadáver', '7,4', 'Tim BurtonMike Johnson', 'Tim Burton, Carlos Grangel, John August', 'Cuando un tímido novio practica sus votos matrimoniales ante la presencia inadvertida de una joven fallecida, esta se levanta de la tumba asumiendo que la ha tomado por esposa.', 'tt0121164')
# Accediendo a la película con ID tt0146272
# Nombre de la película: Shooting Vegetarians
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0146272
# Datos extraídos: ('Shooting Vegetarians', '4,6', '', '', 'No disponible', 'tt0146272')
# Accediendo a la película con ID tt0160706
# Nombre de la película: El enemigo
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0160706
# Datos extraídos: ('El enemigo', '5,3', '', '', 'No disponible', 'tt0160706')
# Accediendo a la película con ID tt0187838
# Nombre de la película: Eve's Preyer
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0187838
# Datos extraídos: ("Eve's Preyer", '7,2', '', '', 'No disponible', 'tt0187838')
# Accediendo a la película con ID tt0195551
# Nombre de la película: Berlin Nights
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0195551
# Datos extraídos: ('Berlin Nights', '6,5', '', '', 'No disponible', 'tt0195551')
# Accediendo a la película con ID tt0196155
# Nombre de la película: Thousands of Miles
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0196155
# Datos extraídos: ('Thousands of Miles', 'No disponible', '', '', 'No disponible', 'tt0196155')
# Accediendo a la película con ID tt0195565
# Nombre de la película: Death-Defying Acts
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0195565
# Datos extraídos: ('Death-Defying Acts', 'No disponible', '', '', 'No disponible', 'tt0195565')
# Accediendo a la película con ID tt0088751
# Nombre de la película: The Naked Monster
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0088751
# Datos extraídos: ('The Naked Monster', '5,2', '', '', 'No disponible', 'tt0088751')
# Accediendo a la película con ID tt0159790
# Nombre de la película: Three
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0159790
# Datos extraídos: ('Three', 'No disponible', '', '', 'No disponible', 'tt0159790')
# Accediendo a la película con ID tt0179803
# Nombre de la película: Angels with Angles
# Dirección: Scott Edmund Lane
# Guionistas: Scott Edmund,  LaneMark Pietri
# Argumento: George Burns is no happy angel. Heaven is "non-smoking", but most importantly, he can't reunite with his wife Gracie.
# ID de la película: tt0179803
# Datos extraídos: ('Angels with Angles', '4,8', 'Scott Edmund Lane', 'Scott Edmund,  LaneMark Pietri', 'George Burns is no happy angel. Heaven is "non-smoking", but most importantly, he can\'t reunite with his wife Gracie.', 'tt0179803')
# Accediendo a la película con ID tt0216584
# Nombre de la película: Bob the Butler
# Dirección: Gary Sinyor
# Guionistas: Jane Walker,  WoodSteven Manners, Gary Sinyor
# Argumento: Tom Green stars as a bumbling buffoon who lands at Butlering after working his way through all other 'A' and 'B' jobs.
# ID de la película: tt0216584
# Datos extraídos: ('Bob the Butler', '5,6', 'Gary Sinyor', 'Jane Walker,  WoodSteven Manners, Gary Sinyor', "Tom Green stars as a bumbling buffoon who lands at Butlering after working his way through all other 'A' and 'B' jobs.", 'tt0216584')
# Accediendo a la película con ID tt0216746
# Nombre de la película: Las chicas malas del valle
# Dirección: John T. Kretchmer
# Guionistas: Paul Fleischman, Robert Lo, CashAndrew Lane
# Argumento: Three snobbish high school girls prematurely age brought on from a curse, a drug (or something) after the arrival of new transfer student whom they believe is connected to a murder they committed a year earlier. A fate worse than death.
# ID de la película: tt0216746
# Datos extraídos: ('Las chicas malas del valle', '3,7', 'John T. Kretchmer', 'Paul Fleischman, Robert Lo, CashAndrew Lane', 'Three snobbish high school girls prematurely age brought on from a curse, a drug (or something) after the arrival of new transfer student whom they believe is connected to a murder they committed a year earlier. A fate worse than death.', 'tt0216746')
# Accediendo a la película con ID tt0222167
# Nombre de la película: Lucky 13
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0222167
# Datos extraídos: ('Lucky 13', '4,5', '', '', 'No disponible', 'tt0222167')
# Accediendo a la película con ID tt0226851
# Nombre de la película: Slipdream
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0226851
# Datos extraídos: ('Slipdream', '6,6', '', '', 'No disponible', 'tt0226851')
# Accediendo a la película con ID tt0121766
# Nombre de la película: Star Wars: Episodio III - La venganza de los sith
# Dirección: George Lucas
# Guionistas: George Lucas
# Argumento: Tras tres años de Guerras Clon, los jedi rescatan a Palpatine del Conde Dooku. Mientras Obi-Wan persigue una nueva amenaza, Anakin actúa como agente doble entre el Consejo Jedi y Palpatine, siendo atraído por un siniestro plan.
# ID de la película: tt0121766
# Datos extraídos: ('Star Wars: Episodio III - La venganza de los sith', '7,6', 'George Lucas', 'George Lucas', 'Tras tres años de Guerras Clon, los jedi rescatan a Palpatine del Conde Dooku. Mientras Obi-Wan persigue una nueva amenaza, Anakin actúa como agente doble entre el Consejo Jedi y Palpatine, siendo atraído por un siniestro plan.', 'tt0121766')
# Accediendo a la película con ID tt0120667
# Nombre de la película: Los 4 Fantásticos
# Dirección: Tim Story
# Guionistas: Mark Frost, Michael France, Stan Lee
# Argumento: Un grupo de astronautas adquiere superpoderes tras una exposición a la radiación cósmica y debe utilizarlos para oponerse a los planes de su enemigo, el Doctor Doom.
# ID de la película: tt0120667
# Datos extraídos: ('Los 4 Fantásticos', '5,7', 'Tim Story', 'Mark Frost, Michael France, Stan Lee', 'Un grupo de astronautas adquiere superpoderes tras una exposición a la radiación cósmica y debe utilizarlos para oponerse a los planes de su enemigo, el Doctor Doom.', 'tt0120667')
# Accediendo a la película con ID tt0228906
# Nombre de la película: Striptease Baby Dolls from Cleveland Meet the Unkillables
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0228906
# Datos extraídos: ('Striptease Baby Dolls from Cleveland Meet the Unkillables', '5,8', '', '', 'No disponible', 'tt0228906')
# Accediendo a la película con ID tt0244306
# Nombre de la película: Wilson Chance
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0244306
# Datos extraídos: ('Wilson Chance', '8,1', '', '', 'No disponible', 'tt0244306')
# Accediendo a la película con ID tt0290747
# Nombre de la película: Man Thing (La naturaleza del miedo)
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0290747
# Datos extraídos: ('Man Thing (La naturaleza del miedo)', '4,1', '', '', 'No disponible', 'tt0290747')
# Accediendo a la película con ID tt0295590
# Nombre de la película: La maldicion del pirata
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0295590
# Datos extraídos: ('La maldicion del pirata', '3,4', '', '', 'No disponible', 'tt0295590')
# Accediendo a la película con ID tt0301265
# Nombre de la película: Dark Warrior
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0301265
# Datos extraídos: ('Dark Warrior', '3,4', '', '', 'No disponible', 'tt0301265')
# Accediendo a la película con ID tt0234084
# Nombre de la película: Last Mountain
# Dirección: Robert Fleet
# Guionistas: Robert Fleet, Stephan Szpak, -Fleet
# Argumento: A homeless dying veteran, trying to find a Unicorn he believes lives in the mountains above Los Angeles, convinces a Latina immigrant to join his quest, provoking a tragic-comic chase as they are followed by the Border Patrol and her Lowrider cousins.
# ID de la película: tt0234084
# Datos extraídos: ('Last Mountain', '8,2', 'Robert Fleet', 'Robert Fleet, Stephan Szpak, -Fleet', 'A homeless dying veteran, trying to find a Unicorn he believes lives in the mountains above Los Angeles, convinces a Latina immigrant to join his quest, provoking a tragic-comic chase as they are followed by the Border Patrol and her Lowrider cousins.', 'tt0234084')
# Accediendo a la película con ID tt0243462
# Nombre de la película: Mee-Shee: El gigante del agua
# Dirección: John Henderson
# Guionistas: Barry Authors
# Argumento: A New York City oil company troubleshooter is brought to a remote B.C. lake to look for some lost machinery. Cancelling a trip to Disney World with his son, he decides to bring the boy along. They both end up experiencing more excitement than Mickey could ever conjure in Orlando, when they meet up with bad guys and a legendary creature.
# ID de la película: tt0243462
# Datos extraídos: ('Mee-Shee: El gigante del agua', '5,3', 'John Henderson', 'Barry Authors', 'A New York City oil company troubleshooter is brought to a remote B.C. lake to look for some lost machinery. Cancelling a trip to Disney World with his son, he decides to bring the boy along. They both end up experiencing more excitement than Mickey could ever conjure in Orlando, when they meet up with bad guys and a legendary creature.', 'tt0243462')
# Accediendo a la película con ID tt0312004
# Nombre de la película: Wallace & Gromit: La maldición de las verduras
# Dirección: Steve BoxNick Park
# Guionistas: Steve Box, Nick Park, Mark Burton
# Argumento: Wallace y su leal perro Gromit se disponen a resolver el misterio tras la plaga que acecha los huertos de todos los vecinos y que amenaza con arruinar el torneo anual de verduras gigantes.
# ID de la película: tt0312004
# Datos extraídos: ('Wallace & Gromit: La maldición de las verduras', '7,5', 'Steve BoxNick Park', 'Steve Box, Nick Park, Mark Burton', 'Wallace y su leal perro Gromit se disponen a resolver el misterio tras la plaga que acecha los huertos de todos los vecinos y que amenaza con arruinar el torneo anual de verduras gigantes.', 'tt0312004')
# Accediendo a la película con ID tt0327660
# Nombre de la película: Lung do kei yuen
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0327660
# Datos extraídos: ('Lung do kei yuen', '5,0', '', '', 'No disponible', 'tt0327660')
# Accediendo a la película con ID tt0257516
# Nombre de la película: La maldición (Cursed)
# Dirección: Wes Craven
# Guionistas: Kevin Williamson
# Argumento: Un hombre lobo suelto en Los Ángeles cambia la vida de tres jóvenes que, tras ser mutilados por la bestia, aprenden que deben matarla para evitar convertirse ellos mismos en hombres lobo.
# ID de la película: tt0257516
# Datos extraídos: ('La maldición (Cursed)', '5,1', 'Wes Craven', 'Kevin Williamson', 'Un hombre lobo suelto en Los Ángeles cambia la vida de tres jóvenes que, tras ser mutilados por la bestia, aprenden que deben matarla para evitar convertirse ellos mismos en hombres lobo.', 'tt0257516')
# Accediendo a la película con ID tt0264323
# Nombre de la película: 2001 maniacos
# Dirección: Tim Sullivan
# Guionistas: Chris Kobin, Tim Sullivan, Chris Kobin
# Argumento: Eight college students travelling to Florida for Spring Break stumble into a remote town in Georgia, where they are set upon by the residents.
# ID de la película: tt0264323
# Datos extraídos: ('2001 maniacos', '5,3', 'Tim Sullivan', 'Chris Kobin, Tim Sullivan, Chris Kobin', 'Eight college students travelling to Florida for Spring Break stumble into a remote town in Georgia, where they are set upon by the residents.', 'tt0264323')
# Accediendo a la película con ID tt0267506
# Nombre de la película: Frankenstein & the Werewolf Reborn!
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0267506
# Datos extraídos: ('Frankenstein & the Werewolf Reborn!', '4,7', '', '', 'No disponible', 'tt0267506')
# Accediendo a la película con ID tt0274509
# Nombre de la película: From Venus
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0274509
# Datos extraídos: ('From Venus', '4,5', '', '', 'No disponible', 'tt0274509')
# Accediendo a la película con ID tt0153517
# Nombre de la película: Jackpot
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0153517
# Datos extraídos: ('Jackpot', 'No disponible', '', '', 'No disponible', 'tt0153517')
# Accediendo a la película con ID tt0204322
# Nombre de la película: Firecracker
# Dirección: Steve Balderson
# Guionistas: Steve Balderson, Clark Balderson
# Argumento: A young boy who lives in a dysfunctional home went to the carnival and met a singer. Shortly after, a murder took place. The town's sheriff is seeking answers. The singer is trying to escape her environment so is the boy. But both has to face their own horror.
# ID de la película: tt0204322
# Datos extraídos: ('Firecracker', '5,0', 'Steve Balderson', 'Steve Balderson, Clark Balderson', "A young boy who lives in a dysfunctional home went to the carnival and met a singer. Shortly after, a murder took place. The town's sheriff is seeking answers. The singer is trying to escape her environment so is the boy. But both has to face their own horror.", 'tt0204322')
# Accediendo a la película con ID tt0220605
# Nombre de la película: The Krone Experiment
# Dirección: J. Robinson Wheeler
# Guionistas: J. Craig Wheeler, J. Robinson Wheeler
# Argumento: A group of scientific intelligence experts must track down the source of a mysterious seismic signal that is causing pinpoints of destruction around the globe. When a Russian ship is disabled, tensions between Russia and the U.S. are revived, threatening to re-ignite the Cold War. When the team finally uncovers the truth about the Krone experiment, they discover a tic... Leer todo
# ID de la película: tt0220605
# Datos extraídos: ('The Krone Experiment', '7,0', 'J. Robinson Wheeler', 'J. Craig Wheeler, J. Robinson Wheeler', 'A group of scientific intelligence experts must track down the source of a mysterious seismic signal that is causing pinpoints of destruction around the globe. When a Russian ship is disabled, tensions between Russia and the U.S. are revived, threatening to re-ignite the Cold War. When the team finally uncovers the truth about the Krone experiment, they discover a tic... Leer todo', 'tt0220605')
# Accediendo a la película con ID tt0304356
# Nombre de la película: Love Thy Neighbor
# Dirección: Nick Gregory
# Guionistas: Nick Gregory, Kirk Aanes
# Argumento: Two married couples are about to give new meaning to the phrase Love Thy Neighbor. When these best friends become more than just friends, one simple game leads to another. A twisted comedy about relationships, deception, and consequences.
# ID de la película: tt0304356
# Datos extraídos: ('Love Thy Neighbor', '3,3', 'Nick Gregory', 'Nick Gregory, Kirk Aanes', 'Two married couples are about to give new meaning to the phrase Love Thy Neighbor. When these best friends become more than just friends, one simple game leads to another. A twisted comedy about relationships, deception, and consequences.', 'tt0304356')
# Accediendo a la película con ID tt0324107
# Nombre de la película: Los suicidas
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0324107
# Datos extraídos: ('Los suicidas', '5,5', '', '', 'No disponible', 'tt0324107')
# Accediendo a la película con ID tt0330373
# Nombre de la película: Harry Potter y el cáliz de fuego
# Dirección: Mike Newell
# Guionistas: Steve Kloves, J.K. Rowling
# Argumento: Harry Potter se encuentra compitiendo en un peligroso torneo entre escuelas de magia rivales, pero está distraído por pesadillas recurrentes.
# ID de la película: tt0330373
# Datos extraídos: ('Harry Potter y el cáliz de fuego', '7,7', 'Mike Newell', 'Steve Kloves, J.K. Rowling', 'Harry Potter se encuentra compitiendo en un peligroso torneo entre escuelas de magia rivales, pero está distraído por pesadillas recurrentes.', 'tt0330373')
# Accediendo a la película con ID tt0337656
# Nombre de la película: Keep Your Distance
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0337656
# Datos extraídos: ('Keep Your Distance', '5,1', '', '', 'No disponible', 'tt0337656')
# Accediendo a la película con ID tt0342882
# Nombre de la película: El afinador de terremotos
# Dirección: Stephen QuayTimothy QuayWeiser Quay
# Guionistas: Alan Passes, Stephen Quay, Timothy Quay
# Argumento: Dark fairy-tale about a demonic doctor who abducts a beautiful opera singer with designs on transforming her into a mechanical nightingale.
# ID de la película: tt0342882
# Datos extraídos: ('El afinador de terremotos', '6,2', 'Stephen QuayTimothy QuayWeiser Quay', 'Alan Passes, Stephen Quay, Timothy Quay', 'Dark fairy-tale about a demonic doctor who abducts a beautiful opera singer with designs on transforming her into a mechanical nightingale.', 'tt0342882')
# Accediendo a la película con ID tt0285682
# Nombre de la película: Alchemy
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0285682
# Datos extraídos: ('Alchemy', '5,3', '', '', 'No disponible', 'tt0285682')
# Accediendo a la película con ID tt0287927
# Nombre de la película: Aspects of Love
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0287927
# Datos extraídos: ('Aspects of Love', '7,4', '', '', 'No disponible', 'tt0287927')
# Accediendo a la película con ID tt0294870
# Nombre de la película: Rent
# Dirección: Chris Columbus
# Guionistas: Jonathan Larson, Stephen Chbosky
# Argumento: Esta es la versión cinematográfica del musical ganador de un premio Pulitzer y Tony sobre los bohemios en el East Village de la ciudad de Nueva York que luchan con la vida, el amor y el SIDA, y los impactos que tienen en Estados Unidos.
# ID de la película: tt0294870
# Datos extraídos: ('Rent', '6,8', 'Chris Columbus', 'Jonathan Larson, Stephen Chbosky', 'Esta es la versión cinematográfica del musical ganador de un premio Pulitzer y Tony sobre los bohemios en el East Village de la ciudad de Nueva York que luchan con la vida, el amor y el SIDA, y los impactos que tienen en Estados Unidos.', 'tt0294870')
# Accediendo a la película con ID tt0295605
# Nombre de la película: Going Shopping
# Dirección: Henry Jaglom
# Guionistas: Victoria Foyt, Henry Jaglom
# Argumento: A clothing designer tries to save her struggling boutique store by having a tumultuous weekend sale of her shop's inventory by playing on the addictions of shopping for the women of Beverly Hills.
# ID de la película: tt0295605
# Datos extraídos: ('Going Shopping', '5,1', 'Henry Jaglom', 'Victoria Foyt, Henry Jaglom', "A clothing designer tries to save her struggling boutique store by having a tumultuous weekend sale of her shop's inventory by playing on the addictions of shopping for the women of Beverly Hills.", 'tt0295605')
# Accediendo a la película con ID tt0160261
# Nombre de la película: False River
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0160261
# Datos extraídos: ('False River', '6,0', '', '', 'No disponible', 'tt0160261')
# Accediendo a la película con ID tt0219171
# Nombre de la película: Ripley Under Ground
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0219171
# Datos extraídos: ('Ripley Under Ground', '5,9', '', '', 'No disponible', 'tt0219171')
# Accediendo a la película con ID tt0227189
# Nombre de la película: Cl.One
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0227189
# Datos extraídos: ('Cl.One', '3,3', '', '', 'No disponible', 'tt0227189')
# Accediendo a la película con ID tt0261759
# Nombre de la película: Imposture
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0261759
# Datos extraídos: ('Imposture', '6,4', '', '', 'No disponible', 'tt0261759')
# Accediendo a la película con ID tt0110476
# Nombre de la película: Master i Margarita
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0110476
# Datos extraídos: ('Master i Margarita', '6,4', '', '', 'No disponible', 'tt0110476')
# Accediendo a la película con ID tt0136517
# Nombre de la película: Seven Days of Grace
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0136517
# Datos extraídos: ('Seven Days of Grace', '3,5', '', '', 'No disponible', 'tt0136517')
# Accediendo a la película con ID tt0166871
# Nombre de la película: Viúva Rica Solteira Não Fica
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0166871
# Datos extraídos: ('Viúva Rica Solteira Não Fica', '6,7', '', '', 'No disponible', 'tt0166871')
# Accediendo a la película con ID tt0206634
# Nombre de la película: Hijos de los hombres
# Dirección: Alfonso Cuarón
# Guionistas: Alfonso Cuar, ónTimothy J. SextonDavid Arata
# Argumento: En el 2027, en un mundo caótico en el que las mujeres se han vuelto estériles sin que se sepa el motivo, un antiguo activista accede a prestar su ayuda para transportar a una mujer milagrosamente embarazada a un santuario junto al mar.
# ID de la película: tt0206634
# Datos extraídos: ('Hijos de los hombres', '7,9', 'Alfonso Cuarón', 'Alfonso Cuar, ónTimothy J. SextonDavid Arata', 'En el 2027, en un mundo caótico en el que las mujeres se han vuelto estériles sin que se sepa el motivo, un antiguo activista accede a prestar su ayuda para transportar a una mujer milagrosamente embarazada a un santuario junto al mar.', 'tt0206634')
# Accediendo a la película con ID tt0260042
# Nombre de la película: False Prophets
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0260042
# Datos extraídos: ('False Prophets', '6,3', '', '', 'No disponible', 'tt0260042')
# Accediendo a la película con ID tt0197633
# Nombre de la película: Live Freaky Die Freaky
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0197633
# Datos extraídos: ('Live Freaky Die Freaky', '4,8', '', '', 'No disponible', 'tt0197633')
# Accediendo a la película con ID tt0204250
# Nombre de la película: Death of a Saleswoman
# Dirección: Donna Wheeler
# Guionistas: Donna Wheeler
# Argumento: Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her personally. All were named as suspects. See if you can figure out her killer.
# ID de la película: tt0204250
# Datos extraídos: ('Death of a Saleswoman', '2,2', 'Donna Wheeler', 'Donna Wheeler', 'Top-ranking RubberTubber saleswoman Agatha J. Ruby was brutally beaten and shot on her morning jog by an unknown assailant. Over six thousand dollars worth of her best plastic storage ware was stolen from her trunk. Nearly all 200 residents in her hometown of Mametville, Washington knew her personally. All were named as suspects. See if you can figure out her killer.', 'tt0204250')
# Accediendo a la película con ID tt0244521
# Nombre de la película: Funny Money
# Dirección: Leslie Greif
# Guionistas: Harry Basil, Leslie Greif, Ray Cooney
# Argumento: When Henry Perkins accidentally trades his briefcase with a man, he finds five million dollars inside. However, the cash draws in Mr. Big, who wants to reclaim his money.
# ID de la película: tt0244521
# Datos extraídos: ('Funny Money', '5,2', 'Leslie Greif', 'Harry Basil, Leslie Greif, Ray Cooney', 'When Henry Perkins accidentally trades his briefcase with a man, he finds five million dollars inside. However, the cash draws in Mr. Big, who wants to reclaim his money.', 'tt0244521')
# Accediendo a la película con ID tt0270417
# Nombre de la película: Cómo prepararse para una cita en Queens
# Dirección: Michelle Danner
# Guionistas: Richard Vetere
# Argumento: A self-proclaimed dating expert tries to get his best friend, who lost his wife two years earlier, back into the dating scene, with disastrous results.
# ID de la película: tt0270417
# Datos extraídos: ('Cómo prepararse para una cita en Queens', '4,3', 'Michelle Danner', 'Richard Vetere', 'A self-proclaimed dating expert tries to get his best friend, who lost his wife two years earlier, back into the dating scene, with disastrous results.', 'tt0270417')
# Accediendo a la película con ID tt0275258
# Nombre de la película: Mothers and Daughters
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0275258
# Datos extraídos: ('Mothers and Daughters', '5,4', '', '', 'No disponible', 'tt0275258')
# Accediendo a la película con ID tt0280000
# Nombre de la película: Ozzie
# Dirección: William Tannen
# Guionistas: Michael Lach, Lori O'BrienKyle Southam
# Argumento: Ozzie (Steven Kynman) is a young koala living in Australia. He is kidnapped by two goons, Buzz Maroni (Peter Rowley) and Tank Emerson (Ralf Moeller), who work for Max Happy (Dame Joan Collins), President of Happy Toys. Legend says that Ozzie speaks English and Max wants to clone Ozzie into hundreds of koalas and sell them for a fortune as talking pets. Buzz and Tank "... Leer todo
# ID de la película: tt0280000
# Datos extraídos: ('Ozzie', '4,3', 'William Tannen', "Michael Lach, Lori O'BrienKyle Southam", 'Ozzie (Steven Kynman) is a young koala living in Australia. He is kidnapped by two goons, Buzz Maroni (Peter Rowley) and Tank Emerson (Ralf Moeller), who work for Max Happy (Dame Joan Collins), President of Happy Toys. Legend says that Ozzie speaks English and Max wants to clone Ozzie into hundreds of koalas and sell them for a fortune as talking pets. Buzz and Tank "... Leer todo', 'tt0280000')
# Accediendo a la película con ID tt0284363
# Nombre de la película: Yo serví al rey de Inglaterra
# Dirección: Jirí Menzel
# Guionistas: Bohumil Hrabal, Jirí Menzel
# Argumento: A look at the glamorous life at an old-world Prague hotel.
# ID de la película: tt0284363
# Datos extraídos: ('Yo serví al rey de Inglaterra', '7,3', 'Jirí Menzel', 'Bohumil Hrabal, Jirí Menzel', 'A look at the glamorous life at an old-world Prague hotel.', 'tt0284363')
# Accediendo a la película con ID tt0317919
# Nombre de la película: Misión: Imposible 3
# Dirección: J.J. Abrams
# Guionistas: Alex Kurtzman, Roberto Orci, J.J. Abrams
# Argumento: Agente del IMF Ethan Hunt se enfrenta a un peligroso y sádico traficante de armas que amenaza su vida y la de su prometida.
# ID de la película: tt0317919
# Datos extraídos: ('Misión: Imposible 3', '6,9', 'J.J. Abrams', 'Alex Kurtzman, Roberto Orci, J.J. Abrams', 'Agente del IMF Ethan Hunt se enfrenta a un peligroso y sádico traficante de armas que amenaza su vida y la de su prometida.', 'tt0317919')
# Accediendo a la película con ID tt0340084
# Nombre de la película: The Drop
# Dirección: Kevin Lewis
# Guionistas: Troy Scott, Kevin Lewis
# Argumento: Un estudiante universitario es contratado simplemente para entregar un coche en un aparcamiento de Los Ángeles. El trabajo parece demasiado fácil, así que revisa el maletero y se convierte en objetivo de una guerra secreta.
# ID de la película: tt0340084
# Datos extraídos: ('The Drop', '2,6', 'Kevin Lewis', 'Troy Scott, Kevin Lewis', 'Un estudiante universitario es contratado simplemente para entregar un coche en un aparcamiento de Los Ángeles. El trabajo parece demasiado fácil, así que revisa el maletero y se convierte en objetivo de una guerra secreta.', 'tt0340084')
# Accediendo a la película con ID tt0337609
# Nombre de la película: Detroit
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0337609
# Datos extraídos: ('Detroit', '5,4', '', '', 'No disponible', 'tt0337609')
# Accediendo a la película con ID tt0339382
# Nombre de la película: Meteoro
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0339382
# Datos extraídos: ('Meteoro', '6,1', '', '', 'No disponible', 'tt0339382')
# Accediendo a la película con ID tt0348150
# Nombre de la película: Superman Returns: El regreso
# Dirección: Bryan Singer
# Guionistas: Michael Dougherty, Dan Harris, Bryan Singer
# Argumento: Superman reaparece después de una larga ausencia, pero es desafiado por un viejo enemigo que utiliza la tecnología kriptoniana para dominar el mundo.
# ID de la película: tt0348150
# Datos extraídos: ('Superman Returns: El regreso', '6,1', 'Bryan Singer', 'Michael Dougherty, Dan Harris, Bryan Singer', 'Superman reaparece después de una larga ausencia, pero es desafiado por un viejo enemigo que utiliza la tecnología kriptoniana para dominar el mundo.', 'tt0348150')
# Accediendo a la película con ID tt0144280
# Nombre de la película: Whispers from a Shallow Grave
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0144280
# Datos extraídos: ('Whispers from a Shallow Grave', '4,4', '', '', 'No disponible', 'tt0144280')
# Accediendo a la película con ID tt0308353
# Nombre de la película: Érase una vez... un cuento al revés
# Dirección: Paul BolgerYvette KaplanGreg Tiernan
# Guionistas: Robert Moreland, Doug Langdale, Andre Sikojev
# Argumento: An alliance of evil-doers, led by Frieda, looks to take over Fairy Tale Land. But when Ella realizes her stepmother is out to ruin her storybook existence, she takes a dramatic turn and blossoms into the leader of the resistance effort.
# ID de la película: tt0308353
# Datos extraídos: ('Érase una vez... un cuento al revés', '4,5', 'Paul BolgerYvette KaplanGreg Tiernan', 'Robert Moreland, Doug Langdale, Andre Sikojev', 'An alliance of evil-doers, led by Frieda, looks to take over Fairy Tale Land. But when Ella realizes her stepmother is out to ruin her storybook existence, she takes a dramatic turn and blossoms into the leader of the resistance effort.', 'tt0308353')
# Accediendo a la película con ID tt0344854
# Nombre de la película: Arthur y los minimoys
# Dirección: Luc Besson
# Guionistas: Céline GarciaLuc Besson, Patrice Garcia
# Argumento: Arthur, un niño de diez años, en un intento de salvar la casa de su abuelo de la demolición, va en busca de un tesoro escondido en la tierra de los minimoys, gente diminuta que vive en armonía con la naturaleza.
# ID de la película: tt0344854
# Datos extraídos: ('Arthur y los minimoys', '6,0', 'Luc Besson', 'Céline GarciaLuc Besson, Patrice Garcia', 'Arthur, un niño de diez años, en un intento de salvar la casa de su abuelo de la demolición, va en busca de un tesoro escondido en la tierra de los minimoys, gente diminuta que vive en armonía con la naturaleza.', 'tt0344854')
# Accediendo a la película con ID tt0354899
# Nombre de la película: La ciencia del sueño
# Dirección: Michel Gondry
# Guionistas: Michel Gondry
# Argumento: Un hombre que vive en trance en su onírica imaginación se enamora de una mujer y siente que puede enseñarle su universo singular.
# ID de la película: tt0354899
# Datos extraídos: ('La ciencia del sueño', '7,2', 'Michel Gondry', 'Michel Gondry', 'Un hombre que vive en trance en su onírica imaginación se enamora de una mujer y siente que puede enseñarle su universo singular.', 'tt0354899')
# Accediendo a la película con ID tt0361852
# Nombre de la película: Love Hollywood Style
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0361852
# Datos extraídos: ('Love Hollywood Style', '4,7', '', '', 'No disponible', 'tt0361852')
# Accediendo a la película con ID tt0367567
# Nombre de la película: La novia del mar
# Dirección: José Pepe Bojórquez
# Guionistas: José Pepe Boj, órquezDavid Howard
# Argumento: On an island across the sea lies a village full of romance, wonder and mystery; a timeless place where people carry strong beliefs that can fulfill the heart's deepest desires. A beautiful woman, led to believe she has powerful ties to the sea, defies everyone to prove them wrong, in a world where man and nature connect in improbable ways, where myths are real and tru... Leer todo
# ID de la película: tt0367567
# Datos extraídos: ('La novia del mar', '6,0', 'José Pepe Bojórquez', 'José Pepe Boj, órquezDavid Howard', "On an island across the sea lies a village full of romance, wonder and mystery; a timeless place where people carry strong beliefs that can fulfill the heart's deepest desires. A beautiful woman, led to believe she has powerful ties to the sea, defies everyone to prove them wrong, in a world where man and nature connect in improbable ways, where myths are real and tru... Leer todo", 'tt0367567')
# Accediendo a la película con ID tt0279688
# Nombre de la película: Beyond the Wall of Sleep
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0279688
# Datos extraídos: ('Beyond the Wall of Sleep', '2,9', '', '', 'No disponible', 'tt0279688')
# Accediendo a la película con ID tt0287072
# Nombre de la película: Under Surveillance
# Dirección: Dave Campfield
# Guionistas: Dave Campfield
# Argumento: When a dead body turns up, a local group of Satanists seem the most likely suspects. With the help of a friend, a criminal law student decides to conduct his own investigation by placing his neighbors under 24/7 video surveillance.
# ID de la película: tt0287072
# Datos extraídos: ('Under Surveillance', '3,8', 'Dave Campfield', 'Dave Campfield', 'When a dead body turns up, a local group of Satanists seem the most likely suspects. With the help of a friend, a criminal law student decides to conduct his own investigation by placing his neighbors under 24/7 video surveillance.', 'tt0287072')
# Accediendo a la película con ID tt0320626
# Nombre de la película: Through the Looking Glass
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0320626
# Datos extraídos: ('Through the Looking Glass', '5,2', '', '', 'No disponible', 'tt0320626')
# Accediendo a la película con ID tt0328899
# Nombre de la película: The Creature of the Sunny Side Up Trailer Park
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0328899
# Datos extraídos: ('The Creature of the Sunny Side Up Trailer Park', '3,8', '', '', 'No disponible', 'tt0328899')
# Accediendo a la película con ID tt0331334
# Nombre de la película: Satan's Playground
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0331334
# Datos extraídos: ("Satan's Playground", '3,5', '', '', 'No disponible', 'tt0331334')
# Accediendo a la película con ID tt0296604
# Nombre de la película: Down the Road
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0296604
# Datos extraídos: ('Down the Road', '7,7', '', '', 'No disponible', 'tt0296604')
# Accediendo a la película con ID tt0349467
# Nombre de la película: El color del crimen
# Dirección: Joe Roth
# Guionistas: Richard Price
# Argumento: Un detective de policía negro debe resolver un extraño caso de un niño secuestrado y hacer frente a una gran protesta racial.
# ID de la película: tt0349467
# Datos extraídos: ('El color del crimen', '5,2', 'Joe Roth', 'Richard Price', 'Un detective de policía negro debe resolver un extraño caso de un niño secuestrado y hacer frente a una gran protesta racial.', 'tt0349467')
# Accediendo a la película con ID tt0353357
# Nombre de la película: El inquisidor
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0353357
# Datos extraídos: ('El inquisidor', '5,4', '', '', 'No disponible', 'tt0353357')
# Accediendo a la película con ID tt0362225
# Nombre de la película: No se lo digas a nadie
# Dirección: Guillaume Canet
# Guionistas: Guillaume Canet, Harlan Coben, Philippe Lefebvre
# Argumento: Un descubrimiento accidental cerca de la propiedad de un doctor reabre las dolorosas heridas abiertas hace 8 años con el asesinato de su esposa.
# ID de la película: tt0362225
# Datos extraídos: ('No se lo digas a nadie', '7,5', 'Guillaume Canet', 'Guillaume Canet, Harlan Coben, Philippe Lefebvre', 'Un descubrimiento accidental cerca de la propiedad de un doctor reabre las dolorosas heridas abiertas hace 8 años con el asesinato de su esposa.', 'tt0362225')
# Accediendo a la película con ID tt0291569
# Nombre de la película: The Worst Day Ever
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0291569
# Datos extraídos: ('The Worst Day Ever', 'No disponible', '', '', 'No disponible', 'tt0291569')
# Accediendo a la película con ID tt0302545
# Nombre de la película: An Existential Affair
# Dirección: Peggy Bruen
# Guionistas: Peggy Bruen
# Argumento: The story of two lovers, a woman and a Young Republican, who meet in hotel rooms over the 1990s to explore their sexual prowess. Only when they venture out of 'the box' does reality start to tear at the fabric of their private, existential affair. Nothing stays the same. They marry. Guess what happens next?
# ID de la película: tt0302545
# Datos extraídos: ('An Existential Affair', '4,1', 'Peggy Bruen', 'Peggy Bruen', "The story of two lovers, a woman and a Young Republican, who meet in hotel rooms over the 1990s to explore their sexual prowess. Only when they venture out of 'the box' does reality start to tear at the fabric of their private, existential affair. Nothing stays the same. They marry. Guess what happens next?", 'tt0302545')
# Accediendo a la película con ID tt0314186
# Nombre de la película: Humko Tumse Pyaar Hai
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0314186
# Datos extraídos: ('Humko Tumse Pyaar Hai', '5,4', '', '', 'No disponible', 'tt0314186')
# Accediendo a la película con ID tt0323120
# Nombre de la película: Loving Annabelle
# Dirección: Katherine Brooks
# Guionistas: Katherine Brooks, Olivia Bohnhoff,  HarrisKaren Klopfenstein
# Argumento: La inteligente Annabelle comienza en un internado católico femenino de élite tras ser expulsada de sus dos colegios anteriores. Se declara abiertamente lesbiana y se siente atraída por su profesora, Simone.
# ID de la película: tt0323120
# Datos extraídos: ('Loving Annabelle', '6,2', 'Katherine Brooks', 'Katherine Brooks, Olivia Bohnhoff,  HarrisKaren Klopfenstein', 'La inteligente Annabelle comienza en un internado católico femenino de élite tras ser expulsada de sus dos colegios anteriores. Se declara abiertamente lesbiana y se siente atraída por su profesora, Simone.', 'tt0323120')
# Accediendo a la película con ID tt0337564
# Nombre de la película: 1972
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0337564
# Datos extraídos: ('1972', '6,0', '', '', 'No disponible', 'tt0337564')
# Accediendo a la película con ID tt0353667
# Nombre de la película: Der Liebeswunsch
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0353667
# Datos extraídos: ('Der Liebeswunsch', '5,7', '', '', 'No disponible', 'tt0353667')
# Accediendo a la película con ID tt0259822
# Nombre de la película: Calibre 45
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0259822
# Datos extraídos: ('Calibre 45', '5,5', '', '', 'No disponible', 'tt0259822')
# Accediendo a la película con ID tt0325011
# Nombre de la película: Camino sin retorno
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0325011
# Datos extraídos: ('Camino sin retorno', '6,9', '', '', 'No disponible', 'tt0325011')
# Accediendo a la película con ID tt0327389
# Nombre de la película: 5ive!
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0327389
# Datos extraídos: ('5ive!', '6,0', '', '', 'No disponible', 'tt0327389')
# Accediendo a la película con ID tt0196186
# Nombre de la película: I Viceré
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0196186
# Datos extraídos: ('I Viceré', '6,2', '', '', 'No disponible', 'tt0196186')
# Accediendo a la película con ID tt0206806
# Nombre de la película: Hermano
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0206806
# Datos extraídos: ('Hermano', '7,3', '', '', 'No disponible', 'tt0206806')
# Accediendo a la película con ID tt0211933
# Nombre de la película: Despierto
# Dirección: Joby Harold
# Guionistas: Joby Harold
# Argumento: Un joven adinerado que se somete a una operación de trasplante de corazón descubre que el equipo quirúrgico pretende asesinarle.
# ID de la película: tt0211933
# Datos extraídos: ('Despierto', '6,5', 'Joby Harold', 'Joby Harold', 'Un joven adinerado que se somete a una operación de trasplante de corazón descubre que el equipo quirúrgico pretende asesinarle.', 'tt0211933')
# Accediendo a la película con ID tt0213985
# Nombre de la película: Pasión sin fronteras
# Dirección: Vic Sarin
# Guionistas: Patricia Finn, Vic Sarin
# Argumento: During the turmoil and violence of Partition, a Sikh ex-soldier, haunted by war, offers shelter to a young Muslim woman who has been separated from her family.
# ID de la película: tt0213985
# Datos extraídos: ('Pasión sin fronteras', '6,9', 'Vic Sarin', 'Patricia Finn, Vic Sarin', 'During the turmoil and violence of Partition, a Sikh ex-soldier, haunted by war, offers shelter to a young Muslim woman who has been separated from her family.', 'tt0213985')
# Accediendo a la película con ID tt0218140
# Nombre de la película: Death and Taxis
# Dirección: Kevin Mukherji
# Guionistas: Nick Pullia
# Argumento: Take a fascinating journey in Death And Taxis where the journey is the destination, and the next world might be just a cab ride away. Hugging the double-yellow line between this life and the next, one big city taxi carries the stories of several drivers and passengers, each contending with intensely psychological and sometimes supernatural brushes with death. Whether ... Leer todo
# ID de la película: tt0218140
# Datos extraídos: ('Death and Taxis', '8,1', 'Kevin Mukherji', 'Nick Pullia', 'Take a fascinating journey in Death And Taxis where the journey is the destination, and the next world might be just a cab ride away. Hugging the double-yellow line between this life and the next, one big city taxi carries the stories of several drivers and passengers, each contending with intensely psychological and sometimes supernatural brushes with death. Whether ... Leer todo', 'tt0218140')
# Accediendo a la película con ID tt0242029
# Nombre de la película: Terra Sonâmbula
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0242029
# Datos extraídos: ('Terra Sonâmbula', '6,7', '', '', 'No disponible', 'tt0242029')
# Accediendo a la película con ID tt0243649
# Nombre de la película: Hitler Meets Christ
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0243649
# Datos extraídos: ('Hitler Meets Christ', '4,6', '', '', 'No disponible', 'tt0243649')
# Accediendo a la película con ID tt0283503
# Nombre de la película: La ley de Brooklyn
# Dirección: Michael Corrente
# Guionistas: Terence Winter
# Argumento: Brooklyn, 1985. With the mob world as a backdrop, three life-long friends struggle with questions of love, loss and loyalty.
# ID de la película: tt0283503
# Datos extraídos: ('La ley de Brooklyn', '6,3', 'Michael Corrente', 'Terence Winter', 'Brooklyn, 1985. With the mob world as a backdrop, three life-long friends struggle with questions of love, loss and loyalty.', 'tt0283503')
# Accediendo a la película con ID tt0287075
# Nombre de la película: Universal Groove
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0287075
# Datos extraídos: ('Universal Groove', '5,5', '', '', 'No disponible', 'tt0287075')
# Accediendo a la película con ID tt0119231
# Nombre de la película: The Junior Defenders
# Dirección: Keith Spiegel
# Guionistas: Keith Spiegel
# Argumento: A deranged fan goes on a mission to kidnap the former cast of a 1970s kids superhero show in order to produce his own episode.
# ID de la película: tt0119231
# Datos extraídos: ('The Junior Defenders', '4,3', 'Keith Spiegel', 'Keith Spiegel', 'A deranged fan goes on a mission to kidnap the former cast of a 1970s kids superhero show in order to produce his own episode.', 'tt0119231')
# Accediendo a la película con ID tt0227671
# Nombre de la película: Tortilla Heaven
# Dirección: Judy Hecht Dumontet
# Guionistas: Judy Hecht,  DumontetJulius Robinson, Mitchell Leib
# Argumento: Isidor's Tortilla Heaven is the best restaurant in the world, but has few customers and makes little money in a small town. During Mass one Sunday he is blessed with a miracle: the face of Jesus appears on one of his tortillas.
# ID de la película: tt0227671
# Datos extraídos: ('Tortilla Heaven', '5,3', 'Judy Hecht Dumontet', 'Judy Hecht,  DumontetJulius Robinson, Mitchell Leib', "Isidor's Tortilla Heaven is the best restaurant in the world, but has few customers and makes little money in a small town. During Mass one Sunday he is blessed with a miracle: the face of Jesus appears on one of his tortillas.", 'tt0227671')
# Accediendo a la película con ID tt0275236
# Nombre de la película: The Bros.
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0275236
# Datos extraídos: ('The Bros.', '2,8', '', '', 'No disponible', 'tt0275236')
# Accediendo a la película con ID tt0293564
# Nombre de la película: Hora punta 3
# Dirección: Brett Ratner
# Guionistas: Jeff Nathanson, Ross La, Manna
# Argumento: Tras el intento de asesinato del embajador chino, Lee y Carter se dirigen a Paris para proteger a una mujer que tiene conocimiento de los líderes secretos de las Tríadas, el sindicato criminal más peligroso.
# ID de la película: tt0293564
# Datos extraídos: ('Hora punta 3', '6,2', 'Brett Ratner', 'Jeff Nathanson, Ross La, Manna', 'Tras el intento de asesinato del embajador chino, Lee y Carter se dirigen a Paris para proteger a una mujer que tiene conocimiento de los líderes secretos de las Tríadas, el sindicato criminal más peligroso.', 'tt0293564')
# Accediendo a la película con ID tt0294654
# Nombre de la película: Hollywood Dot Com
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0294654
# Datos extraídos: ('Hollywood Dot Com', '6,1', '', '', 'No disponible', 'tt0294654')
# Accediendo a la película con ID tt0300007
# Nombre de la película: The Man Who Would Be Queen
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0300007
# Datos extraídos: ('The Man Who Would Be Queen', '5,8', '', '', 'No disponible', 'tt0300007')
# Accediendo a la película con ID tt0329354
# Nombre de la película: Marigold
# Dirección: Willard Carroll
# Guionistas: Willard Carroll
# Argumento: Ali Larter plays an American actress who becomes immersed in the Bollywood film world.
# ID de la película: tt0329354
# Datos extraídos: ('Marigold', '4,9', 'Willard Carroll', 'Willard Carroll', 'Ali Larter plays an American actress who becomes immersed in the Bollywood film world.', 'tt0329354')
# Accediendo a la película con ID tt0348062
# Nombre de la película: So, You've Downloaded a Demon
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0348062
# Datos extraídos: ("So, You've Downloaded a Demon", '5,8', '', '', 'No disponible', 'tt0348062')
# Accediendo a la película con ID tt0259324
# Nombre de la película: Ghost Rider: El motorista fantasma
# Dirección: Mark Steven Johnson
# Guionistas: Mark Steven,  Johnson
# Argumento: Cuando el motociclista Johnny Blaze vende su alma para salvar la vida de su padre, se transforma en El Motorista Fantasma, el cazarrecompensas del Diablo, y es enviado a cazar a los pecadores.
# ID de la película: tt0259324
# Datos extraídos: ('Ghost Rider: El motorista fantasma', '5,3', 'Mark Steven Johnson', 'Mark Steven,  Johnson', 'Cuando el motociclista Johnny Blaze vende su alma para salvar la vida de su padre, se transforma en El Motorista Fantasma, el cazarrecompensas del Diablo, y es enviado a cazar a los pecadores.', 'tt0259324')
# Accediendo a la película con ID tt0330972
# Nombre de la película: Intergalactic Combat
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0330972
# Datos extraídos: ('Intergalactic Combat', '6,5', '', '', 'No disponible', 'tt0330972')
# Accediendo a la película con ID tt0337978
# Nombre de la película: La jungla 4.0
# Dirección: Len Wiseman
# Guionistas: John Carlin, Roderick Thorp, Mark Bomback
# ...
# Accediendo a la película con ID tt0312958
# Nombre de la película: Chinango
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0312958
# Datos extraídos: ('Chinango', '5,3', '', '', 'No disponible', 'tt0312958')
# Accediendo a la película con ID tt0353765
# Nombre de la película: Los muertos van deprisa
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0353765
# Datos extraídos: ('Los muertos van deprisa', '5,8', '', '', 'No disponible', 'tt0353765')
# Accediendo a la película con ID tt0365873
# Nombre de la película: Two-Minute Heist
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0365873
# Datos extraídos: ('Two-Minute Heist', '5,1', '', '', 'No disponible', 'tt0365873')
# Accediendo a la película con ID tt0375568
# Nombre de la película: Astro Boy
# Dirección: David Bowers
# Guionistas: Osamu Tezuka, David Bowers, Timothy Harris
# Argumento: Cuando un androide réplica de un niño es rechazado por su afligido creador, sale a buscar su propia identidad en una aventura que lo convertirá en el mayor héroe de su tiempo.
# ID de la película: tt0375568
# Datos extraídos: ('Astro Boy', '6,2', 'David Bowers', 'Osamu Tezuka, David Bowers, Timothy Harris', 'Cuando un androide réplica de un niño es rechazado por su afligido creador, sale a buscar su propia identidad en una aventura que lo convertirá en el mayor héroe de su tiempo.', 'tt0375568')
# Accediendo a la película con ID tt0365929
# Nombre de la película: Terror en la Antártida
# Dirección: Dominic Sena
# Guionistas: Jon Hoeber, Erich Hoeber, Chad Hayes
# Argumento: En Antártica, el sol está a punto de ponerse para los próximos seis meses y la marshal Carrie Stetko da caza a un asesino.
# ID de la película: tt0365929
# Datos extraídos: ('Terror en la Antártida', '5,5', 'Dominic Sena', 'Jon Hoeber, Erich Hoeber, Chad Hayes', 'En Antártica, el sol está a punto de ponerse para los próximos seis meses y la marshal Carrie Stetko da caza a un asesino.', 'tt0365929')
# Accediendo a la película con ID tt0373340
# Nombre de la película: Sterling: The Secret of the Lost Medallion
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0373340
# Datos extraídos: ('Sterling: The Secret of the Lost Medallion', '5,9', '', '', 'No disponible', 'tt0373340')
# Accediendo a la película con ID tt0409459
# Nombre de la película: Watchmen
# Dirección: Zack Snyder
# Guionistas: Dave Gibbons, David Hayter, Alex Tse
# Argumento: En 1985, donde existen antiguos superhéroes, el asesinato de un colega envía al activo vigilante Rorschach a su propia investigación, descubriendo algo que podría cambiar completamente el curso de la historia tal y como la conocemos.
# ID de la película: tt0409459
# Datos extraídos: ('Watchmen', '7,6', 'Zack Snyder', 'Dave Gibbons, David Hayter, Alex Tse', 'En 1985, donde existen antiguos superhéroes, el asesinato de un colega envía al activo vigilante Rorschach a su propia investigación, descubriendo algo que podría cambiar completamente el curso de la historia tal y como la conocemos.', 'tt0409459')
# Accediendo a la película con ID tt0417741
# Nombre de la película: Harry Potter y el misterio del príncipe
# Dirección: David Yates
# Guionistas: Steve Kloves, J.K. Rowling
# Argumento: Cuando Harry Potter empieza su sexto año en Hogwarts, descubre un viejo libro marcado como propiedad del príncipe mestizo y comienza a aprender más sobre el oscuro pasado de Lord Voldemort.
# ID de la película: tt0417741
# Datos extraídos: ('Harry Potter y el misterio del príncipe', '7,6', 'David Yates', 'Steve Kloves, J.K. Rowling', 'Cuando Harry Potter empieza su sexto año en Hogwarts, descubre un viejo libro marcado como propiedad del príncipe mestizo y comienza a aprender más sobre el oscuro pasado de Lord Voldemort.', 'tt0417741')
# Accediendo a la película con ID tt0421237
# Nombre de la película: Royal Kill
# Dirección: Bob Ahmed
# Guionistas: Bob Ahmed
# Argumento: Mujer asesina recibe el encargo de matar al heredero himalayo en EE.UU. Un guardia real es enviado para salvaguardarlo. Cuando se conocen, ambos deben decidir entre el deber y algo más profundo que está surgiendo entre ellos.
# ID de la película: tt0421237
# Datos extraídos: ('Royal Kill', '2,9', 'Bob Ahmed', 'Bob Ahmed', 'Mujer asesina recibe el encargo de matar al heredero himalayo en EE.UU. Un guardia real es enviado para salvaguardarlo. Cuando se conocen, ambos deben decidir entre el deber y algo más profundo que está surgiendo entre ellos.', 'tt0421237')
# Accediendo a la película con ID tt0293354
# Nombre de la película: The Magic Stone
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0293354
# Datos extraídos: ('The Magic Stone', '6,4', '', '', 'No disponible', 'tt0293354')
# Accediendo a la película con ID tt0374853
# Nombre de la película: Malice in Wonderland
# Dirección: Simon Fellows
# Guionistas: Jayson Rothwell
# Argumento: A modern take on the classic fairytale, Alice in Wonderland, set in the North East of England.
# ID de la película: tt0374853
# Datos extraídos: ('Malice in Wonderland', '5,8', 'Simon Fellows', 'Jayson Rothwell', 'A modern take on the classic fairytale, Alice in Wonderland, set in the North East of England.', 'tt0374853')
# Accediendo a la película con ID tt0380510
# Nombre de la película: The Lovely Bones
# Dirección: Peter Jackson
# Guionistas: Fran Walsh, Philippa Boyens, Peter Jackson
# Argumento: En torno a una niña que ha sido asesinada y cuida de su familia - al tiempo que observa a su asesino - des del purgatorio. Tendrá que encontrar el equilibrio entre su deseo de venganza y su deseo de reconfortar a su familia.
# ID de la película: tt0380510
# Datos extraídos: ('The Lovely Bones', '6,6', 'Peter Jackson', 'Fran Walsh, Philippa Boyens, Peter Jackson', 'En torno a una niña que ha sido asesinada y cuida de su familia - al tiempo que observa a su asesino - des del purgatorio. Tendrá que encontrar el equilibrio entre su deseo de venganza y su deseo de reconfortar a su familia.', 'tt0380510')
# Accediendo a la película con ID tt0386117
# Nombre de la película: Donde viven los monstruos
# Dirección: Spike Jonze
# Guionistas: Spike Jonze, Dave Eggers, Maurice Sendak
# Argumento: Una adaptación de la historia infantil clásica de Maurice Sendak, en la que Max, un niño pequeño y desobediente es enviado a la cama sin su cena, crea su propio mundo--un bosque habitado por feroces criaturas salvajes quienes coronan Max como su gobernante.Reseña anónima (Traducida por IMDb.es)
# ID de la película: tt0386117
# Datos extraídos: ('Donde viven los monstruos', '6,7', 'Spike Jonze', 'Spike Jonze, Dave Eggers, Maurice Sendak', 'Una adaptación de la historia infantil clásica de Maurice Sendak, en la que Max, un niño pequeño y desobediente es enviado a la cama sin su cena, crea su propio mundo--un bosque habitado por feroces criaturas salvajes quienes coronan Max como su gobernante.Reseña anónima (Traducida por IMDb.es)', 'tt0386117')
# Accediendo a la película con ID tt0289146
# Nombre de la película: T.M.A.
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0289146
# Datos extraídos: ('T.M.A.', '4,7', '', '', 'No disponible', 'tt0289146')
# Accediendo a la película con ID tt0353665
# Nombre de la película: El libro de piedra
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0353665
# Datos extraídos: ('El libro de piedra', '4,1', '', '', 'No disponible', 'tt0353665')
# Accediendo a la película con ID tt0368563
# Nombre de la película: Posesión
# Dirección: Joel BergvallSimon Sandquist
# Guionistas: Michael Petroni, Won-mi ByunMin-ho Song
# Argumento: Jess tiene la desgracia de ver cómo su marido y el hermano de éste caen en coma tras un accidente de coche. Cuando su cuñado despierta, le dice a ella que él es realmente su marido. Ella deberá entender qué es lo que realmente sucede.
# ID de la película: tt0368563
# Datos extraídos: ('Posesión', '5,4', 'Joel BergvallSimon Sandquist', 'Michael Petroni, Won-mi ByunMin-ho Song', 'Jess tiene la desgracia de ver cómo su marido y el hermano de éste caen en coma tras un accidente de coche. Cuando su cuñado despierta, le dice a ella que él es realmente su marido. Ella deberá entender qué es lo que realmente sucede.', 'tt0368563')
# Accediendo a la película con ID tt0425141
# Nombre de la película: It Came from Trafalgar
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0425141
# Datos extraídos: ('It Came from Trafalgar', '7,0', '', '', 'No disponible', 'tt0425141')
# Accediendo a la película con ID tt0431670
# Nombre de la película: Cabeza de pescado
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0431670
# Datos extraídos: ('Cabeza de pescado', '7,6', '', '', 'No disponible', 'tt0431670')
# Accediendo a la película con ID tt0433362
# Nombre de la película: Daybreakers
# Dirección: Michael SpierigPeter Spierig
# Guionistas: Michael Spierig, Peter Spierig
# Argumento: En 2019, una plaga ha convertido a casi todos en vampiros. Dado el poco suministro de sangre, la raza dominante planea su supervivencia; mientras, un investigador trabaja con un grupo de vampiros encubiertos para salvar a la humanidad.
# ID de la película: tt0433362
# Datos extraídos: ('Daybreakers', '6,4', 'Michael SpierigPeter Spierig', 'Michael Spierig, Peter Spierig', 'En 2019, una plaga ha convertido a casi todos en vampiros. Dado el poco suministro de sangre, la raza dominante planea su supervivencia; mientras, un investigador trabaja con un grupo de vampiros encubiertos para salvar a la humanidad.', 'tt0433362')
# Accediendo a la película con ID tt0436154
# Nombre de la película: Cabras
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0436154
# Datos extraídos: ('Cabras', 'No disponible', '', '', 'No disponible', 'tt0436154')
# Accediendo a la película con ID tt0450336
# Nombre de la película: La masacre de Town Creek
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0450336
# Datos extraídos: ('La masacre de Town Creek', '5,3', '', '', 'No disponible', 'tt0450336')
# Accediendo a la película con ID tt0121569
# Nombre de la película: Moonlight Blade
# Puntuación de IMDb: No disponible
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0121569
# Datos extraídos: ('Moonlight Blade', 'No disponible', '', '', 'No disponible', 'tt0121569')
# Accediendo a la película con ID tt0381940
# Nombre de la película: Cargo
# Dirección: Ivan EnglerRalph Etter
# Guionistas: Arnold Bucher, Ivan Engler, Patrik Steinmann
# Argumento: Dr. Laura P. takes a job on a cargo spaceship for 4 years plus 4 years back. She'll join her sister on Rhea. 44 months later, in Laura's shift, strange things happen in cargo. The crew is reanimated and the captain dies mysteriously.
# ID de la película: tt0381940
# Datos extraídos: ('Cargo', '6,1', 'Ivan EnglerRalph Etter', 'Arnold Bucher, Ivan Engler, Patrik Steinmann', "Dr. Laura P. takes a job on a cargo spaceship for 4 years plus 4 years back. She'll join her sister on Rhea. 44 months later, in Laura's shift, strange things happen in cargo. The crew is reanimated and the captain dies mysteriously.", 'tt0381940')
# Accediendo a la película con ID tt0405022
# Nombre de la película: House of Boys
# Dirección: Jean-Claude Schlim
# Guionistas: Jean-Claude Schlim, Christian Thiry, Robert David,  Graham
# Argumento: Dos jóvenes almas gemelas se encuentran mientras trabajan en un club para hombres. Eventualmente, uno contrae el SIDA.
# ID de la película: tt0405022
# Datos extraídos: ('House of Boys', '6,5', 'Jean-Claude Schlim', 'Jean-Claude Schlim, Christian Thiry, Robert David,  Graham', 'Dos jóvenes almas gemelas se encuentran mientras trabajan en un club para hombres. Eventualmente, uno contrae el SIDA.', 'tt0405022')
# Accediendo a la película con ID tt0403702
# Nombre de la película: Rebelión adolescente
# Dirección: Miguel Arteta
# Guionistas: Gustin Nash, C.D. Payne
# Argumento: Mientras sus horribles padres se tambalean al borde del divorcio, Nick Twisp pone su mirada en la chica de sus sueños Sheeni Saunders, con la esperanza de que ella sea la que le quite la virginidad.
# ID de la película: tt0403702
# Datos extraídos: ('Rebelión adolescente', '6,4', 'Miguel Arteta', 'Gustin Nash, C.D. Payne', 'Mientras sus horribles padres se tambalean al borde del divorcio, Nick Twisp pone su mirada en la chica de sus sueños Sheeni Saunders, con la esperanza de que ella sea la que le quite la virginidad.', 'tt0403702')
# Accediendo a la película con ID tt0407852
# Nombre de la película: Utolsó jelentés Annáról
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0407852
# Datos extraídos: ('Utolsó jelentés Annáról', '6,6', '', '', 'No disponible', 'tt0407852')
# Accediendo a la película con ID tt0435716
# Nombre de la película: The Perfect Sleep
# Dirección: Jeremy Alter
# Guionistas: Anton Pardoe
# Argumento: Against the backdrop of a noirish dreamscape, a tortured man returns to the city he swore he would never return to, in order to save the woman he has always loved yet can never have.
# ID de la película: tt0435716
# Datos extraídos: ('The Perfect Sleep', '4,4', 'Jeremy Alter', 'Anton Pardoe', 'Against the backdrop of a noirish dreamscape, a tortured man returns to the city he swore he would never return to, in order to save the woman he has always loved yet can never have.', 'tt0435716')
# Accediendo a la película con ID tt0437065
# Nombre de la película: AmerAsian
# Dirección: Roger Lim
# Guionistas: Roger Lim
# Argumento: Eric, an American-born Asian college graduate, must steal a younger student's identity to take back the one last year of baseball eligibility that he lost when his dad passed away. Monica, his coach's All-American co-ed daughter, must ascertain her own questionable identity to come to terms with the years of abuse that she suffered after her mother passed away. Throug... Leer todo
# ID de la película: tt0437065
# Datos extraídos: ('AmerAsian', '6,7', 'Roger Lim', 'Roger Lim', "Eric, an American-born Asian college graduate, must steal a younger student's identity to take back the one last year of baseball eligibility that he lost when his dad passed away. Monica, his coach's All-American co-ed daughter, must ascertain her own questionable identity to come to terms with the years of abuse that she suffered after her mother passed away. Throug... Leer todo", 'tt0437065')
# Accediendo a la película con ID tt0437550
# Nombre de la película: Why George?
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0437550
# Datos extraídos: ('Why George?', '8,1', '', '', 'No disponible', 'tt0437550')
# Accediendo a la película con ID tt0438894
# Nombre de la película: Kisse Pyaar Karoon?
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0438894
# Datos extraídos: ('Kisse Pyaar Karoon?', '3,5', '', '', 'No disponible', 'tt0438894')
# Accediendo a la película con ID tt0448182
# Nombre de la película: Yesterday Was a Lie
# Dirección: James Kerwin
# Guionistas: James Kerwin
# Argumento: Hoyle, a girl with a sharp mind and a weakness for bourbon, finds herself on the trail of a reclusive genius. But her work takes a series of unforeseen twists as events around her grow increasingly fragmented... disconnected... surreal. With an ethereal lounge singer and her loyal partner as her only allies, Hoyle is plunged into a dark world of intrigue and earth-sha... Leer todo
# ID de la película: tt0448182
# Datos extraídos: ('Yesterday Was a Lie', '5,2', 'James Kerwin', 'James Kerwin', 'Hoyle, a girl with a sharp mind and a weakness for bourbon, finds herself on the trail of a reclusive genius. But her work takes a series of unforeseen twists as events around her grow increasingly fragmented... disconnected... surreal. With an ethereal lounge singer and her loyal partner as her only allies, Hoyle is plunged into a dark world of intrigue and earth-sha... Leer todo', 'tt0448182')
# Accediendo a la película con ID tt0408060
# Nombre de la película: 1
# Dirección:
# Guionistas:
# Argumento: No disponible
# ID de la película: tt0408060
# Datos extraídos: ('1', '6,0', '', '', 'No disponible', 'tt0408060')

# %%
# Guardar el DataFrame en un nuevo archivo CSV
df_peliculas.to_csv('peliculas_ext_sel_2005_2009.csv', index=False)
print("Archivo 'peliculas_ext_sel_2005_2009.csv' creado exitosamente.")
# Out:
# Archivo 'peliculas_ext_sel_2005_2009.csv' creado exitosamente.
